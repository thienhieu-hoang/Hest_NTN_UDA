# %%
import tensorflow as tf

import os
import sys
import numpy as np
from scipy.io import savemat

# Add the Torch_code directory to the Python path
# sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))
sys.path.append(os.path.abspath('helper'))
# import utils
# import loader
import utils_UDA_CNN15

# %%
notebook_dir = os.getcwd()
print(notebook_dir)
print(os.path.abspath(os.path.join(notebook_dir, '..', '..')))
sys.path.append(os.path.abspath(os.path.join(notebook_dir, '..', '..')))
import Est_btween_CSIRS.helper.utils as utils_CNN
import Est_btween_CSIRS.helper.loader as loader
import Est_btween_CSIRS.helper.plotfig as plotfig
# Out:
# /home/thien/Code/H_predict_UDA/H_predict_Sionna/Domain_Adaptation/Domain_Adversarial
# /home/thien/Code/H_predict_UDA/H_predict_Sionna

# %%
data_file_path = os.path.abspath(os.path.join(notebook_dir, '..', '..', 'Generate_Data', 'CDL_Channel', 'generatedChannel', 'ver3_'))
print(data_file_path)
source_data_file_path = os.path.abspath(os.path.join(notebook_dir, '..', '..', 'Generate_Data', 'CDL_Channel', 
                                                    'generatedChannel', 'ver3_', '0dB', 'mapBaseData.mat'))
target_data_file_path = os.path.abspath(os.path.join(notebook_dir, '..', '..', 'Generate_Data', 'CDL_Channel', 
                                                    'generatedChannel', 'ver3_', '10dB', 'mapBaseData.mat'))
# Out:
# /home/thien/Code/H_predict_UDA/H_predict_Sionna/Generate_Data/CDL_Channel/generatedChannel/ver3_

# %%
learning_rate = 0.0001
norm_approach = 'minmax' # can be set to 'std'
lower_range = -1 
    # if norm_approach = 'minmax': 
        # =  0 for scaling to  [0 1]
        # = -1 for scaling to [-1 1]
    # if norm_approach = 'std': can be any value, but need to be defined
    
# snr_start = -25
# snr_step = 5
# snr_end = 25
# SNR = np.arange(snr_start, snr_end+1, snr_step)

# SNR = np.array([0])

# if len(SNR) >1:
#     SNR_txt = f'{snr_start}:{snr_step}:{snr_end}'
# else:
#     SNR_txt = f'{SNR[0]}'
    
# ============ CNN settings ==============
if norm_approach == 'minmax':
    if lower_range == 0:
        norm_txt = 'Using min-max [0 1]'
    elif lower_range ==-1:
        norm_txt = 'Using min-max [-1 1]'
elif norm_approach == 'no':
    norm_txt = 'No'
    
CNN_activation = 'Tanh'
CNN_DropOut = 0.2
if CNN_DropOut != 0:
    dropOut_txt = f'Add p={CNN_DropOut} DropOut'
    
# ============ Adversarial for Domain Discriminator settings ==============
extract_layer = 5  # extract features after convelution layer 3 
# extract_layer = 5
lambda_domain=0.3
text_lambda = f'lambda_domain = {lambda_domain}'
    
    
# create readme.txt file
content = f"""Generated by file 'Domain_Adversarial/UDA_CNN_v1.ipynb'.
28 GHz fc,
Source dataset got from {source_data_file_path},
Target dataset got from {target_data_file_path},
Learning rate {learning_rate},
{norm_txt} scaler for each sample
Using {CNN_activation} as activation function of CNN
{dropOut_txt}
========= For Domain Discriminator ==========
Extract features after layer {extract_layer} of CNN
{text_lambda}
"""

# %%
# Paths to save
idx_save_path = loader.find_incremental_filename(notebook_dir + '/model/CNN','ver', '_', '')

model_path = notebook_dir + '/model/CNN/ver' + str(idx_save_path) + '_'
# figure_path = notebook_dir + '/model/CNN/ver' + str(idx_save_path) + '_/figure'
model_readme = model_path + '/readme.txt'
# figure_readme = figure_path + '/readme.txt'

if not os.path.exists(os.path.dirname(model_readme)):
    os.makedirs(os.path.dirname(model_readme))
# if not os.path.exists(os.path.dirname(figure_readme)):
#     os.makedirs(os.path.dirname(figure_readme))

# Open the file in write mode ('w'). If the file does not exist, it will be created.
with open(model_readme, 'w') as file:
    # Write the content to the file
    file.write(content)

# with open(figure_readme, 'w') as file:
#     # Write the content to the file
#     file.write(content)

print(f"File '{model_readme}'  created and content written.")
# Out:
# File '/home/thien/Code/H_predict_UDA/H_predict_Sionna/Domain_Adaptation/Domain_Adversarial/model/CNN/ver8_/readme.txt'  created and content written.

# %%
import h5py

batch_size=16

# ============ Source data ==============
source_file = h5py.File(source_data_file_path, 'r')
H_true_source = source_file['H_true']
N_samp_source = H_true_source.shape[0]
print('N_samp_source = ', N_samp_source)

# ============ Target data ==============
target_file = h5py.File(target_data_file_path, 'r')
H_true_target = target_file['H_true']
N_samp_target = H_true_target.shape[0]
print('N_samp_target = ', N_samp_target)
# Out:
# N_samp_source =  2048
# N_samp_target =  2048

# %%
indices_source = np.arange(N_samp_source)
np.random.shuffle(indices_source)
indices_target = np.arange(N_samp_target)
np.random.shuffle(indices_target)
#
train_size = int(np.floor(N_samp_source * 0.9) // batch_size * batch_size)
val_size = N_samp_source - train_size
print('train_size = ', train_size)
print('val_size = ', val_size)

# Repeat the indices to match the maximum number of samples
N_samp = max(N_samp_source, N_samp_target) 
indices_source = np.resize(indices_source, N_samp)
indices_target = np.resize(indices_target, N_samp)

# =======================================================
## Divide the indices into training and validation sets
indices_train_source = indices_source[:train_size]
indices_val_source   = indices_source[train_size:train_size + val_size]

indices_train_target = indices_target[:train_size]
indices_val_target   = indices_target[train_size:train_size + val_size]

# to test code
# indices_train_source = indices_source[:32]
# indices_val_source = indices_source[2032:]
# indices_train_target = indices_target[:32]
# indices_val_target = indices_target[2032:]
# Out:
# train_size =  1840
# val_size =  208

# %%
# =========== Source dataset ==============
loader_H_true_train_source = utils_CNN.H5BatchLoader(source_file, dataset_name='H_true', batch_size=batch_size, shuffled_indices=indices_train_source)
loader_H_1_6_11_train_source = utils_CNN.H5BatchLoader(source_file, 'H_linear_1_6_11', batch_size=batch_size, shuffled_indices=indices_train_source)
    # channel at symbol 2 of slots 1,6,11 (channel corresponding to CSI-RS 1, 2, 3)
loader_H_true_val_source = utils_CNN.H5BatchLoader(source_file, dataset_name='H_true', batch_size=batch_size, shuffled_indices=indices_val_source)
loader_H_1_6_11_val_source = utils_CNN.H5BatchLoader(source_file, 'H_linear_1_6_11', batch_size=batch_size, shuffled_indices=indices_val_source)

# =========== Target dataset ==============
loader_H_true_train_target = utils_CNN.H5BatchLoader(target_file, dataset_name='H_true', batch_size=batch_size, shuffled_indices=indices_train_target)
    # actually at target domain, we don't have true channels, just use this for evaluating the model
loader_H_1_6_11_train_target = utils_CNN.H5BatchLoader(target_file, 'H_linear_1_6_11', batch_size=batch_size, shuffled_indices=indices_train_target)
    # channel at symbol 2 of slots 1,6,11 (channel corresponding to CSI-RS 1, 2, 3)
loader_H_true_val_target = utils_CNN.H5BatchLoader(target_file, dataset_name='H_true', batch_size=batch_size, shuffled_indices=indices_val_target)
loader_H_1_6_11_val_target = utils_CNN.H5BatchLoader(target_file, 'H_linear_1_6_11', batch_size=batch_size, shuffled_indices=indices_val_target)

print('size loader_H_true_train = ', loader_H_true_train_target.total_batches)
print('size loader_H_true_val = ', loader_H_true_val_target.total_batches)
# Out:
# size loader_H_true_train =  115
# size loader_H_true_val =  13

# %%
loss_fn_ce = tf.keras.losses.MeanSquaredError()  # Channel estimation loss
loss_fn_domain = tf.keras.losses.BinaryCrossentropy()  # Domain classification loss

# %%
from tensorflow.keras import optimizers, losses

n_epochs= 70
epoch_min = 30
epoch_step = 10
# n_epochs= 2
# epoch_min = 0
# epoch_step = 1

train_mode = ['in_15_symbs']
for sub_folder in train_mode:
    print(f"Processing: {sub_folder}")
    
    if not os.path.exists(os.path.dirname(model_path + '/' + sub_folder +'/')):
        os.makedirs(os.path.dirname(model_path + '/' + sub_folder + '/'))

    train_loss          = [] # (epoch,1)
    train_est_loss      = [] 
    train_domain_loss   = []
    train_est_loss_target = []
    #    
    val_loss, val_domain_loss_source, val_domain_loss_target, val_domain_loss,\
    val_est_loss_source, val_est_loss_target, val_est_loss,\
    source_acc, target_acc, acc,\
    nmse_val_source, nmse_val_target, nmse_val = [[] for _ in range(13)]
    #
    H_to_save = {}          # list to save to .mat file for H
    perform_to_save = {}    # list to save to .mat file for nmse, losses,...
    
    model = utils_UDA_CNN15.UDA_CNN(extractLayer=extract_layer)
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    
    flag = 1 # flag to plot and save H_true

    for epoch in range(n_epochs):
        # ===================== Training =====================
        loader_H_true_train_source.reset()
        loader_H_1_6_11_train_source.reset()
        loader_H_true_train_target.reset()
        loader_H_1_6_11_train_target.reset()
                
        loader_H = [loader_H_1_6_11_train_source, loader_H_true_train_source, loader_H_1_6_11_train_target, loader_H_true_train_target]
        loss_fn = [loss_fn_ce, loss_fn_domain, optimizer]
        #
        train_epoc_loss_est, train_epoc_loss_domain, train_epoc_loss, train_epoc_loss_est_target = utils_UDA_CNN15.train_step(model, 
                                                        loader_H, loss_fn, lower_range, lambda_domain=lambda_domain)
                # train_epoc_loss        = total train loss = loss_est + lambda_domain * domain_loss
                # train_epoc_loss_est    = loss in estimation network in source domain (labels available)
                # train_epoc_loss_domain = loss in domain discrimination network
                # train_epoc_loss_est_target - just to monitor - the machine can not calculate because no label available in source domain
                # All are already calculated in average over training dataset (source/target - respectively)
        # Average loss for the epoch
        train_loss.append(train_epoc_loss)
        print(f"epoch {epoch+1}/{n_epochs} Average Training Loss: {train_epoc_loss:.6f}")
        #
        train_est_loss.append(train_epoc_loss_est)
        print(f"epoch {epoch+1}/{n_epochs} Average Estimation Loss (in Source domain): {train_epoc_loss_est:.6f}")
        #
        train_domain_loss.append(train_epoc_loss_domain)
        print(f"epoch {epoch+1}/{n_epochs} Average Domain Discrimination Loss: {train_epoc_loss_domain:.6f}")
        #
        train_est_loss_target.append(train_epoc_loss_est_target)
        print(f"epoch {epoch+1}/{n_epochs} For observation only - Average Estimation Loss in Target domain: {train_epoc_loss_est_target:.6f}")
        
        
        # ===================== Evaluation =====================
        loader_H_true_val_source.reset()
        loader_H_1_6_11_val_source.reset()
        loader_H_true_val_target.reset()
        loader_H_1_6_11_val_target.reset()
        loader_H_eval = [loader_H_1_6_11_val_source, loader_H_true_val_source, loader_H_1_6_11_val_target, loader_H_true_val_target]

        loss_fn = loss_fn_ce, loss_fn_domain
        
        eval_func = utils_UDA_CNN15.val_step
        if (epoch+1>epoch_min and epoch%epoch_step==0) or epoch==n_epochs-1:
            H_sample, epoc_val_return = utils_UDA_CNN15.val_step(model, loader_H_eval, loss_fn, lower_range, epoch=epoch, lambda_domain=lambda_domain)
            print('Unpack H_sample and save for visualization')
            (
                H_true_sample,  H_input_sample, H_est_sample, H_input_condition, 
                nmse_input_source, nmse_est_source, domain_sample_return_source,
                H_true_sample_target, H_input_sample_target, H_est_sample_target, H_input_condition_target,
                nmse_input_target, nmse_est_target, domain_sample_return_target
            ) = H_sample
            
            # plot real parts
            # source domain
            if flag == 1:
                plotfig.figChan(H_true_sample[0,:,:,0], title='True channel Slot 6', index_save=epoch+1, 
                                        figure_save_path=model_path + '/' + sub_folder + '/H_visualize', name='H_true_source')
                plotfig.figChan(H_input_sample[0,:,:,0], nmse=nmse_input_source[0], title='Raw-estimated Channel Slot 6', index_save=epoch+1, 
                                        figure_save_path=model_path + '/' + sub_folder + '/H_visualize', name='H_input_source')
                # if sub_folder == 'in_15_symbs' or sub_folder == 'FiLM':
                plotfig.figChan(H_input_condition[0,:,0,0], title='Condition Channel', index_save=epoch+1, 
                                        figure_save_path=model_path + '/' + sub_folder + '/H_visualize', name='H_input_condition_source')
            plotfig.figChan(H_est_sample[0,:,:,0], nmse=nmse_est_source[0], title='CNN-refined Channel Slot 6', index_save=epoch+1, 
                                        figure_save_path=model_path + '/' + sub_folder + '/H_visualize', name='H_CNN_source')
            # target domain
            if flag == 1:
                plotfig.figChan(H_true_sample_target[0,:,:,0], title='True channel Slot 6', index_save=epoch+1, 
                                        figure_save_path=model_path + '/' + sub_folder + '/H_visualize', name='H_true_target')
                plotfig.figChan(H_input_sample_target[0,:,:,0], nmse=nmse_input_target[0], title='Raw-estimated Channel Slot 6', index_save=epoch+1, 
                                        figure_save_path=model_path + '/' + sub_folder + '/H_visualize', name='H_input_target')
                # if sub_folder == 'in_15_symbs' or sub_folder == 'FiLM':
                plotfig.figChan(H_input_condition_target[0,:,0,0], title='Condition Channel', index_save=epoch+1, 
                                        figure_save_path=model_path + '/' + sub_folder + '/H_visualize', name='H_input_condition_target')
                flag = 0
            plotfig.figChan(H_est_sample[0,:,:,0], nmse=nmse_est_target[0], title='CNN-refined Channel Slot 6', index_save=epoch+1, 
                                        figure_save_path=model_path + '/' + sub_folder + '/H_visualize', name='H_CNN_target')
            
            H_to_save[f'{epoch+1}_H_true_source'] = H_true_sample
            H_to_save[f'{epoch+1}_H_input_source'] = H_input_sample
            H_to_save[f'{epoch+1}_H_est_source'] = H_est_sample
            H_to_save[f'{epoch+1}_H_input_condition_source'] = H_input_condition
                # don't save nmse_input_source, nmse_est_source because can compute them later
            H_to_save[f'{epoch+1}_domain_sample_return_source'] = domain_sample_return_source
            #
            H_to_save[f'{epoch+1}_H_true_target'] = H_true_sample_target
            H_to_save[f'{epoch+1}_H_input_target'] = H_input_sample_target
            H_to_save[f'{epoch+1}_H_est_target'] = H_est_sample_target
            H_to_save[f'{epoch+1}_H_input_condition_target'] = H_input_condition_target
            H_to_save[f'{epoch+1}_domain_sample_return_target'] = domain_sample_return_target
            
        else:
            _, epoc_val_return = utils_UDA_CNN15.val_step(model, loader_H_eval, loss_fn, lower_range, lambda_domain=lambda_domain)
        
        (
            avg_epoc_total_loss, 
            avg_epoc_val_domain_loss_source, avg_epoc_val_domain_loss_target, avg_epoc_val_domain_loss,
            avg_epoc_val_est_loss_source, avg_epoc_val_est_loss_target, avg_epoc_val_est_loss,
            avg_epoc_source_acc, avg_epoc_target_acc, avg_epoc_acc,
            avg_epoc_nmse_val_source, avg_epoc_nmse_val_target, avg_epoc_nmse_val
        ) = epoc_val_return
        # Average loss for the epoch
        val_est_loss.append(avg_epoc_val_est_loss)
        print(f"epoch {epoch+1}/{n_epochs} (Val) Average Validating Loss: {avg_epoc_val_est_loss:.6f}")
        #
        val_est_loss_source.append(avg_epoc_val_est_loss_source)
        print(f"epoch {epoch+1}/{n_epochs} (Val) Average Estimation Loss (in Source domain): {avg_epoc_val_est_loss_source:.6f}")
        #
        val_loss.append(avg_epoc_total_loss)
        print(f"epoch {epoch+1}/{n_epochs} (Val) Average Domain Discrimination Loss: {avg_epoc_total_loss:.6f}")
        #
        val_est_loss_target.append(avg_epoc_val_est_loss_target)
        print(f"epoch {epoch+1}/{n_epochs} (Val) For observation only - Average Estimation Loss in Target domain: {avg_epoc_val_est_loss_target:.6f}")
        #
        val_domain_loss_source.append(avg_epoc_val_domain_loss_source)
        val_domain_loss_target.append(avg_epoc_val_domain_loss_target)
        val_domain_loss.append(avg_epoc_val_domain_loss)
        source_acc.append(avg_epoc_source_acc)
        target_acc.append(avg_epoc_target_acc)
        acc.append(avg_epoc_acc)
        nmse_val_source.append(avg_epoc_nmse_val_source)
        nmse_val_target.append(avg_epoc_nmse_val_target)
        nmse_val.append(avg_epoc_nmse_val)
        
        
        if (epoch+1>epoch_min and (epoch+1)%epoch_step==0) or epoch==n_epochs-1:
            # Save model
            os.makedirs(f"{model_path}/{sub_folder}/model/", exist_ok=True)
            model.save(f"{model_path}/{sub_folder}/model/epoch_{epoch+1}.keras")
            print(f"Model saved at epoch {epoch+1} to {model_path}/{sub_folder}/epoch_{epoch+1}")    
            
            # === save and overwrite at checkpoints
            # train
            perform_to_save['train_loss'] = train_loss
            perform_to_save['train_est_loss'] = train_est_loss
            perform_to_save['train_domain_loss'] = train_domain_loss
            perform_to_save['train_est_loss_target'] = train_est_loss_target
            # val
            perform_to_save['val_est_loss'] = val_est_loss
            perform_to_save['val_est_loss_source'] = val_est_loss_source
            perform_to_save['val_loss'] = val_loss
            perform_to_save['val_est_loss_target'] = val_est_loss_target
            perform_to_save['val_domain_loss_source'] = val_domain_loss_source
            perform_to_save['val_domain_loss_target'] = val_domain_loss_target
            perform_to_save['val_domain_loss'] = val_domain_loss
            perform_to_save['source_acc'] = source_acc
            perform_to_save['target_acc'] = target_acc
            perform_to_save['acc'] = acc
            perform_to_save['nmse_val_source'] = nmse_val_source
            perform_to_save['nmse_val_target'] = nmse_val_target
            perform_to_save['nmse_val'] = nmse_val
            # save
            os.makedirs(f"{model_path}/{sub_folder}/performance/", exist_ok=True)
            savemat(model_path + '/' + sub_folder + '/performance/performance.mat', perform_to_save)
            
            # Plot figures === save and overwrite at checkpoints
            plotfig.figLoss(line_list=[(nmse_val_source, 'Source Domain'), (nmse_val_target, 'Target Domain')], xlabel='Epoch', ylabel='NMSE',
                        title='NMSE in Validation', index_save=1, figure_save_path= model_path + '/' + sub_folder + '/performance', fig_name='NMSE_val')
            plotfig.figLoss(line_list=[(source_acc, 'Source Domain'), (target_acc, 'Target Domain')], xlabel='Epoch', ylabel='Discrimination Accuracy',
                        title='Domain Discrimination Accuracy in Validation', index_save=1, figure_save_path= model_path + '/' + sub_folder + '/performance', fig_name='Domain_acc')
            #
            plotfig.figLoss(line_list=[(train_loss, 'Training'), (val_loss, 'Validating')], xlabel='Epoch', ylabel='Total Loss',
                        title='Training and Validating Total Loss', index_save=1, figure_save_path= model_path + '/' + sub_folder + '/performance', fig_name='Loss_total')
            plotfig.figLoss(line_list=[(train_est_loss, 'Training-Source'), (train_est_loss_target, 'Training-Target'), 
                                    (val_est_loss_source, 'Validating-Source'), (val_est_loss_target, 'Validating-Target')], xlabel='Epoch', ylabel='Estimation Loss',
                        title='Training and Validating Estimation Loss', index_save=1, figure_save_path= model_path + '/' + sub_folder + '/performance', fig_name='Loss_est')
            plotfig.figLoss(line_list=[(train_domain_loss, 'Training'), (val_domain_loss, 'Validating')], xlabel='Epoch', ylabel='Domain Discrimination Loss',
                        title='Training and Validating Domain Discrimination Loss', index_save=1, figure_save_path= model_path + '/' + sub_folder + '/performance', fig_name='Loss_domain')
            
    # end of epoch loop
    # =====================            
    # Save performances
    # Save H matrix
    savemat(model_path + '/' + sub_folder + '/H_visualize/H_trix.mat', H_to_save)
# Out:
# Processing: in_15_symbs
# I0000 00:00:1748632208.930351  269185 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9539 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:1a:00.0, compute capability: 7.5
# I0000 00:00:1748632208.930950  269185 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 9539 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:67:00.0, compute capability: 7.5
# I0000 00:00:1748632208.931432  269185 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 9264 MB memory:  -> device: 2, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:68:00.0, compute capability: 7.5
# batch_idx: 1/115
# I0000 00:00:1748632212.792090  269185 cuda_dnn.cc:529] Loaded cuDNN version 90300
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 1/70 Average Training Loss: 0.307533
# epoch 1/70 Average Estimation Loss (in Source domain): 0.199087
# epoch 1/70 Average Domain Discrimination Loss: 0.693298
# epoch 1/70 For observation only - Average Estimation Loss in Target domain: 0.198091
# epoch 1/70 (Val) Average Validating Loss: 0.193643
# epoch 1/70 (Val) Average Estimation Loss (in Source domain): 0.192866
# epoch 1/70 (Val) Average Domain Discrimination Loss: 0.304489
# epoch 1/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.194420
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 2/70 Average Training Loss: 0.298485
# epoch 2/70 Average Estimation Loss (in Source domain): 0.180799
# epoch 2/70 Average Domain Discrimination Loss: 0.693617
# epoch 2/70 For observation only - Average Estimation Loss in Target domain: 0.175663
# epoch 2/70 (Val) Average Validating Loss: 0.176394
# epoch 2/70 (Val) Average Estimation Loss (in Source domain): 0.175253
# epoch 2/70 (Val) Average Domain Discrimination Loss: 0.295802
# epoch 2/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.177535
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 3/70 Average Training Loss: 0.293842
# epoch 3/70 Average Estimation Loss (in Source domain): 0.171391
# epoch 3/70 Average Domain Discrimination Loss: 0.693821
# epoch 3/70 For observation only - Average Estimation Loss in Target domain: 0.164479
# epoch 3/70 (Val) Average Validating Loss: 0.167561
# epoch 3/70 (Val) Average Estimation Loss (in Source domain): 0.166068
# epoch 3/70 (Val) Average Domain Discrimination Loss: 0.291235
# epoch 3/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.169053
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 4/70 Average Training Loss: 0.290557
# epoch 4/70 Average Estimation Loss (in Source domain): 0.164759
# epoch 4/70 Average Domain Discrimination Loss: 0.693926
# epoch 4/70 For observation only - Average Estimation Loss in Target domain: 0.157311
# epoch 4/70 (Val) Average Validating Loss: 0.164497
# epoch 4/70 (Val) Average Estimation Loss (in Source domain): 0.163099
# epoch 4/70 (Val) Average Domain Discrimination Loss: 0.289817
# epoch 4/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.165895
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 5/70 Average Training Loss: 0.288058
# epoch 5/70 Average Estimation Loss (in Source domain): 0.159771
# epoch 5/70 Average Domain Discrimination Loss: 0.693907
# epoch 5/70 For observation only - Average Estimation Loss in Target domain: 0.151864
# epoch 5/70 (Val) Average Validating Loss: 0.160269
# epoch 5/70 (Val) Average Estimation Loss (in Source domain): 0.158881
# epoch 5/70 (Val) Average Domain Discrimination Loss: 0.287606
# epoch 5/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.161657
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 6/70 Average Training Loss: 0.286182
# epoch 6/70 Average Estimation Loss (in Source domain): 0.156118
# epoch 6/70 Average Domain Discrimination Loss: 0.693744
# epoch 6/70 For observation only - Average Estimation Loss in Target domain: 0.147765
# epoch 6/70 (Val) Average Validating Loss: 0.156140
# epoch 6/70 (Val) Average Estimation Loss (in Source domain): 0.154492
# epoch 6/70 (Val) Average Domain Discrimination Loss: 0.285382
# epoch 6/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.157788
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 7/70 Average Training Loss: 0.284554
# epoch 7/70 Average Estimation Loss (in Source domain): 0.153091
# epoch 7/70 Average Domain Discrimination Loss: 0.693363
# epoch 7/70 For observation only - Average Estimation Loss in Target domain: 0.144505
# epoch 7/70 (Val) Average Validating Loss: 0.153794
# epoch 7/70 (Val) Average Estimation Loss (in Source domain): 0.152036
# epoch 7/70 (Val) Average Domain Discrimination Loss: 0.284136
# epoch 7/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.155551
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 8/70 Average Training Loss: 0.283262
# epoch 8/70 Average Estimation Loss (in Source domain): 0.150456
# epoch 8/70 Average Domain Discrimination Loss: 0.693446
# epoch 8/70 For observation only - Average Estimation Loss in Target domain: 0.141664
# epoch 8/70 (Val) Average Validating Loss: 0.151628
# epoch 8/70 (Val) Average Estimation Loss (in Source domain): 0.149816
# epoch 8/70 (Val) Average Domain Discrimination Loss: 0.283070
# epoch 8/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.153439
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 9/70 Average Training Loss: 0.282116
# epoch 9/70 Average Estimation Loss (in Source domain): 0.148149
# epoch 9/70 Average Domain Discrimination Loss: 0.693471
# epoch 9/70 For observation only - Average Estimation Loss in Target domain: 0.139140
# epoch 9/70 (Val) Average Validating Loss: 0.149531
# epoch 9/70 (Val) Average Estimation Loss (in Source domain): 0.147828
# epoch 9/70 (Val) Average Domain Discrimination Loss: 0.281943
# epoch 9/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.151233
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 10/70 Average Training Loss: 0.281050
# epoch 10/70 Average Estimation Loss (in Source domain): 0.146121
# epoch 10/70 Average Domain Discrimination Loss: 0.693296
# epoch 10/70 For observation only - Average Estimation Loss in Target domain: 0.136853
# epoch 10/70 (Val) Average Validating Loss: 0.148156
# epoch 10/70 (Val) Average Estimation Loss (in Source domain): 0.146420
# epoch 10/70 (Val) Average Domain Discrimination Loss: 0.281038
# epoch 10/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.149892
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 11/70 Average Training Loss: 0.280058
# epoch 11/70 Average Estimation Loss (in Source domain): 0.144223
# epoch 11/70 Average Domain Discrimination Loss: 0.693156
# epoch 11/70 For observation only - Average Estimation Loss in Target domain: 0.134674
# epoch 11/70 (Val) Average Validating Loss: 0.147124
# epoch 11/70 (Val) Average Estimation Loss (in Source domain): 0.145501
# epoch 11/70 (Val) Average Domain Discrimination Loss: 0.280480
# epoch 11/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.148748
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 12/70 Average Training Loss: 0.279227
# epoch 12/70 Average Estimation Loss (in Source domain): 0.142569
# epoch 12/70 Average Domain Discrimination Loss: 0.693143
# epoch 12/70 For observation only - Average Estimation Loss in Target domain: 0.132846
# epoch 12/70 (Val) Average Validating Loss: 0.145536
# epoch 12/70 (Val) Average Estimation Loss (in Source domain): 0.144030
# epoch 12/70 (Val) Average Domain Discrimination Loss: 0.279780
# epoch 12/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.147042
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 13/70 Average Training Loss: 0.278516
# epoch 13/70 Average Estimation Loss (in Source domain): 0.141095
# epoch 13/70 Average Domain Discrimination Loss: 0.693229
# epoch 13/70 For observation only - Average Estimation Loss in Target domain: 0.131143
# epoch 13/70 (Val) Average Validating Loss: 0.143501
# epoch 13/70 (Val) Average Estimation Loss (in Source domain): 0.142198
# epoch 13/70 (Val) Average Domain Discrimination Loss: 0.278897
# epoch 13/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.144803
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 14/70 Average Training Loss: 0.278041
# epoch 14/70 Average Estimation Loss (in Source domain): 0.140088
# epoch 14/70 Average Domain Discrimination Loss: 0.693322
# epoch 14/70 For observation only - Average Estimation Loss in Target domain: 0.129894
# epoch 14/70 (Val) Average Validating Loss: 0.138996
# epoch 14/70 (Val) Average Estimation Loss (in Source domain): 0.138241
# epoch 14/70 (Val) Average Domain Discrimination Loss: 0.276905
# epoch 14/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.139752
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 15/70 Average Training Loss: 0.277711
# epoch 15/70 Average Estimation Loss (in Source domain): 0.139408
# epoch 15/70 Average Domain Discrimination Loss: 0.693356
# epoch 15/70 For observation only - Average Estimation Loss in Target domain: 0.128661
# epoch 15/70 (Val) Average Validating Loss: 0.133719
# epoch 15/70 (Val) Average Estimation Loss (in Source domain): 0.133322
# epoch 15/70 (Val) Average Domain Discrimination Loss: 0.274421
# epoch 15/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.134117
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 16/70 Average Training Loss: 0.276981
# epoch 16/70 Average Estimation Loss (in Source domain): 0.137995
# epoch 16/70 Average Domain Discrimination Loss: 0.693278
# epoch 16/70 For observation only - Average Estimation Loss in Target domain: 0.126790
# epoch 16/70 (Val) Average Validating Loss: 0.132467
# epoch 16/70 (Val) Average Estimation Loss (in Source domain): 0.131864
# epoch 16/70 (Val) Average Domain Discrimination Loss: 0.273672
# epoch 16/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.133070
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 17/70 Average Training Loss: 0.276297
# epoch 17/70 Average Estimation Loss (in Source domain): 0.136697
# epoch 17/70 Average Domain Discrimination Loss: 0.693163
# epoch 17/70 For observation only - Average Estimation Loss in Target domain: 0.125270
# epoch 17/70 (Val) Average Validating Loss: 0.131445
# epoch 17/70 (Val) Average Estimation Loss (in Source domain): 0.130765
# epoch 17/70 (Val) Average Domain Discrimination Loss: 0.273166
# epoch 17/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.132125
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 18/70 Average Training Loss: 0.275774
# epoch 18/70 Average Estimation Loss (in Source domain): 0.135601
# epoch 18/70 Average Domain Discrimination Loss: 0.693247
# epoch 18/70 For observation only - Average Estimation Loss in Target domain: 0.123985
# epoch 18/70 (Val) Average Validating Loss: 0.130277
# epoch 18/70 (Val) Average Estimation Loss (in Source domain): 0.129592
# epoch 18/70 (Val) Average Domain Discrimination Loss: 0.272690
# epoch 18/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.130961
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 19/70 Average Training Loss: 0.275276
# epoch 19/70 Average Estimation Loss (in Source domain): 0.134460
# epoch 19/70 Average Domain Discrimination Loss: 0.693487
# epoch 19/70 For observation only - Average Estimation Loss in Target domain: 0.122669
# epoch 19/70 (Val) Average Validating Loss: 0.128980
# epoch 19/70 (Val) Average Estimation Loss (in Source domain): 0.128471
# epoch 19/70 (Val) Average Domain Discrimination Loss: 0.272204
# epoch 19/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.129488
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 20/70 Average Training Loss: 0.274847
# epoch 20/70 Average Estimation Loss (in Source domain): 0.133571
# epoch 20/70 Average Domain Discrimination Loss: 0.693538
# epoch 20/70 For observation only - Average Estimation Loss in Target domain: 0.121569
# epoch 20/70 (Val) Average Validating Loss: 0.127603
# epoch 20/70 (Val) Average Estimation Loss (in Source domain): 0.127212
# epoch 20/70 (Val) Average Domain Discrimination Loss: 0.271655
# epoch 20/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.127994
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 21/70 Average Training Loss: 0.274421
# epoch 21/70 Average Estimation Loss (in Source domain): 0.132708
# epoch 21/70 Average Domain Discrimination Loss: 0.693557
# epoch 21/70 For observation only - Average Estimation Loss in Target domain: 0.120514
# epoch 21/70 (Val) Average Validating Loss: 0.126387
# epoch 21/70 (Val) Average Estimation Loss (in Source domain): 0.126100
# epoch 21/70 (Val) Average Domain Discrimination Loss: 0.271188
# epoch 21/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.126674
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 22/70 Average Training Loss: 0.273902
# epoch 22/70 Average Estimation Loss (in Source domain): 0.131731
# epoch 22/70 Average Domain Discrimination Loss: 0.693454
# epoch 22/70 For observation only - Average Estimation Loss in Target domain: 0.119421
# epoch 22/70 (Val) Average Validating Loss: 0.125180
# epoch 22/70 (Val) Average Estimation Loss (in Source domain): 0.125097
# epoch 22/70 (Val) Average Domain Discrimination Loss: 0.270481
# epoch 22/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.125262
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 23/70 Average Training Loss: 0.273346
# epoch 23/70 Average Estimation Loss (in Source domain): 0.130864
# epoch 23/70 Average Domain Discrimination Loss: 0.693045
# epoch 23/70 For observation only - Average Estimation Loss in Target domain: 0.118391
# epoch 23/70 (Val) Average Validating Loss: 0.123493
# epoch 23/70 (Val) Average Estimation Loss (in Source domain): 0.123567
# epoch 23/70 (Val) Average Domain Discrimination Loss: 0.269574
# epoch 23/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.123418
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 24/70 Average Training Loss: 0.272929
# epoch 24/70 Average Estimation Loss (in Source domain): 0.130081
# epoch 24/70 Average Domain Discrimination Loss: 0.692961
# epoch 24/70 For observation only - Average Estimation Loss in Target domain: 0.117465
# epoch 24/70 (Val) Average Validating Loss: 0.122323
# epoch 24/70 (Val) Average Estimation Loss (in Source domain): 0.122535
# epoch 24/70 (Val) Average Domain Discrimination Loss: 0.269192
# epoch 24/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.122111
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 25/70 Average Training Loss: 0.272675
# epoch 25/70 Average Estimation Loss (in Source domain): 0.129311
# epoch 25/70 Average Domain Discrimination Loss: 0.693398
# epoch 25/70 For observation only - Average Estimation Loss in Target domain: 0.116551
# epoch 25/70 (Val) Average Validating Loss: 0.121458
# epoch 25/70 (Val) Average Estimation Loss (in Source domain): 0.121726
# epoch 25/70 (Val) Average Domain Discrimination Loss: 0.269042
# epoch 25/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.121190
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 26/70 Average Training Loss: 0.272376
# epoch 26/70 Average Estimation Loss (in Source domain): 0.128526
# epoch 26/70 Average Domain Discrimination Loss: 0.693710
# epoch 26/70 For observation only - Average Estimation Loss in Target domain: 0.115634
# epoch 26/70 (Val) Average Validating Loss: 0.120730
# epoch 26/70 (Val) Average Estimation Loss (in Source domain): 0.121051
# epoch 26/70 (Val) Average Domain Discrimination Loss: 0.268680
# epoch 26/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.120409
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 27/70 Average Training Loss: 0.271985
# epoch 27/70 Average Estimation Loss (in Source domain): 0.127783
# epoch 27/70 Average Domain Discrimination Loss: 0.693647
# epoch 27/70 For observation only - Average Estimation Loss in Target domain: 0.114788
# epoch 27/70 (Val) Average Validating Loss: 0.119818
# epoch 27/70 (Val) Average Estimation Loss (in Source domain): 0.120266
# epoch 27/70 (Val) Average Domain Discrimination Loss: 0.268208
# epoch 27/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.119369
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 28/70 Average Training Loss: 0.271621
# epoch 28/70 Average Estimation Loss (in Source domain): 0.127119
# epoch 28/70 Average Domain Discrimination Loss: 0.693540
# epoch 28/70 For observation only - Average Estimation Loss in Target domain: 0.113998
# epoch 28/70 (Val) Average Validating Loss: 0.118957
# epoch 28/70 (Val) Average Estimation Loss (in Source domain): 0.119537
# epoch 28/70 (Val) Average Domain Discrimination Loss: 0.267786
# epoch 28/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.118377
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 29/70 Average Training Loss: 0.271296
# epoch 29/70 Average Estimation Loss (in Source domain): 0.126469
# epoch 29/70 Average Domain Discrimination Loss: 0.693540
# epoch 29/70 For observation only - Average Estimation Loss in Target domain: 0.113230
# epoch 29/70 (Val) Average Validating Loss: 0.118212
# epoch 29/70 (Val) Average Estimation Loss (in Source domain): 0.118885
# epoch 29/70 (Val) Average Domain Discrimination Loss: 0.267484
# epoch 29/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.117539
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 30/70 Average Training Loss: 0.270975
# epoch 30/70 Average Estimation Loss (in Source domain): 0.125835
# epoch 30/70 Average Domain Discrimination Loss: 0.693524
# epoch 30/70 For observation only - Average Estimation Loss in Target domain: 0.112486
# epoch 30/70 (Val) Average Validating Loss: 0.117574
# epoch 30/70 (Val) Average Estimation Loss (in Source domain): 0.118355
# epoch 30/70 (Val) Average Domain Discrimination Loss: 0.267216
# epoch 30/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.116793
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 31/70 Average Training Loss: 0.270644
# epoch 31/70 Average Estimation Loss (in Source domain): 0.125179
# epoch 31/70 Average Domain Discrimination Loss: 0.693515
# epoch 31/70 For observation only - Average Estimation Loss in Target domain: 0.111695
# Unpack H_sample and save for visualization
# epoch 31/70 (Val) Average Validating Loss: 0.116932
# epoch 31/70 (Val) Average Estimation Loss (in Source domain): 0.117845
# epoch 31/70 (Val) Average Domain Discrimination Loss: 0.266932
# epoch 31/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.116019
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 32/70 Average Training Loss: 0.270297
# epoch 32/70 Average Estimation Loss (in Source domain): 0.124544
# epoch 32/70 Average Domain Discrimination Loss: 0.693417
# epoch 32/70 For observation only - Average Estimation Loss in Target domain: 0.110954
# epoch 32/70 (Val) Average Validating Loss: 0.116276
# epoch 32/70 (Val) Average Estimation Loss (in Source domain): 0.117309
# epoch 32/70 (Val) Average Domain Discrimination Loss: 0.266610
# epoch 32/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.115242
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 33/70 Average Training Loss: 0.269954
# epoch 33/70 Average Estimation Loss (in Source domain): 0.123987
# epoch 33/70 Average Domain Discrimination Loss: 0.693203
# epoch 33/70 For observation only - Average Estimation Loss in Target domain: 0.110300
# epoch 33/70 (Val) Average Validating Loss: 0.115686
# epoch 33/70 (Val) Average Estimation Loss (in Source domain): 0.116880
# epoch 33/70 (Val) Average Domain Discrimination Loss: 0.266322
# epoch 33/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.114493
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 34/70 Average Training Loss: 0.269628
# epoch 34/70 Average Estimation Loss (in Source domain): 0.123399
# epoch 34/70 Average Domain Discrimination Loss: 0.693095
# epoch 34/70 For observation only - Average Estimation Loss in Target domain: 0.109628
# epoch 34/70 (Val) Average Validating Loss: 0.115243
# epoch 34/70 (Val) Average Estimation Loss (in Source domain): 0.116549
# epoch 34/70 (Val) Average Domain Discrimination Loss: 0.266217
# epoch 34/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.113937
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 35/70 Average Training Loss: 0.269377
# epoch 35/70 Average Estimation Loss (in Source domain): 0.122873
# epoch 35/70 Average Domain Discrimination Loss: 0.693135
# epoch 35/70 For observation only - Average Estimation Loss in Target domain: 0.108997
# epoch 35/70 (Val) Average Validating Loss: 0.114538
# epoch 35/70 (Val) Average Estimation Loss (in Source domain): 0.115903
# epoch 35/70 (Val) Average Domain Discrimination Loss: 0.265967
# epoch 35/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.113173
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 36/70 Average Training Loss: 0.269129
# epoch 36/70 Average Estimation Loss (in Source domain): 0.122340
# epoch 36/70 Average Domain Discrimination Loss: 0.693195
# epoch 36/70 For observation only - Average Estimation Loss in Target domain: 0.108372
# epoch 36/70 (Val) Average Validating Loss: 0.113939
# epoch 36/70 (Val) Average Estimation Loss (in Source domain): 0.115401
# epoch 36/70 (Val) Average Domain Discrimination Loss: 0.265760
# epoch 36/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.112477
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 37/70 Average Training Loss: 0.268904
# epoch 37/70 Average Estimation Loss (in Source domain): 0.121814
# epoch 37/70 Average Domain Discrimination Loss: 0.693323
# epoch 37/70 For observation only - Average Estimation Loss in Target domain: 0.107753
# epoch 37/70 (Val) Average Validating Loss: 0.113340
# epoch 37/70 (Val) Average Estimation Loss (in Source domain): 0.114941
# epoch 37/70 (Val) Average Domain Discrimination Loss: 0.265576
# epoch 37/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.111739
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 38/70 Average Training Loss: 0.268628
# epoch 38/70 Average Estimation Loss (in Source domain): 0.121281
# epoch 38/70 Average Domain Discrimination Loss: 0.693291
# epoch 38/70 For observation only - Average Estimation Loss in Target domain: 0.107123
# epoch 38/70 (Val) Average Validating Loss: 0.112836
# epoch 38/70 (Val) Average Estimation Loss (in Source domain): 0.114530
# epoch 38/70 (Val) Average Domain Discrimination Loss: 0.265300
# epoch 38/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.111142
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 39/70 Average Training Loss: 0.268349
# epoch 39/70 Average Estimation Loss (in Source domain): 0.120804
# epoch 39/70 Average Domain Discrimination Loss: 0.693159
# epoch 39/70 For observation only - Average Estimation Loss in Target domain: 0.106600
# epoch 39/70 (Val) Average Validating Loss: 0.112382
# epoch 39/70 (Val) Average Estimation Loss (in Source domain): 0.114137
# epoch 39/70 (Val) Average Domain Discrimination Loss: 0.265012
# epoch 39/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.110627
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 40/70 Average Training Loss: 0.268092
# epoch 40/70 Average Estimation Loss (in Source domain): 0.120327
# epoch 40/70 Average Domain Discrimination Loss: 0.693093
# epoch 40/70 For observation only - Average Estimation Loss in Target domain: 0.106066
# epoch 40/70 (Val) Average Validating Loss: 0.111705
# epoch 40/70 (Val) Average Estimation Loss (in Source domain): 0.113559
# epoch 40/70 (Val) Average Domain Discrimination Loss: 0.264685
# epoch 40/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.109851
# Model saved at epoch 40 to /home/thien/Code/H_predict_UDA/H_predict_Sionna/Domain_Adaptation/Domain_Adversarial/model/CNN/ver8_/in_15_symbs/epoch_40
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 41/70 Average Training Loss: 0.267850
# epoch 41/70 Average Estimation Loss (in Source domain): 0.119817
# epoch 41/70 Average Domain Discrimination Loss: 0.693138
# epoch 41/70 For observation only - Average Estimation Loss in Target domain: 0.105472
# Unpack H_sample and save for visualization
# epoch 41/70 (Val) Average Validating Loss: 0.111135
# epoch 41/70 (Val) Average Estimation Loss (in Source domain): 0.113056
# epoch 41/70 (Val) Average Domain Discrimination Loss: 0.264449
# epoch 41/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.109214
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 42/70 Average Training Loss: 0.267649
# epoch 42/70 Average Estimation Loss (in Source domain): 0.119352
# epoch 42/70 Average Domain Discrimination Loss: 0.693244
# epoch 42/70 For observation only - Average Estimation Loss in Target domain: 0.104928
# epoch 42/70 (Val) Average Validating Loss: 0.110727
# epoch 42/70 (Val) Average Estimation Loss (in Source domain): 0.112677
# epoch 42/70 (Val) Average Domain Discrimination Loss: 0.264302
# epoch 42/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.108778
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 43/70 Average Training Loss: 0.267450
# epoch 43/70 Average Estimation Loss (in Source domain): 0.118898
# epoch 43/70 Average Domain Discrimination Loss: 0.693335
# epoch 43/70 For observation only - Average Estimation Loss in Target domain: 0.104387
# epoch 43/70 (Val) Average Validating Loss: 0.110202
# epoch 43/70 (Val) Average Estimation Loss (in Source domain): 0.112226
# epoch 43/70 (Val) Average Domain Discrimination Loss: 0.264054
# epoch 43/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.108178
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 44/70 Average Training Loss: 0.267261
# epoch 44/70 Average Estimation Loss (in Source domain): 0.118495
# epoch 44/70 Average Domain Discrimination Loss: 0.693380
# epoch 44/70 For observation only - Average Estimation Loss in Target domain: 0.103915
# epoch 44/70 (Val) Average Validating Loss: 0.109767
# epoch 44/70 (Val) Average Estimation Loss (in Source domain): 0.111922
# epoch 44/70 (Val) Average Domain Discrimination Loss: 0.263888
# epoch 44/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.107611
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 45/70 Average Training Loss: 0.267038
# epoch 45/70 Average Estimation Loss (in Source domain): 0.118062
# epoch 45/70 Average Domain Discrimination Loss: 0.693358
# epoch 45/70 For observation only - Average Estimation Loss in Target domain: 0.103398
# epoch 45/70 (Val) Average Validating Loss: 0.109330
# epoch 45/70 (Val) Average Estimation Loss (in Source domain): 0.111593
# epoch 45/70 (Val) Average Domain Discrimination Loss: 0.263712
# epoch 45/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.107068
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 46/70 Average Training Loss: 0.266804
# epoch 46/70 Average Estimation Loss (in Source domain): 0.117622
# epoch 46/70 Average Domain Discrimination Loss: 0.693310
# epoch 46/70 For observation only - Average Estimation Loss in Target domain: 0.102880
# epoch 46/70 (Val) Average Validating Loss: 0.108888
# epoch 46/70 (Val) Average Estimation Loss (in Source domain): 0.111232
# epoch 46/70 (Val) Average Domain Discrimination Loss: 0.263548
# epoch 46/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.106545
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 47/70 Average Training Loss: 0.266574
# epoch 47/70 Average Estimation Loss (in Source domain): 0.117195
# epoch 47/70 Average Domain Discrimination Loss: 0.693255
# epoch 47/70 For observation only - Average Estimation Loss in Target domain: 0.102359
# epoch 47/70 (Val) Average Validating Loss: 0.108459
# epoch 47/70 (Val) Average Estimation Loss (in Source domain): 0.110911
# epoch 47/70 (Val) Average Domain Discrimination Loss: 0.263407
# epoch 47/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.106006
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 48/70 Average Training Loss: 0.266366
# epoch 48/70 Average Estimation Loss (in Source domain): 0.116807
# epoch 48/70 Average Domain Discrimination Loss: 0.693207
# epoch 48/70 For observation only - Average Estimation Loss in Target domain: 0.101893
# epoch 48/70 (Val) Average Validating Loss: 0.107954
# epoch 48/70 (Val) Average Estimation Loss (in Source domain): 0.110543
# epoch 48/70 (Val) Average Domain Discrimination Loss: 0.263219
# epoch 48/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.105365
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 49/70 Average Training Loss: 0.266176
# epoch 49/70 Average Estimation Loss (in Source domain): 0.116415
# epoch 49/70 Average Domain Discrimination Loss: 0.693228
# epoch 49/70 For observation only - Average Estimation Loss in Target domain: 0.101435
# epoch 49/70 (Val) Average Validating Loss: 0.107617
# epoch 49/70 (Val) Average Estimation Loss (in Source domain): 0.110326
# epoch 49/70 (Val) Average Domain Discrimination Loss: 0.263170
# epoch 49/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.104907
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 50/70 Average Training Loss: 0.265978
# epoch 50/70 Average Estimation Loss (in Source domain): 0.116024
# epoch 50/70 Average Domain Discrimination Loss: 0.693221
# epoch 50/70 For observation only - Average Estimation Loss in Target domain: 0.100966
# epoch 50/70 (Val) Average Validating Loss: 0.107207
# epoch 50/70 (Val) Average Estimation Loss (in Source domain): 0.109990
# epoch 50/70 (Val) Average Domain Discrimination Loss: 0.263051
# epoch 50/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.104423
# Model saved at epoch 50 to /home/thien/Code/H_predict_UDA/H_predict_Sionna/Domain_Adaptation/Domain_Adversarial/model/CNN/ver8_/in_15_symbs/epoch_50
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 51/70 Average Training Loss: 0.265834
# epoch 51/70 Average Estimation Loss (in Source domain): 0.115665
# epoch 51/70 Average Domain Discrimination Loss: 0.693337
# epoch 51/70 For observation only - Average Estimation Loss in Target domain: 0.100544
# Unpack H_sample and save for visualization
# /home/thien/Code/H_predict_UDA/H_predict_Sionna/Est_btween_CSIRS/helper/plotfig.py:50: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(10, 5))
# epoch 51/70 (Val) Average Validating Loss: 0.106881
# epoch 51/70 (Val) Average Estimation Loss (in Source domain): 0.109726
# epoch 51/70 (Val) Average Domain Discrimination Loss: 0.263018
# epoch 51/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.104035
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 52/70 Average Training Loss: 0.265663
# epoch 52/70 Average Estimation Loss (in Source domain): 0.115291
# epoch 52/70 Average Domain Discrimination Loss: 0.693390
# epoch 52/70 For observation only - Average Estimation Loss in Target domain: 0.100106
# epoch 52/70 (Val) Average Validating Loss: 0.106294
# epoch 52/70 (Val) Average Estimation Loss (in Source domain): 0.109235
# epoch 52/70 (Val) Average Domain Discrimination Loss: 0.262721
# epoch 52/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.103353
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 53/70 Average Training Loss: 0.265449
# epoch 53/70 Average Estimation Loss (in Source domain): 0.114902
# epoch 53/70 Average Domain Discrimination Loss: 0.693326
# epoch 53/70 For observation only - Average Estimation Loss in Target domain: 0.099642
# epoch 53/70 (Val) Average Validating Loss: 0.105876
# epoch 53/70 (Val) Average Estimation Loss (in Source domain): 0.108920
# epoch 53/70 (Val) Average Domain Discrimination Loss: 0.262472
# epoch 53/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.102832
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 54/70 Average Training Loss: 0.265255
# epoch 54/70 Average Estimation Loss (in Source domain): 0.114556
# epoch 54/70 Average Domain Discrimination Loss: 0.693255
# epoch 54/70 For observation only - Average Estimation Loss in Target domain: 0.099218
# epoch 54/70 (Val) Average Validating Loss: 0.105484
# epoch 54/70 (Val) Average Estimation Loss (in Source domain): 0.108635
# epoch 54/70 (Val) Average Domain Discrimination Loss: 0.262281
# epoch 54/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.102333
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 55/70 Average Training Loss: 0.265080
# epoch 55/70 Average Estimation Loss (in Source domain): 0.114213
# epoch 55/70 Average Domain Discrimination Loss: 0.693245
# epoch 55/70 For observation only - Average Estimation Loss in Target domain: 0.098803
# epoch 55/70 (Val) Average Validating Loss: 0.105115
# epoch 55/70 (Val) Average Estimation Loss (in Source domain): 0.108355
# epoch 55/70 (Val) Average Domain Discrimination Loss: 0.262128
# epoch 55/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.101875
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 56/70 Average Training Loss: 0.264895
# epoch 56/70 Average Estimation Loss (in Source domain): 0.113888
# epoch 56/70 Average Domain Discrimination Loss: 0.693169
# epoch 56/70 For observation only - Average Estimation Loss in Target domain: 0.098406
# epoch 56/70 (Val) Average Validating Loss: 0.104565
# epoch 56/70 (Val) Average Estimation Loss (in Source domain): 0.107936
# epoch 56/70 (Val) Average Domain Discrimination Loss: 0.261848
# epoch 56/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.101194
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 57/70 Average Training Loss: 0.264675
# epoch 57/70 Average Estimation Loss (in Source domain): 0.113520
# epoch 57/70 Average Domain Discrimination Loss: 0.693052
# epoch 57/70 For observation only - Average Estimation Loss in Target domain: 0.097983
# epoch 57/70 (Val) Average Validating Loss: 0.104230
# epoch 57/70 (Val) Average Estimation Loss (in Source domain): 0.107674
# epoch 57/70 (Val) Average Domain Discrimination Loss: 0.261652
# epoch 57/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.100787
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 58/70 Average Training Loss: 0.264471
# epoch 58/70 Average Estimation Loss (in Source domain): 0.113160
# epoch 58/70 Average Domain Discrimination Loss: 0.692969
# epoch 58/70 For observation only - Average Estimation Loss in Target domain: 0.097560
# epoch 58/70 (Val) Average Validating Loss: 0.103750
# epoch 58/70 (Val) Average Estimation Loss (in Source domain): 0.107330
# epoch 58/70 (Val) Average Domain Discrimination Loss: 0.261457
# epoch 58/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.100171
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 59/70 Average Training Loss: 0.264311
# epoch 59/70 Average Estimation Loss (in Source domain): 0.112848
# epoch 59/70 Average Domain Discrimination Loss: 0.692957
# epoch 59/70 For observation only - Average Estimation Loss in Target domain: 0.097176
# epoch 59/70 (Val) Average Validating Loss: 0.103279
# epoch 59/70 (Val) Average Estimation Loss (in Source domain): 0.106936
# epoch 59/70 (Val) Average Domain Discrimination Loss: 0.261336
# epoch 59/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.099622
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 60/70 Average Training Loss: 0.264175
# epoch 60/70 Average Estimation Loss (in Source domain): 0.112528
# epoch 60/70 Average Domain Discrimination Loss: 0.693036
# epoch 60/70 For observation only - Average Estimation Loss in Target domain: 0.096796
# epoch 60/70 (Val) Average Validating Loss: 0.102919
# epoch 60/70 (Val) Average Estimation Loss (in Source domain): 0.106640
# epoch 60/70 (Val) Average Domain Discrimination Loss: 0.261226
# epoch 60/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.099197
# Model saved at epoch 60 to /home/thien/Code/H_predict_UDA/H_predict_Sionna/Domain_Adaptation/Domain_Adversarial/model/CNN/ver8_/in_15_symbs/epoch_60
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 61/70 Average Training Loss: 0.264018
# epoch 61/70 Average Estimation Loss (in Source domain): 0.112186
# epoch 61/70 Average Domain Discrimination Loss: 0.693081
# epoch 61/70 For observation only - Average Estimation Loss in Target domain: 0.096407
# Unpack H_sample and save for visualization
# epoch 61/70 (Val) Average Validating Loss: 0.102597
# epoch 61/70 (Val) Average Estimation Loss (in Source domain): 0.106395
# epoch 61/70 (Val) Average Domain Discrimination Loss: 0.261114
# epoch 61/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.098798
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 62/70 Average Training Loss: 0.263852
# epoch 62/70 Average Estimation Loss (in Source domain): 0.111862
# epoch 62/70 Average Domain Discrimination Loss: 0.693070
# epoch 62/70 For observation only - Average Estimation Loss in Target domain: 0.096036
# epoch 62/70 (Val) Average Validating Loss: 0.102311
# epoch 62/70 (Val) Average Estimation Loss (in Source domain): 0.106221
# epoch 62/70 (Val) Average Domain Discrimination Loss: 0.261016
# epoch 62/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.098401
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 63/70 Average Training Loss: 0.263701
# epoch 63/70 Average Estimation Loss (in Source domain): 0.111547
# epoch 63/70 Average Domain Discrimination Loss: 0.693091
# epoch 63/70 For observation only - Average Estimation Loss in Target domain: 0.095655
# epoch 63/70 (Val) Average Validating Loss: 0.102035
# epoch 63/70 (Val) Average Estimation Loss (in Source domain): 0.105940
# epoch 63/70 (Val) Average Domain Discrimination Loss: 0.260870
# epoch 63/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.098129
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 64/70 Average Training Loss: 0.263555
# epoch 64/70 Average Estimation Loss (in Source domain): 0.111240
# epoch 64/70 Average Domain Discrimination Loss: 0.693117
# epoch 64/70 For observation only - Average Estimation Loss in Target domain: 0.095303
# epoch 64/70 (Val) Average Validating Loss: 0.101646
# epoch 64/70 (Val) Average Estimation Loss (in Source domain): 0.105621
# epoch 64/70 (Val) Average Domain Discrimination Loss: 0.260677
# epoch 64/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.097670
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 65/70 Average Training Loss: 0.263404
# epoch 65/70 Average Estimation Loss (in Source domain): 0.110927
# epoch 65/70 Average Domain Discrimination Loss: 0.693136
# epoch 65/70 For observation only - Average Estimation Loss in Target domain: 0.094944
# epoch 65/70 (Val) Average Validating Loss: 0.101232
# epoch 65/70 (Val) Average Estimation Loss (in Source domain): 0.105301
# epoch 65/70 (Val) Average Domain Discrimination Loss: 0.260527
# epoch 65/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.097164
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 66/70 Average Training Loss: 0.263265
# epoch 66/70 Average Estimation Loss (in Source domain): 0.110618
# epoch 66/70 Average Domain Discrimination Loss: 0.693188
# epoch 66/70 For observation only - Average Estimation Loss in Target domain: 0.094583
# epoch 66/70 (Val) Average Validating Loss: 0.100897
# epoch 66/70 (Val) Average Estimation Loss (in Source domain): 0.105055
# epoch 66/70 (Val) Average Domain Discrimination Loss: 0.260433
# epoch 66/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.096739
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 67/70 Average Training Loss: 0.263125
# epoch 67/70 Average Estimation Loss (in Source domain): 0.110298
# epoch 67/70 Average Domain Discrimination Loss: 0.693253
# epoch 67/70 For observation only - Average Estimation Loss in Target domain: 0.094210
# epoch 67/70 (Val) Average Validating Loss: 0.100561
# epoch 67/70 (Val) Average Estimation Loss (in Source domain): 0.104781
# epoch 67/70 (Val) Average Domain Discrimination Loss: 0.260322
# epoch 67/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.096340
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 68/70 Average Training Loss: 0.262961
# epoch 68/70 Average Estimation Loss (in Source domain): 0.109991
# epoch 68/70 Average Domain Discrimination Loss: 0.693219
# epoch 68/70 For observation only - Average Estimation Loss in Target domain: 0.093863
# epoch 68/70 (Val) Average Validating Loss: 0.100289
# epoch 68/70 (Val) Average Estimation Loss (in Source domain): 0.104544
# epoch 68/70 (Val) Average Domain Discrimination Loss: 0.260219
# epoch 68/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.096033
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 69/70 Average Training Loss: 0.262815
# epoch 69/70 Average Estimation Loss (in Source domain): 0.109710
# epoch 69/70 Average Domain Discrimination Loss: 0.693200
# epoch 69/70 For observation only - Average Estimation Loss in Target domain: 0.093539
# epoch 69/70 (Val) Average Validating Loss: 0.099832
# epoch 69/70 (Val) Average Estimation Loss (in Source domain): 0.104176
# epoch 69/70 (Val) Average Domain Discrimination Loss: 0.260053
# epoch 69/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.095488
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# epoch 70/70 Average Training Loss: 0.262656
# epoch 70/70 Average Estimation Loss (in Source domain): 0.109396
# epoch 70/70 Average Domain Discrimination Loss: 0.693194
# epoch 70/70 For observation only - Average Estimation Loss in Target domain: 0.093174
# Unpack H_sample and save for visualization
# epoch 70/70 (Val) Average Validating Loss: 0.099466
# epoch 70/70 (Val) Average Estimation Loss (in Source domain): 0.103890
# epoch 70/70 (Val) Average Domain Discrimination Loss: 0.259922
# epoch 70/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.095043
# Model saved at epoch 70 to /home/thien/Code/H_predict_UDA/H_predict_Sionna/Domain_Adaptation/Domain_Adversarial/model/CNN/ver8_/in_15_symbs/epoch_70

# %%
plotfig.figLoss(line_list=[(nmse_val_source[42:], 'Source Domain'), (nmse_val_target[42:], 'Target Domain'), (nmse_val[42:], 'Average')], xlabel='Epoch', ylabel='NMSE',
                        title='NMSE in Validation', index_save=1, fig_show=True, fig_name='NMSE_val')

# %%
plotfig.figLoss(line_list=[(train_domain_loss[42:], 'Source Domain'), (val_domain_loss[42:], 'Target Domain')], xlabel='Epoch', ylabel='Domain Loss',
                        title='Domain Discrimination Loss', index_save=1, fig_show=True)
