# %%
import tensorflow as tf

import os
import sys
import numpy as np
from scipy.io import savemat

# os.environ["CUDA_VISIBLE_DEVICES"] = "1"
sys.path.append(os.path.abspath('helper'))
# import utils
# import loader
import utils_UDA_FiLM, PAD
from utils_UDA_FiLM import UDA_FiLM_Output, train_step_Output
# Out:
# 2025-07-09 11:18:10.494893: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752074290.509301   45095 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752074290.513729   45095 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1752074290.525324   45095 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752074290.525339   45095 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752074290.525340   45095 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752074290.525342   45095 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-07-09 11:18:10.529439: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
notebook_dir = os.getcwd()
print(notebook_dir)
print(os.path.abspath(os.path.join(notebook_dir, '..', '..')))
sys.path.append(os.path.abspath(os.path.join(notebook_dir, '..', '..')))
import Est_btween_CSIRS.helper.utils as utils_CNN
import Est_btween_CSIRS.helper.loader as loader
import Est_btween_CSIRS.helper.plotfig as plotfig
# Out:
# /home/thien/Code/H_predict_UDA/H_predict_Sionna/Domain_Adaptation/Domain_Adversarial
# /home/thien/Code/H_predict_UDA/H_predict_Sionna

# %%
source_data_file_path = os.path.abspath(os.path.join(notebook_dir, '..', '..', 'Generate_Data', 'CDL_Channel', 'generatedChannel', 'ver3_', '0dB', 'mapBaseData.mat'))
target_data_file_path = os.path.abspath(os.path.join(notebook_dir, '..', '..', 'Generate_Data', 'Sionna', 'generatedChannel', 'ver3_', 'sionnaTrue.mat'))

# %%
learning_rate = 0.0001
norm_approach = 'minmax' # can be set to 'std'
lower_range = -1 
    # if norm_approach = 'minmax': 
        # =  0 for scaling to  [0 1]
        # = -1 for scaling to [-1 1]
    # if norm_approach = 'std': can be any value, but need to be defined
    
# snr_start = -25
# snr_step = 5
# snr_end = 25
# SNR = np.arange(snr_start, snr_end+1, snr_step)

# SNR = np.array([0])

# if len(SNR) >1:
#     SNR_txt = f'{snr_start}:{snr_step}:{snr_end}'
# else:
#     SNR_txt = f'{SNR[0]}'
    
# ============ CNN settings ==============
if norm_approach == 'minmax':
    if lower_range == 0:
        norm_txt = 'Using min-max [0 1]'
    elif lower_range ==-1:
        norm_txt = 'Using min-max [-1 1]'
elif norm_approach == 'no':
    norm_txt = 'No'
    
CNN_activation = 'Tanh'
CNN_DropOut = 0.2
if CNN_DropOut != 0:
    dropOut_txt = f'Add p={CNN_DropOut} DropOut'
    
# ============ Adversarial for Domain Discriminator settings ==============
domain_disc = 'hybrid' # 'dense' or 'conv' or 'hybrid'
first_layer_disc = 'pool' # 'flatten' or 'pool' - only matters when domain_disc = 'dense'
                            # note: flatten may cause exhausted memory 
extract_layer = 3  # extract features after convelution layer 3 
# extract_layer = 5
lambda_domain=0.1
lambda_domain_cond = 0.1
text_lambda = f'lambda_domain = {lambda_domain}'
    
    
# create readme.txt file
content = f"""Generated by file 'Domain_Adversarial/UDA_CNN_v3_1.ipynb'.
28 GHz fc,
Source dataset got from {source_data_file_path},
Target dataset got from {target_data_file_path},
Learning rate {learning_rate},
{norm_txt} scaler for each sample
Using {CNN_activation} as activation function of CNN
{dropOut_txt}
========= For Domain Discriminator ==========
Extract features after layer {extract_layer} of CNN
{text_lambda}
"""

# %%
# Paths to save
idx_save_path = loader.find_incremental_filename(notebook_dir + '/model/CNN','ver', '_', '')

model_path = notebook_dir + '/model/CNN/ver' + str(idx_save_path) + '_'
# figure_path = notebook_dir + '/model/CNN/ver' + str(idx_save_path) + '_/figure'
model_readme = model_path + '/readme.txt'
# figure_readme = figure_path + '/readme.txt'

# if not os.path.exists(os.path.dirname(model_readme)):
#     os.makedirs(os.path.dirname(model_readme))
# # if not os.path.exists(os.path.dirname(figure_readme)):
# #     os.makedirs(os.path.dirname(figure_readme))

# # Open the file in write mode ('w'). If the file does not exist, it will be created.
# with open(model_readme, 'w') as file:
#     # Write the content to the file
#     file.write(content)

# # with open(figure_readme, 'w') as file:
# #     # Write the content to the file
# #     file.write(content)

# print(f"File '{model_readme}'  created and content written.")

# %%
import h5py

batch_size=16

# ============ Source data ==============
source_file = h5py.File(source_data_file_path, 'r')
H_true_source = source_file['H_true']
N_samp_source = H_true_source.shape[0]
print('N_samp_source = ', N_samp_source)

# ============ Target data ==============
target_file = h5py.File(target_data_file_path, 'r')
H_true_target = target_file['H_true']
N_samp_target = H_true_target.shape[0]
print('N_samp_target = ', N_samp_target)
# Out:
# N_samp_source =  2048
# N_samp_target =  2048

# %%
indices_source = np.arange(N_samp_source)
np.random.shuffle(indices_source)
indices_target = np.arange(N_samp_target)
np.random.shuffle(indices_target)
#
train_size = int(np.floor(N_samp_source * 0.9) // batch_size * batch_size)
val_size = N_samp_source - train_size

# Repeat the indices to match the maximum number of samples
N_samp = max(N_samp_source, N_samp_target) 
indices_source = np.resize(indices_source, N_samp)
indices_target = np.resize(indices_target, N_samp)

# =======================================================
## Divide the indices into training and validation sets
indices_train_source = indices_source[:train_size]
indices_val_source   = indices_source[train_size:train_size + val_size]

indices_train_target = indices_target[:train_size]
indices_val_target   = indices_target[train_size:train_size + val_size]

# to test code
# indices_train_source = indices_source[:96]
# indices_val_source = indices_source[2032:]
# indices_train_target = indices_target[:96]
# indices_val_target = indices_target[2032:]

print('train_size = ', indices_train_source.shape[0])
print('val_size = ', indices_val_source.shape[0])
# Out:
# train_size =  1840
# val_size =  208

# %%
# =========== Source dataset ==============
loader_H_true_train_source = utils_CNN.H5BatchLoader(source_file, dataset_name='H_true', batch_size=batch_size, shuffled_indices=indices_train_source)
loader_H_1_6_11_train_source = utils_CNN.H5BatchLoader(source_file, 'H_linear_1_6_11', batch_size=batch_size, shuffled_indices=indices_train_source)
    # channel at symbol 2 of slots 1,6,11 (channel corresponding to CSI-RS 1, 2, 3)
loader_H_true_val_source = utils_CNN.H5BatchLoader(source_file, dataset_name='H_true', batch_size=batch_size, shuffled_indices=indices_val_source)
loader_H_1_6_11_val_source = utils_CNN.H5BatchLoader(source_file, 'H_linear_1_6_11', batch_size=batch_size, shuffled_indices=indices_val_source)

# =========== Target dataset ==============
loader_H_true_train_target = utils_CNN.H5BatchLoader(target_file, dataset_name='H_true', batch_size=batch_size, shuffled_indices=indices_train_target)
    # actually at target domain, we don't have true channels, just use this for evaluating the model
loader_H_1_6_11_train_target = utils_CNN.H5BatchLoader(target_file, 'H_linear_1_6', batch_size=batch_size, shuffled_indices=indices_train_target)
    # channel at symbol 2 of slots 1,6,11 (channel corresponding to CSI-RS 1, 2)
loader_H_true_val_target = utils_CNN.H5BatchLoader(target_file, dataset_name='H_true', batch_size=batch_size, shuffled_indices=indices_val_target)
loader_H_1_6_11_val_target = utils_CNN.H5BatchLoader(target_file, 'H_linear_1_6', batch_size=batch_size, shuffled_indices=indices_val_target)

print('size loader_H_true_train = ', loader_H_true_train_target.total_batches)
print('size loader_H_true_val = ', loader_H_true_val_target.total_batches)
# Out:
# size loader_H_true_train =  115
# size loader_H_true_val =  13

# %%
pad = PAD.original_PAD(loader_H_1_6_11_train_source, loader_H_1_6_11_train_target)
print(f"PAD = {pad:.4f}")
# Out:
# X shape =  (3680, 3168)
# X1 shape =  (1840, 3168) y1 shape =  (1840,)
# (1840, 3168) (1840,)
# C: 0.01, Error rate: 0.0255
# C: 0.1, Error rate: 0.0250
# C: 0.5, Error rate: 0.0234
# C: 1.0, Error rate: 0.0228
# C: 2.0, Error rate: 0.0125
# C: 5.0, Error rate: 0.0027
# C: 10.0, Error rate: 0.0022
# C: 50.0, Error rate: 0.0016
# C: 100.0, Error rate: 0.0016
# C: 500.0, Error rate: 0.0016
# C: 1000.0, Error rate: 0.0016
# Best C: 50.0, Best error rate: 0.0016
# PAD = 1.9935
# PAD = 1.9935

# %%
loss_fn_ce = tf.keras.losses.MeanSquaredError()  # Channel estimation loss
loss_fn_domain = tf.keras.losses.BinaryCrossentropy()  # Domain classification loss

# %%
from tensorflow.keras import optimizers, losses
import time
start = time.perf_counter()

n_epochs= 25 # n_epochs= 70
epoch_min = 30
epoch_step = 10
# n_epochs= 2
# epoch_min = 0
# epoch_step = 1

train_mode = ['FiLM']

for sub_folder in train_mode:
    print(f"Processing: {sub_folder}")
    
    if not os.path.exists(os.path.dirname(model_path + '/' + sub_folder +'/')):
        os.makedirs(os.path.dirname(model_path + '/' + sub_folder + '/'))

    train_loss          = [] # (epoch,1)
    train_est_loss      = [] 
    train_domain_loss   = []
    train_est_loss_target = []
    #    
    val_loss, val_domain_loss_source, val_domain_loss_target, val_domain_loss,\
    val_est_loss_source, val_est_loss_target, val_est_loss,\
    source_acc, target_acc, acc,\
    nmse_val_source, nmse_val_target, nmse_val = [[] for _ in range(13)]
    #
    H_to_save = {}          # list to save to .mat file for H
    perform_to_save = {}    # list to save to .mat file for nmse, losses,...

    model = utils_UDA_FiLM.UDA_FiLM(domain_disc = domain_disc, extract_layer=extract_layer, first_layer_disc=first_layer_disc)
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    
    flag = 1 # flag to plot and save H_true
    pad = []
    epoc_pad = []
    for epoch in range(n_epochs):
        # ===================== Training =====================
        loader_H_true_train_source.reset()
        loader_H_1_6_11_train_source.reset()
        loader_H_true_train_target.reset()
        loader_H_1_6_11_train_target.reset()
                
        loader_H = [loader_H_1_6_11_train_source, loader_H_true_train_source, loader_H_1_6_11_train_target, loader_H_true_train_target]
        loss_fn = [loss_fn_ce, loss_fn_domain, optimizer]
        ##########################
        if epoch in [int((n_epochs) * r) for r in [0.49, 0.99]]:  # [0.25, 0.5, 0.75, 0.99]]
            return_features = True
            epoc_pad.append(epoch)
        else:
            return_features = False
        # return_features = True
        ##########################
        train_step_output = utils_UDA_FiLM.train_step(model, loader_H, loss_fn, lower_range,
                                lambda_domain=lambda_domain, return_features=return_features)
        train_epoc_loss_est        = train_step_output.avg_epoc_loss_est
        train_epoc_loss_domain     = train_step_output.avg_epoc_loss_domain
        train_epoc_loss            = train_step_output.avg_epoc_loss
        train_epoc_loss_est_target = train_step_output.avg_epoc_loss_est_target
                # train_epoc_loss        = total train loss = loss_est + lambda_domain * domain_loss
                # train_epoc_loss_est    = loss in estimation network in source domain (labels available)
                # train_epoc_loss_domain = loss in domain discrimination network
                # train_epoc_loss_est_target - just to monitor - the machine can not calculate because no label available in source domain
                # All are already calculated in average over training dataset (source/target - respectively)
        # Calculate PAD for the extracted features
        print("Time", time.perf_counter() - start, "seconds")
        if return_features:
            features_source_file = "features_source.h5"
            features_target_file = "features_target.h5"
            print(f"epoch {epoch+1}/{n_epochs}")
            # pad_epoc_sgd  = PAD.cal_PAD_SGD(features_source_file, features_target_file)
            pad_epoc  = PAD.cal_PAD2(features_source_file, features_target_file, pca_components=50, batch_size=256)
            pad.append(pad_epoc)
            if os.path.exists(features_source_file):
                os.remove(features_source_file)
            if os.path.exists(features_target_file):
                os.remove(features_target_file)
            print("Time", time.perf_counter() - start, "seconds")
            
        
        # Average loss for the epoch
        train_loss.append(train_epoc_loss)
        print(f"epoch {epoch+1}/{n_epochs} Average Training Loss: {train_epoc_loss:.6f}")
        #
        train_est_loss.append(train_epoc_loss_est)
        print(f"epoch {epoch+1}/{n_epochs} Average Estimation Loss (in Source domain): {train_epoc_loss_est:.6f}")
        #
        train_domain_loss.append(train_epoc_loss_domain)
        print(f"epoch {epoch+1}/{n_epochs} Average Domain Discrimination Loss: {train_epoc_loss_domain:.6f}")
        #
        train_est_loss_target.append(train_epoc_loss_est_target)
        print(f"epoch {epoch+1}/{n_epochs} For observation only - Average Estimation Loss in Target domain: {train_epoc_loss_est_target:.6f}")
        
        
        # ===================== Evaluation =====================
        loader_H_true_val_source.reset()
        loader_H_1_6_11_val_source.reset()
        loader_H_true_val_target.reset()
        loader_H_1_6_11_val_target.reset()
        loader_H_eval = [loader_H_1_6_11_val_source, loader_H_true_val_source, loader_H_1_6_11_val_target, loader_H_true_val_target]

        loss_fn = loss_fn_ce, loss_fn_domain
        
        eval_func = utils_UDA_FiLM.val_step
        if (epoch+1>epoch_min and epoch%epoch_step==0) or epoch==n_epochs-1:
            H_sample, epoc_val_return = utils_UDA_FiLM.val_step(model, loader_H_eval, loss_fn, lower_range, epoch=epoch, lambda_domain=lambda_domain)
            print('Unpack H_sample and save for visualization')
            (
                H_true_sample,  H_input_sample, H_est_sample, H_input_condition, 
                nmse_input_source, nmse_est_source, domain_sample_return_source,
                H_true_sample_target, H_input_sample_target, H_est_sample_target, H_input_condition_target,
                nmse_input_target, nmse_est_target, domain_sample_return_target
            ) = H_sample
            
            # plot real parts
            # source domain
            if flag == 1:
                plotfig.figChan(H_true_sample[0,:,:,0], title='True channel Slot 6', index_save=epoch+1, 
                                        figure_save_path=model_path + '/' + sub_folder + '/H_visualize', name='H_true_source')
                plotfig.figChan(H_input_sample[0,:,:,0], nmse=nmse_input_source[0], title='Raw-estimated Channel Slot 6', index_save=epoch+1, 
                                        figure_save_path=model_path + '/' + sub_folder + '/H_visualize', name='H_input_source')
                # if sub_folder == 'in_15_symbs' or sub_folder == 'FiLM':
                plotfig.figChan(H_input_condition[0,:,0,0], title='Condition Channel', index_save=epoch+1, 
                                        figure_save_path=model_path + '/' + sub_folder + '/H_visualize', name='H_input_condition_source')
            plotfig.figChan(H_est_sample[0,:,:,0], nmse=nmse_est_source[0], title='CNN-refined Channel Slot 6', index_save=epoch+1, 
                                        figure_save_path=model_path + '/' + sub_folder + '/H_visualize', name='H_CNN_source')
            # target domain
            if flag == 1:
                plotfig.figChan(H_true_sample_target[0,:,:,0], title='True channel Slot 6', index_save=epoch+1, 
                                        figure_save_path=model_path + '/' + sub_folder + '/H_visualize', name='H_true_target')
                plotfig.figChan(H_input_sample_target[0,:,:,0], nmse=nmse_input_target[0], title='Raw-estimated Channel Slot 6', index_save=epoch+1, 
                                        figure_save_path=model_path + '/' + sub_folder + '/H_visualize', name='H_input_target')
                # if sub_folder == 'in_15_symbs' or sub_folder == 'FiLM':
                plotfig.figChan(H_input_condition_target[0,:,0,0], title='Condition Channel', index_save=epoch+1, 
                                        figure_save_path=model_path + '/' + sub_folder + '/H_visualize', name='H_input_condition_target')
                flag = 0
            plotfig.figChan(H_est_sample[0,:,:,0], nmse=nmse_est_target[0], title='CNN-refined Channel Slot 6', index_save=epoch+1, 
                                        figure_save_path=model_path + '/' + sub_folder + '/H_visualize', name='H_CNN_target')
            
            H_to_save[f'{epoch+1}_H_true_source'] = H_true_sample
            H_to_save[f'{epoch+1}_H_input_source'] = H_input_sample
            H_to_save[f'{epoch+1}_H_est_source'] = H_est_sample
            H_to_save[f'{epoch+1}_H_input_condition_source'] = H_input_condition
                # don't save nmse_input_source, nmse_est_source because can compute them later
            H_to_save[f'{epoch+1}_domain_sample_return_source'] = domain_sample_return_source
            #
            H_to_save[f'{epoch+1}_H_true_target'] = H_true_sample_target
            H_to_save[f'{epoch+1}_H_input_target'] = H_input_sample_target
            H_to_save[f'{epoch+1}_H_est_target'] = H_est_sample_target
            H_to_save[f'{epoch+1}_H_input_condition_target'] = H_input_condition_target
            H_to_save[f'{epoch+1}_domain_sample_return_target'] = domain_sample_return_target
            
        else:
            _, epoc_val_return = utils_UDA_FiLM.val_step(model, loader_H_eval, loss_fn, lower_range, lambda_domain=lambda_domain)
        
        (
            avg_epoc_total_loss, 
            avg_epoc_val_domain_loss_source, avg_epoc_val_domain_loss_target, avg_epoc_val_domain_loss,
            avg_epoc_val_est_loss_source, avg_epoc_val_est_loss_target, avg_epoc_val_est_loss,
            avg_epoc_source_acc, avg_epoc_target_acc, avg_epoc_acc,
            avg_epoc_nmse_val_source, avg_epoc_nmse_val_target, avg_epoc_nmse_val
        ) = epoc_val_return
        # Average loss for the epoch
        val_est_loss.append(avg_epoc_val_est_loss)
        print(f"epoch {epoch+1}/{n_epochs} (Val) Average Validating Loss: {avg_epoc_val_est_loss:.6f}")
        #
        val_est_loss_source.append(avg_epoc_val_est_loss_source)
        print(f"epoch {epoch+1}/{n_epochs} (Val) Average Estimation Loss (in Source domain): {avg_epoc_val_est_loss_source:.6f}")
        #
        val_loss.append(avg_epoc_total_loss)
        print(f"epoch {epoch+1}/{n_epochs} (Val) Average Domain Discrimination Loss: {avg_epoc_total_loss:.6f}")
        #
        val_est_loss_target.append(avg_epoc_val_est_loss_target)
        print(f"epoch {epoch+1}/{n_epochs} (Val) For observation only - Average Estimation Loss in Target domain: {avg_epoc_val_est_loss_target:.6f}")
        #
        val_domain_loss_source.append(avg_epoc_val_domain_loss_source)
        val_domain_loss_target.append(avg_epoc_val_domain_loss_target)
        val_domain_loss.append(avg_epoc_val_domain_loss)
        source_acc.append(avg_epoc_source_acc)
        target_acc.append(avg_epoc_target_acc)
        acc.append(avg_epoc_acc)
        nmse_val_source.append(avg_epoc_nmse_val_source)
        nmse_val_target.append(avg_epoc_nmse_val_target)
        nmse_val.append(avg_epoc_nmse_val)
        
        
        if (epoch+1>epoch_min and (epoch+1)%epoch_step==0) or epoch==n_epochs-1:
            # Save model
            os.makedirs(f"{model_path}/{sub_folder}/model/", exist_ok=True)
            model.save(f"{model_path}/{sub_folder}/model/epoch_{epoch+1}.keras")
            print(f"Model saved at epoch {epoch+1} to {model_path}/{sub_folder}/epoch_{epoch+1}")    
            
            # === save and overwrite at checkpoints
            # train
            perform_to_save['train_loss'] = train_loss
            perform_to_save['train_est_loss'] = train_est_loss
            perform_to_save['train_domain_loss'] = train_domain_loss
            perform_to_save['train_est_loss_target'] = train_est_loss_target
            # val
            perform_to_save['val_est_loss'] = val_est_loss
            perform_to_save['val_est_loss_source'] = val_est_loss_source
            perform_to_save['val_loss'] = val_loss
            perform_to_save['val_est_loss_target'] = val_est_loss_target
            perform_to_save['val_domain_loss_source'] = val_domain_loss_source
            perform_to_save['val_domain_loss_target'] = val_domain_loss_target
            perform_to_save['val_domain_loss'] = val_domain_loss
            perform_to_save['source_acc'] = source_acc
            perform_to_save['target_acc'] = target_acc
            perform_to_save['acc'] = acc
            perform_to_save['nmse_val_source'] = nmse_val_source
            perform_to_save['nmse_val_target'] = nmse_val_target
            perform_to_save['nmse_val'] = nmse_val
            #
            perform_to_save['pad'] = pad
            perform_to_save['epoc_pad'] = epoc_pad
            
            # save
            os.makedirs(f"{model_path}/{sub_folder}/performance/", exist_ok=True)
            savemat(model_path + '/' + sub_folder + '/performance/performance.mat', perform_to_save)
            
            # Plot figures === save and overwrite at checkpoints
            plotfig.figLoss(line_list=[(nmse_val_source, 'Source Domain'), (nmse_val_target, 'Target Domain')], xlabel='Epoch', ylabel='NMSE',
                        title='NMSE in Validation', index_save=1, figure_save_path= model_path + '/' + sub_folder + '/performance', fig_name='NMSE_val')
            plotfig.figLoss(line_list=[(source_acc, 'Source Domain'), (target_acc, 'Target Domain')], xlabel='Epoch', ylabel='Discrimination Accuracy',
                        title='Domain Discrimination Accuracy in Validation', index_save=1, figure_save_path= model_path + '/' + sub_folder + '/performance', fig_name='Domain_acc')
            #
            plotfig.figLoss(line_list=[(train_loss, 'Training'), (val_loss, 'Validating')], xlabel='Epoch', ylabel='Total Loss',
                        title='Training and Validating Total Loss', index_save=1, figure_save_path= model_path + '/' + sub_folder + '/performance', fig_name='Loss_total')
            plotfig.figLoss(line_list=[(train_est_loss, 'Training-Source'), (train_est_loss_target, 'Training-Target'), 
                                    (val_est_loss_source, 'Validating-Source'), (val_est_loss_target, 'Validating-Target')], xlabel='Epoch', ylabel='Estimation Loss',
                        title='Training and Validating Estimation Loss', index_save=1, figure_save_path= model_path + '/' + sub_folder + '/performance', fig_name='Loss_est')
            plotfig.figLoss(line_list=[(train_domain_loss, 'Training'), (val_domain_loss, 'Validating')], xlabel='Epoch', ylabel='Domain Discrimination Loss',
                        title='Training and Validating Domain Discrimination Loss', index_save=1, figure_save_path= model_path + '/' + sub_folder + '/performance', fig_name='Loss_domain')
            
    # end of epoch loop
    # =====================            
    # Save performances
    # Save H matrix
    savemat(model_path + '/' + sub_folder + '/H_visualize/H_trix.mat', H_to_save)
# Out:
# Processing: FiLM
# I0000 00:00:1752074357.028618   45095 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9548 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:1a:00.0, compute capability: 7.5
# I0000 00:00:1752074357.029199   45095 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 9548 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:67:00.0, compute capability: 7.5
# I0000 00:00:1752074357.029670   45095 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 9484 MB memory:  -> device: 2, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:68:00.0, compute capability: 7.5
# batch_idx: 1/115
# /home/thien/miniconda3/envs/TF_py311/lib/python3.11/site-packages/keras/src/layers/layer.py:396: UserWarning: `build()` was called on layer 'domain_discriminator2', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /home/thien/miniconda3/envs/TF_py311/lib/python3.11/site-packages/keras/src/layers/layer.py:396: UserWarning: `build()` was called on layer 'domain_discriminator', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# I0000 00:00:1752074360.882676   45095 cuda_dnn.cc:529] Loaded cuDNN version 90300
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 111.59936420200393 seconds
# epoch 1/25 Average Training Loss: 0.153329
# epoch 1/25 Average Estimation Loss (in Source domain): 0.206850
# epoch 1/25 Average Domain Discrimination Loss: 0.415770
# epoch 1/25 For observation only - Average Estimation Loss in Target domain: 0.206312
# epoch 1/25 (Val) Average Validating Loss: 0.211433
# epoch 1/25 (Val) Average Estimation Loss (in Source domain): 0.181958
# epoch 1/25 (Val) Average Domain Discrimination Loss: 0.110379
# epoch 1/25 (Val) For observation only - Average Estimation Loss in Target domain: 0.240908
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 222.37370858492795 seconds
# epoch 2/25 Average Training Loss: 0.108822
# epoch 2/25 Average Estimation Loss (in Source domain): 0.179210
# epoch 2/25 Average Domain Discrimination Loss: 0.179185
# epoch 2/25 For observation only - Average Estimation Loss in Target domain: 0.307016
# epoch 2/25 (Val) Average Validating Loss: 0.271501
# epoch 2/25 (Val) Average Estimation Loss (in Source domain): 0.174979
# epoch 2/25 (Val) Average Domain Discrimination Loss: 0.107386
# epoch 2/25 (Val) For observation only - Average Estimation Loss in Target domain: 0.368022
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 333.39955827593803 seconds
# epoch 3/25 Average Training Loss: 0.108038
# epoch 3/25 Average Estimation Loss (in Source domain): 0.175468
# epoch 3/25 Average Domain Discrimination Loss: 0.195952
# epoch 3/25 For observation only - Average Estimation Loss in Target domain: 0.378527
# epoch 3/25 (Val) Average Validating Loss: 0.277541
# epoch 3/25 (Val) Average Estimation Loss (in Source domain): 0.173319
# epoch 3/25 (Val) Average Domain Discrimination Loss: 0.105666
# epoch 3/25 (Val) For observation only - Average Estimation Loss in Target domain: 0.381763
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 444.35565774398856 seconds
# epoch 4/25 Average Training Loss: 0.105862
# epoch 4/25 Average Estimation Loss (in Source domain): 0.173661
# epoch 4/25 Average Domain Discrimination Loss: 0.186127
# epoch 4/25 For observation only - Average Estimation Loss in Target domain: 0.384350
# epoch 4/25 (Val) Average Validating Loss: 0.284868
# epoch 4/25 (Val) Average Estimation Loss (in Source domain): 0.172359
# epoch 4/25 (Val) Average Domain Discrimination Loss: 0.105255
# epoch 4/25 (Val) For observation only - Average Estimation Loss in Target domain: 0.397377
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 555.349316191976 seconds
# epoch 5/25 Average Training Loss: 0.105341
# epoch 5/25 Average Estimation Loss (in Source domain): 0.171921
# epoch 5/25 Average Domain Discrimination Loss: 0.183677
# epoch 5/25 For observation only - Average Estimation Loss in Target domain: 0.409281
# epoch 5/25 (Val) Average Validating Loss: 0.298986
# epoch 5/25 (Val) Average Estimation Loss (in Source domain): 0.183590
# epoch 5/25 (Val) Average Domain Discrimination Loss: 0.108031
# epoch 5/25 (Val) For observation only - Average Estimation Loss in Target domain: 0.414381
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 666.1480226540007 seconds
# epoch 6/25 Average Training Loss: 0.102799
# epoch 6/25 Average Estimation Loss (in Source domain): 0.170780
# epoch 6/25 Average Domain Discrimination Loss: 0.162553
# epoch 6/25 For observation only - Average Estimation Loss in Target domain: 0.429960
# epoch 6/25 (Val) Average Validating Loss: 0.306974
# epoch 6/25 (Val) Average Estimation Loss (in Source domain): 0.180240
# epoch 6/25 (Val) Average Domain Discrimination Loss: 0.104909
# epoch 6/25 (Val) For observation only - Average Estimation Loss in Target domain: 0.433708
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 777.0504658300197 seconds
# epoch 7/25 Average Training Loss: 0.097241
# epoch 7/25 Average Estimation Loss (in Source domain): 0.170142
# epoch 7/25 Average Domain Discrimination Loss: 0.112149
# epoch 7/25 For observation only - Average Estimation Loss in Target domain: 0.441973
# epoch 7/25 (Val) Average Validating Loss: 0.310250
# epoch 7/25 (Val) Average Estimation Loss (in Source domain): 0.178897
# epoch 7/25 (Val) Average Domain Discrimination Loss: 0.100881
# epoch 7/25 (Val) For observation only - Average Estimation Loss in Target domain: 0.441604
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 887.9882032609312 seconds
# epoch 8/25 Average Training Loss: 0.092853
# epoch 8/25 Average Estimation Loss (in Source domain): 0.169096
# epoch 8/25 Average Domain Discrimination Loss: 0.075214
# epoch 8/25 For observation only - Average Estimation Loss in Target domain: 0.446689
# epoch 8/25 (Val) Average Validating Loss: 0.311144
# epoch 8/25 (Val) Average Estimation Loss (in Source domain): 0.179085
# epoch 8/25 (Val) Average Domain Discrimination Loss: 0.099335
# epoch 8/25 (Val) For observation only - Average Estimation Loss in Target domain: 0.443204
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 999.137678882922 seconds
# epoch 9/25 Average Training Loss: 0.094002
# epoch 9/25 Average Estimation Loss (in Source domain): 0.168058
# epoch 9/25 Average Domain Discrimination Loss: 0.061017
# epoch 9/25 For observation only - Average Estimation Loss in Target domain: 0.445558
# epoch 9/25 (Val) Average Validating Loss: 0.312493
# epoch 9/25 (Val) Average Estimation Loss (in Source domain): 0.181740
# epoch 9/25 (Val) Average Domain Discrimination Loss: 0.100038
# epoch 9/25 (Val) For observation only - Average Estimation Loss in Target domain: 0.443246
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 1110.3438032019185 seconds
# epoch 10/25 Average Training Loss: 0.096697
# epoch 10/25 Average Estimation Loss (in Source domain): 0.166776
# epoch 10/25 Average Domain Discrimination Loss: 0.062721
# epoch 10/25 For observation only - Average Estimation Loss in Target domain: 0.438291
# epoch 10/25 (Val) Average Validating Loss: 0.308154
# epoch 10/25 (Val) Average Estimation Loss (in Source domain): 0.181859
# epoch 10/25 (Val) Average Domain Discrimination Loss: 0.102882
# epoch 10/25 (Val) For observation only - Average Estimation Loss in Target domain: 0.434449
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 1221.5317283839686 seconds
# epoch 11/25 Average Training Loss: 0.092828
# epoch 11/25 Average Estimation Loss (in Source domain): 0.166132
# epoch 11/25 Average Domain Discrimination Loss: 0.085985
# epoch 11/25 For observation only - Average Estimation Loss in Target domain: 0.433927
# epoch 11/25 (Val) Average Validating Loss: 0.322482
# epoch 11/25 (Val) Average Estimation Loss (in Source domain): 0.182674
# epoch 11/25 (Val) Average Domain Discrimination Loss: 0.107809
# epoch 11/25 (Val) For observation only - Average Estimation Loss in Target domain: 0.462290
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 1332.5908830099506 seconds
# epoch 12/25 Average Training Loss: 0.103605
# epoch 12/25 Average Estimation Loss (in Source domain): 0.166731
# epoch 12/25 Average Domain Discrimination Loss: 0.202341
# epoch 12/25 For observation only - Average Estimation Loss in Target domain: 0.423008
# epoch 12/25 (Val) Average Validating Loss: 0.290665
# epoch 12/25 (Val) Average Estimation Loss (in Source domain): 0.172884
# epoch 12/25 (Val) Average Domain Discrimination Loss: 0.098387
# epoch 12/25 (Val) For observation only - Average Estimation Loss in Target domain: 0.408446
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 1479.7346370059531 seconds
# epoch 13/25
# Fitting IncrementalPCA on batches from features_source.h5 and features_target.h5
# Fitted PCA on batch: source 256/1840, target 256/1840
# Fitted PCA on batch: source 512/1840, target 512/1840
# Fitted PCA on batch: source 768/1840, target 768/1840
# Fitted PCA on batch: source 1024/1840, target 1024/1840
# Fitted PCA on batch: source 1280/1840, target 1280/1840
# Fitted PCA on batch: source 1536/1840, target 1536/1840
# Fitted PCA on batch: source 1792/1840, target 1792/1840
# Fitted PCA on batch: source 2048/1840, target 2048/1840
# Reduced source shape: (1840, 50), target shape: (1840, 50)
# == C: 0.01, Error rate: 0.0364
# == C: 0.1, Error rate: 0.0022
# == C: 0.5, Error rate: 0.0022
# == C: 1.0, Error rate: 0.0022
# == C: 2.0, Error rate: 0.0022
# == C: 5.0, Error rate: 0.0016
# == C: 10.0, Error rate: 0.0016
# == C: 50.0, Error rate: 0.0016
# == C: 100.0, Error rate: 0.0016
# == C: 500.0, Error rate: 0.0016
# == C: 1000.0, Error rate: 0.0016
# Best C: 5.0, Best error rate: 0.0016
# ============ PAD (SVM, batch PCA) = 1.9935
# Time 2235.509414862958 seconds
# epoch 13/25 Average Training Loss: 0.092295
# epoch 13/25 Average Estimation Loss (in Source domain): 0.163972
# epoch 13/25 Average Domain Discrimination Loss: 0.103071
# epoch 13/25 For observation only - Average Estimation Loss in Target domain: 0.399739
# epoch 13/25 (Val) Average Validating Loss: 0.290167
# epoch 13/25 (Val) Average Estimation Loss (in Source domain): 0.179271
# epoch 13/25 (Val) Average Domain Discrimination Loss: 0.097413
# epoch 13/25 (Val) For observation only - Average Estimation Loss in Target domain: 0.401063
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 2344.6077756389277 seconds
# epoch 14/25 Average Training Loss: 0.087032
# epoch 14/25 Average Estimation Loss (in Source domain): 0.162828
# epoch 14/25 Average Domain Discrimination Loss: 0.056183
# epoch 14/25 For observation only - Average Estimation Loss in Target domain: 0.405250
# epoch 14/25 (Val) Average Validating Loss: 0.291407
# epoch 14/25 (Val) Average Estimation Loss (in Source domain): 0.179606
# epoch 14/25 (Val) Average Domain Discrimination Loss: 0.096607
# epoch 14/25 (Val) For observation only - Average Estimation Loss in Target domain: 0.403208
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 2453.71176933893 seconds
# epoch 15/25 Average Training Loss: 0.085092
# epoch 15/25 Average Estimation Loss (in Source domain): 0.161951
# epoch 15/25 Average Domain Discrimination Loss: 0.041169
# epoch 15/25 For observation only - Average Estimation Loss in Target domain: 0.403397
# epoch 15/25 (Val) Average Validating Loss: 0.288277
# epoch 15/25 (Val) Average Estimation Loss (in Source domain): 0.179571
# epoch 15/25 (Val) Average Domain Discrimination Loss: 0.097669
# epoch 15/25 (Val) For observation only - Average Estimation Loss in Target domain: 0.396983
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 2562.8035281589255 seconds
# epoch 16/25 Average Training Loss: 0.085502
# epoch 16/25 Average Estimation Loss (in Source domain): 0.161245
# epoch 16/25 Average Domain Discrimination Loss: 0.048799
# epoch 16/25 For observation only - Average Estimation Loss in Target domain: 0.389800
# epoch 16/25 (Val) Average Validating Loss: 0.279195
# epoch 16/25 (Val) Average Estimation Loss (in Source domain): 0.180207
# epoch 16/25 (Val) Average Domain Discrimination Loss: 0.099955
# epoch 16/25 (Val) For observation only - Average Estimation Loss in Target domain: 0.378184
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 2672.2457632449223 seconds
# epoch 17/25 Average Training Loss: 0.085060
# epoch 17/25 Average Estimation Loss (in Source domain): 0.160750
# epoch 17/25 Average Domain Discrimination Loss: 0.046852
# epoch 17/25 For observation only - Average Estimation Loss in Target domain: 0.374831
# epoch 17/25 (Val) Average Validating Loss: 0.276737
# epoch 17/25 (Val) Average Estimation Loss (in Source domain): 0.180226
# epoch 17/25 (Val) Average Domain Discrimination Loss: 0.097518
# epoch 17/25 (Val) For observation only - Average Estimation Loss in Target domain: 0.373249
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 2781.4303587849718 seconds
# epoch 18/25 Average Training Loss: 0.092326
# epoch 18/25 Average Estimation Loss (in Source domain): 0.160873
# epoch 18/25 Average Domain Discrimination Loss: 0.118899
# epoch 18/25 For observation only - Average Estimation Loss in Target domain: 0.383594
# epoch 18/25 (Val) Average Validating Loss: 0.287027
# epoch 18/25 (Val) Average Estimation Loss (in Source domain): 0.187613
# epoch 18/25 (Val) Average Domain Discrimination Loss: 0.114388
# epoch 18/25 (Val) For observation only - Average Estimation Loss in Target domain: 0.386440
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 2890.5983350139577 seconds
# epoch 19/25 Average Training Loss: 0.088776
# epoch 19/25 Average Estimation Loss (in Source domain): 0.160519
# epoch 19/25 Average Domain Discrimination Loss: 0.085170
# epoch 19/25 For observation only - Average Estimation Loss in Target domain: 0.384704
# epoch 19/25 (Val) Average Validating Loss: 0.281543
# epoch 19/25 (Val) Average Estimation Loss (in Source domain): 0.170667
# epoch 19/25 (Val) Average Domain Discrimination Loss: 0.114795
# epoch 19/25 (Val) For observation only - Average Estimation Loss in Target domain: 0.392418
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 2999.837177486974 seconds
# epoch 20/25 Average Training Loss: 0.092778
# epoch 20/25 Average Estimation Loss (in Source domain): 0.160879
# epoch 20/25 Average Domain Discrimination Loss: 0.123384
# epoch 20/25 For observation only - Average Estimation Loss in Target domain: 0.396276
# epoch 20/25 (Val) Average Validating Loss: 0.277906
# epoch 20/25 (Val) Average Estimation Loss (in Source domain): 0.164915
# epoch 20/25 (Val) Average Domain Discrimination Loss: 0.095897
# epoch 20/25 (Val) For observation only - Average Estimation Loss in Target domain: 0.390897
# batch_idx: 1/115
# batch_idx: 21/115
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 56
#      53     return_features = False
#      54 # return_features = True
#      55 ##########################
# ---> 56 train_step_output = utils_UDA_FiLM.train_step(model, loader_H, loss_fn, lower_range,
#      57                         lambda_domain=lambda_domain, return_features=return_features)
#      58 train_epoc_loss_est        = train_step_output.avg_epoc_loss_est
#      59 train_epoc_loss_domain     = train_step_output.avg_epoc_loss_domain
#
# File ~/Code/H_predict_UDA/H_predict_Sionna/Domain_Adaptation/Domain_Adversarial/helper/utils_UDA_FiLM.py:326, in train_step(model, loader_H, loss_fn, lower_range, nsymb, lambda_domain, lamda_domain_cond, return_features)
#     324 x = loader_H_input_train.next_batch()
#     325 x_cond, x = prepare_data(x, nsymb=nsymb) # Input: concatenated of (nsample, nsubcs,1) (row 2 of slot 1) to (nsample, nsubcs, nsymbs) (duplicate of plot 6)
# --> 326 y = loader_H_true_train.next_batch()  # Label: H_true
#     327 y = y[:,:,70:84]  # only consider 14 symbols of  slot 6
#     328 N_train_source += x.shape[0]
#
# File ~/Code/H_predict_UDA/H_predict_Sionna/Est_btween_CSIRS/helper/utils.py:40, in H5BatchLoader.next_batch(self)
#      38 original_order = np.argsort(np.argsort(batch_indices))
#      39 # Fetch sorted data from HDF5
# ---> 40 batch_sorted = self.data[sorted_indices]
#      41 # Reorder to match original (shuffled) order
#      42 batch = batch_sorted[original_order]
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/miniconda3/envs/TF_py311/lib/python3.11/site-packages/h5py/_hl/dataset.py:885, in Dataset.__getitem__(self, args, new_dtype)
#     883 mspace = h5s.create_simple(selection.mshape)
#     884 fspace = selection.id
# --> 885 self.id.read(mspace, fspace, arr, mtype, dxpl=self._dxpl)
#     887 # Patch up the output for NumPy
#     888 if arr.shape == ():
#
# KeyboardInterrupt:

# %%
print(perform_to_save['pad'])
print(perform_to_save['epoc_pad'])
# Out:
# [1.9934782608695651, 1.991304347826087]
# [34, 69]

# %%
plotfig.figLoss(line_list=[(nmse_val_source, 'Source Domain'), (nmse_val_target, 'Target Domain'), (nmse_val, 'Average')], xlabel='Epoch', ylabel='NMSE',
                        title='NMSE in Validation', index_save=1, fig_show=True, fig_name='NMSE_val')

# %%
plotfig.figLoss(line_list=[(nmse_val_source, 'Source Domain')], xlabel='Epoch', ylabel='NMSE',
                        title='NMSE in Validation in Source Domain', index_save=1, fig_show=True, fig_name='NMSE_val')
