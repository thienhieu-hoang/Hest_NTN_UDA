# %%
import tensorflow as tf

import os
import sys
import numpy as np
from scipy.io import savemat

# os.environ["CUDA_VISIBLE_DEVICES"] = "1"
sys.path.append(os.path.abspath('helper'))
# import utils
# import loader
import utils_UDA_FiLM, PAD
from utils_UDA_FiLM import UDA_FiLM_Output, train_step_Output

# %%
CUDA_VISIBLE_DEVICES=0,1,2

# %%
notebook_dir = os.getcwd()
print(notebook_dir)
print(os.path.abspath(os.path.join(notebook_dir, '..', '..')))
sys.path.append(os.path.abspath(os.path.join(notebook_dir, '..', '..')))
import Est_btween_CSIRS.helper.utils as utils_CNN
import Est_btween_CSIRS.helper.loader as loader
import Est_btween_CSIRS.helper.plotfig as plotfig
# Out:
# /home/thien/Code/H_predict_UDA/H_predict_Sionna/Domain_Adaptation/Domain_Adversarial
# /home/thien/Code/H_predict_UDA/H_predict_Sionna

# %%
source_data_file_path = os.path.abspath(os.path.join(notebook_dir, '..', '..', 'Generate_Data', 'CDL_Channel', 'generatedChannel', 'ver3_', '0dB', 'mapBaseData.mat'))
target_data_file_path = os.path.abspath(os.path.join(notebook_dir, '..', '..', 'Generate_Data', 'Sionna', 'generatedChannel', 'ver3_', 'sionnaTrue.mat'))

# %%
learning_rate = 0.0001
norm_approach = 'minmax' # can be set to 'std'
lower_range = -1 
    # if norm_approach = 'minmax': 
        # =  0 for scaling to  [0 1]
        # = -1 for scaling to [-1 1]
    # if norm_approach = 'std': can be any value, but need to be defined
    
# snr_start = -25
# snr_step = 5
# snr_end = 25
# SNR = np.arange(snr_start, snr_end+1, snr_step)

# SNR = np.array([0])

# if len(SNR) >1:
#     SNR_txt = f'{snr_start}:{snr_step}:{snr_end}'
# else:
#     SNR_txt = f'{SNR[0]}'
    
# ============ CNN settings ==============
if norm_approach == 'minmax':
    if lower_range == 0:
        norm_txt = 'Using min-max [0 1]'
    elif lower_range ==-1:
        norm_txt = 'Using min-max [-1 1]'
elif norm_approach == 'no':
    norm_txt = 'No'
    
CNN_activation = 'Tanh'
CNN_DropOut = 0.2
if CNN_DropOut != 0:
    dropOut_txt = f'Add p={CNN_DropOut} DropOut'
    
# ============ Adversarial for Domain Discriminator settings ==============
domain_disc = 'dense' # 'dense' or 'conv' or 'hybrid'
first_layer_disc = 'pool' # 'flatten' or 'pool' - only matters when domain_disc = 'dense'
                            # note: flatten may cause exhausted memory 
extract_layer = 4  # extract features after convolution layer 3 
# extract_layer = 5
lambda_domain=0.1
lambda_domain_cond = 0.1
text_lambda = f'lambda_domain = {lambda_domain}'
    
    
# create readme.txt file
content = f"""Generated by file 'Domain_Adversarial/UDA_CNN_v3_2.ipynb'.
28 GHz fc,
Source dataset got from {source_data_file_path},
Target dataset got from {target_data_file_path},
Learning rate {learning_rate},
{norm_txt} scaler for each sample
Using {CNN_activation} as activation function of CNN
{dropOut_txt}
========= For Domain Discriminator ==========
Extract features after layer {extract_layer} of CNN
{text_lambda}
"""

# %%
# Paths to save
idx_save_path = loader.find_incremental_filename(notebook_dir + '/model/CNN','ver', '_', '')

model_path = notebook_dir + '/model/CNN/ver' + str(idx_save_path) + '_'
# figure_path = notebook_dir + '/model/CNN/ver' + str(idx_save_path) + '_/figure'
model_readme = model_path + '/readme.txt'
# figure_readme = figure_path + '/readme.txt'

# if not os.path.exists(os.path.dirname(model_readme)):
#     os.makedirs(os.path.dirname(model_readme))
# # if not os.path.exists(os.path.dirname(figure_readme)):
# #     os.makedirs(os.path.dirname(figure_readme))

# # Open the file in write mode ('w'). If the file does not exist, it will be created.
# with open(model_readme, 'w') as file:
#     # Write the content to the file
#     file.write(content)

# # with open(figure_readme, 'w') as file:
# #     # Write the content to the file
# #     file.write(content)

# print(f"File '{model_readme}'  created and content written.")

# %%
import h5py

batch_size=16

# ============ Source data ==============
source_file = h5py.File(source_data_file_path, 'r')
H_true_source = source_file['H_true']
N_samp_source = H_true_source.shape[0]
print('N_samp_source = ', N_samp_source)

# ============ Target data ==============
target_file = h5py.File(target_data_file_path, 'r')
H_true_target = target_file['H_true']
N_samp_target = H_true_target.shape[0]
print('N_samp_target = ', N_samp_target)
# Out:
# N_samp_source =  2048
# N_samp_target =  2048

# %%
indices_source = np.arange(N_samp_source)
np.random.shuffle(indices_source)
indices_target = np.arange(N_samp_target)
np.random.shuffle(indices_target)
#
train_size = int(np.floor(N_samp_source * 0.9) // batch_size * batch_size)
val_size = N_samp_source - train_size

# Repeat the indices to match the maximum number of samples
N_samp = max(N_samp_source, N_samp_target) 
indices_source = np.resize(indices_source, N_samp)
indices_target = np.resize(indices_target, N_samp)

# =======================================================
## Divide the indices into training and validation sets
indices_train_source = indices_source[:train_size]
indices_val_source   = indices_source[train_size:train_size + val_size]

indices_train_target = indices_target[:train_size]
indices_val_target   = indices_target[train_size:train_size + val_size]

# to test code
# indices_train_source = indices_source[:96]
# indices_val_source = indices_source[2032:]
# indices_train_target = indices_target[:96]
# indices_val_target = indices_target[2032:]
#
# indices_train_source = indices_source[:500]
# indices_val_source = indices_source[1998:]
# indices_train_target = indices_target[:500]
# indices_val_target = indices_target[1998:]

print('train_size = ', indices_train_source.shape[0])
print('val_size = ', indices_val_source.shape[0])
# Out:
# train_size =  1840
# val_size =  208

# %%
# =========== Source dataset ==============
loader_H_true_train_source = utils_CNN.H5BatchLoader(source_file, dataset_name='H_true', batch_size=batch_size, shuffled_indices=indices_train_source)
loader_H_1_6_11_train_source = utils_CNN.H5BatchLoader(source_file, 'H_linear_1_6_11', batch_size=batch_size, shuffled_indices=indices_train_source)
    # channel at symbol 2 of slots 1,6,11 (channel corresponding to CSI-RS 1, 2, 3)
loader_H_true_val_source = utils_CNN.H5BatchLoader(source_file, dataset_name='H_true', batch_size=batch_size, shuffled_indices=indices_val_source)
loader_H_1_6_11_val_source = utils_CNN.H5BatchLoader(source_file, 'H_linear_1_6_11', batch_size=batch_size, shuffled_indices=indices_val_source)

# =========== Target dataset ==============
loader_H_true_train_target = utils_CNN.H5BatchLoader(target_file, dataset_name='H_true', batch_size=batch_size, shuffled_indices=indices_train_target)
    # actually at target domain, we don't have true channels, just use this for evaluating the model
loader_H_1_6_11_train_target = utils_CNN.H5BatchLoader(target_file, 'H_linear_1_6', batch_size=batch_size, shuffled_indices=indices_train_target)
    # channel at symbol 2 of slots 1,6,11 (channel corresponding to CSI-RS 1, 2)
loader_H_true_val_target = utils_CNN.H5BatchLoader(target_file, dataset_name='H_true', batch_size=batch_size, shuffled_indices=indices_val_target)
loader_H_1_6_11_val_target = utils_CNN.H5BatchLoader(target_file, 'H_linear_1_6', batch_size=batch_size, shuffled_indices=indices_val_target)

print('size loader_H_true_train = ', loader_H_true_train_target.total_batches)
print('size loader_H_true_val = ', loader_H_true_val_target.total_batches)
# Out:
# size loader_H_true_train =  115
# size loader_H_true_val =  13

# %%
# pad = PAD.original_PAD(loader_H_1_6_11_train_source, loader_H_1_6_11_train_target)
# print(f"PAD = {pad:.4f}")

# %%
loss_fn_ce = tf.keras.losses.MeanSquaredError()  # Channel estimation loss
loss_fn_domain = tf.keras.losses.BinaryCrossentropy()  # Domain classification loss

# %%
from tensorflow.keras import optimizers, losses
import time
start = time.perf_counter()

n_epochs= 70 # n_epochs= 25
epoch_min = 30
epoch_step = 10
# n_epochs= 2
# epoch_min = 0
# epoch_step = 1

train_mode = ['FiLM']

for sub_folder in train_mode:
    print(f"Processing: {sub_folder}")
    
    if not os.path.exists(os.path.dirname(model_path + '/' + sub_folder +'/')):
        os.makedirs(os.path.dirname(model_path + '/' + sub_folder + '/'))

    train_loss          = [] # (epoch,1)
    train_est_loss      = [] 
    train_domain_loss   = []
    train_est_loss_target = []
    #    
    val_loss, val_domain_loss_source, val_domain_loss_target, val_domain_loss,\
    val_est_loss_source, val_est_loss_target, val_est_loss,\
    source_acc, target_acc, acc,\
    nmse_val_source, nmse_val_target, nmse_val = [[] for _ in range(13)]
    #
    H_to_save = {}          # list to save to .mat file for H
    perform_to_save = {}    # list to save to .mat file for nmse, losses,...

    model = utils_UDA_FiLM.UDA_FiLM_UpDown(domain_disc = domain_disc, extract_layer=extract_layer, first_layer_disc=first_layer_disc)
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    
    flag = 1 # flag to plot and save H_true
    pad = []
    epoc_pad = []
    for epoch in range(n_epochs):
        # ===================== Training =====================
        loader_H_true_train_source.reset()
        loader_H_1_6_11_train_source.reset()
        loader_H_true_train_target.reset()
        loader_H_1_6_11_train_target.reset()
                
        loader_H = [loader_H_1_6_11_train_source, loader_H_true_train_source, loader_H_1_6_11_train_target, loader_H_true_train_target]
        loss_fn = [loss_fn_ce, loss_fn_domain, optimizer]
        ##########################
        if epoch in [int((n_epochs) * r) for r in [0.49, 0.99]]:  # [0.25, 0.5, 0.75, 0.99]]
            return_features = True
            epoc_pad.append(epoch)
        else:
            return_features = False
        # return_features = True
        ##########################
        train_step_output = utils_UDA_FiLM.train_step(model, loader_H, loss_fn, lower_range,
                                lambda_domain=lambda_domain, return_features=return_features)
        train_epoc_loss_est        = train_step_output.avg_epoc_loss_est
        train_epoc_loss_domain     = train_step_output.avg_epoc_loss_domain
        train_epoc_loss            = train_step_output.avg_epoc_loss
        train_epoc_loss_est_target = train_step_output.avg_epoc_loss_est_target
                # train_epoc_loss        = total train loss = loss_est + lambda_domain * domain_loss
                # train_epoc_loss_est    = loss in estimation network in source domain (labels available)
                # train_epoc_loss_domain = loss in domain discrimination network
                # train_epoc_loss_est_target - just to monitor - the machine can not calculate because no label available in source domain
                # All are already calculated in average over training dataset (source/target - respectively)
        # Calculate PAD for the extracted features
        print("Time", time.perf_counter() - start, "seconds")
        if return_features:
            features_source_file = "features_source.h5"
            features_target_file = "features_target.h5"
            print(f"epoch {epoch+1}/{n_epochs}")
            # pad_epoc_sgd  = PAD.cal_PAD_SGD(features_source_file, features_target_file)
            pad_epoc  = PAD.cal_PAD2(features_source_file, features_target_file, pca_components=50, batch_size=256)
            pad.append(pad_epoc)
            if os.path.exists(features_source_file):
                os.remove(features_source_file)
            if os.path.exists(features_target_file):
                os.remove(features_target_file)
            print("Time", time.perf_counter() - start, "seconds")
            
        
        # Average loss for the epoch
        train_loss.append(train_epoc_loss)
        print(f"epoch {epoch+1}/{n_epochs} Average Training Loss: {train_epoc_loss:.6f}")
        #
        train_est_loss.append(train_epoc_loss_est)
        print(f"epoch {epoch+1}/{n_epochs} Average Estimation Loss (in Source domain): {train_epoc_loss_est:.6f}")
        #
        train_domain_loss.append(train_epoc_loss_domain)
        print(f"epoch {epoch+1}/{n_epochs} Average Domain Discrimination Loss: {train_epoc_loss_domain:.6f}")
        #
        train_est_loss_target.append(train_epoc_loss_est_target)
        print(f"epoch {epoch+1}/{n_epochs} For observation only - Average Estimation Loss in Target domain: {train_epoc_loss_est_target:.6f}")
        
        
        # ===================== Evaluation =====================
        loader_H_true_val_source.reset()
        loader_H_1_6_11_val_source.reset()
        loader_H_true_val_target.reset()
        loader_H_1_6_11_val_target.reset()
        loader_H_eval = [loader_H_1_6_11_val_source, loader_H_true_val_source, loader_H_1_6_11_val_target, loader_H_true_val_target]

        loss_fn = loss_fn_ce, loss_fn_domain
        
        eval_func = utils_UDA_FiLM.val_step
        if (epoch+1>epoch_min and epoch%epoch_step==0) or epoch==n_epochs-1:
            H_sample, epoc_val_return = utils_UDA_FiLM.val_step(model, loader_H_eval, loss_fn, lower_range, epoch=epoch, lambda_domain=lambda_domain)
            print('Unpack H_sample and save for visualization')
            (
                H_true_sample,  H_input_sample, H_est_sample, H_input_condition, 
                nmse_input_source, nmse_est_source, domain_sample_return_source,
                H_true_sample_target, H_input_sample_target, H_est_sample_target, H_input_condition_target,
                nmse_input_target, nmse_est_target, domain_sample_return_target
            ) = H_sample
            
            # plot real parts
            # source domain
            if flag == 1:
                plotfig.figChan(H_true_sample[0,:,:,0], title='True channel Slot 6', index_save=epoch+1, 
                                        figure_save_path=model_path + '/' + sub_folder + '/H_visualize', name='H_true_source')
                plotfig.figChan(H_input_sample[0,:,:,0], nmse=nmse_input_source[0], title='Raw-estimated Channel Slot 6', index_save=epoch+1, 
                                        figure_save_path=model_path + '/' + sub_folder + '/H_visualize', name='H_input_source')
                # if sub_folder == 'in_15_symbs' or sub_folder == 'FiLM':
                plotfig.figChan(H_input_condition[0,:,0,0], title='Condition Channel', index_save=epoch+1, 
                                        figure_save_path=model_path + '/' + sub_folder + '/H_visualize', name='H_input_condition_source')
            plotfig.figChan(H_est_sample[0,:,:,0], nmse=nmse_est_source[0], title='CNN-refined Channel Slot 6', index_save=epoch+1, 
                                        figure_save_path=model_path + '/' + sub_folder + '/H_visualize', name='H_CNN_source')
            # target domain
            if flag == 1:
                plotfig.figChan(H_true_sample_target[0,:,:,0], title='True channel Slot 6', index_save=epoch+1, 
                                        figure_save_path=model_path + '/' + sub_folder + '/H_visualize', name='H_true_target')
                plotfig.figChan(H_input_sample_target[0,:,:,0], nmse=nmse_input_target[0], title='Raw-estimated Channel Slot 6', index_save=epoch+1, 
                                        figure_save_path=model_path + '/' + sub_folder + '/H_visualize', name='H_input_target')
                # if sub_folder == 'in_15_symbs' or sub_folder == 'FiLM':
                plotfig.figChan(H_input_condition_target[0,:,0,0], title='Condition Channel', index_save=epoch+1, 
                                        figure_save_path=model_path + '/' + sub_folder + '/H_visualize', name='H_input_condition_target')
                flag = 0
            plotfig.figChan(H_est_sample[0,:,:,0], nmse=nmse_est_target[0], title='CNN-refined Channel Slot 6', index_save=epoch+1, 
                                        figure_save_path=model_path + '/' + sub_folder + '/H_visualize', name='H_CNN_target')
            
            H_to_save[f'{epoch+1}_H_true_source'] = H_true_sample
            H_to_save[f'{epoch+1}_H_input_source'] = H_input_sample
            H_to_save[f'{epoch+1}_H_est_source'] = H_est_sample
            H_to_save[f'{epoch+1}_H_input_condition_source'] = H_input_condition
                # don't save nmse_input_source, nmse_est_source because can compute them later
            H_to_save[f'{epoch+1}_domain_sample_return_source'] = domain_sample_return_source
            #
            H_to_save[f'{epoch+1}_H_true_target'] = H_true_sample_target
            H_to_save[f'{epoch+1}_H_input_target'] = H_input_sample_target
            H_to_save[f'{epoch+1}_H_est_target'] = H_est_sample_target
            H_to_save[f'{epoch+1}_H_input_condition_target'] = H_input_condition_target
            H_to_save[f'{epoch+1}_domain_sample_return_target'] = domain_sample_return_target
            
        else:
            _, epoc_val_return = utils_UDA_FiLM.val_step(model, loader_H_eval, loss_fn, lower_range, lambda_domain=lambda_domain)
        
        (
            avg_epoc_total_loss, 
            avg_epoc_val_domain_loss_source, avg_epoc_val_domain_loss_target, avg_epoc_val_domain_loss,
            avg_epoc_val_est_loss_source, avg_epoc_val_est_loss_target, avg_epoc_val_est_loss,
            avg_epoc_source_acc, avg_epoc_target_acc, avg_epoc_acc,
            avg_epoc_nmse_val_source, avg_epoc_nmse_val_target, avg_epoc_nmse_val
        ) = epoc_val_return
        # Average loss for the epoch
        val_est_loss.append(avg_epoc_val_est_loss)
        print(f"epoch {epoch+1}/{n_epochs} (Val) Average Validating Loss: {avg_epoc_val_est_loss:.6f}")
        #
        val_est_loss_source.append(avg_epoc_val_est_loss_source)
        print(f"epoch {epoch+1}/{n_epochs} (Val) Average Estimation Loss (in Source domain): {avg_epoc_val_est_loss_source:.6f}")
        #
        val_loss.append(avg_epoc_total_loss)
        print(f"epoch {epoch+1}/{n_epochs} (Val) Average Domain Discrimination Loss: {avg_epoc_total_loss:.6f}")
        #
        val_est_loss_target.append(avg_epoc_val_est_loss_target)
        print(f"epoch {epoch+1}/{n_epochs} (Val) For observation only - Average Estimation Loss in Target domain: {avg_epoc_val_est_loss_target:.6f}")
        #
        val_domain_loss_source.append(avg_epoc_val_domain_loss_source)
        val_domain_loss_target.append(avg_epoc_val_domain_loss_target)
        val_domain_loss.append(avg_epoc_val_domain_loss)
        source_acc.append(avg_epoc_source_acc)
        target_acc.append(avg_epoc_target_acc)
        acc.append(avg_epoc_acc)
        nmse_val_source.append(avg_epoc_nmse_val_source)
        nmse_val_target.append(avg_epoc_nmse_val_target)
        nmse_val.append(avg_epoc_nmse_val)
        
        
        if (epoch+1>epoch_min and (epoch+1)%epoch_step==0) or epoch==n_epochs-1:
            # Save model
            os.makedirs(f"{model_path}/{sub_folder}/model/", exist_ok=True)
            model.save(f"{model_path}/{sub_folder}/model/epoch_{epoch+1}.keras")
            print(f"Model saved at epoch {epoch+1} to {model_path}/{sub_folder}/epoch_{epoch+1}")    
            
            # === save and overwrite at checkpoints
            # train
            perform_to_save['train_loss'] = train_loss
            perform_to_save['train_est_loss'] = train_est_loss
            perform_to_save['train_domain_loss'] = train_domain_loss
            perform_to_save['train_est_loss_target'] = train_est_loss_target
            # val
            perform_to_save['val_est_loss'] = val_est_loss
            perform_to_save['val_est_loss_source'] = val_est_loss_source
            perform_to_save['val_loss'] = val_loss
            perform_to_save['val_est_loss_target'] = val_est_loss_target
            perform_to_save['val_domain_loss_source'] = val_domain_loss_source
            perform_to_save['val_domain_loss_target'] = val_domain_loss_target
            perform_to_save['val_domain_loss'] = val_domain_loss
            perform_to_save['source_acc'] = source_acc
            perform_to_save['target_acc'] = target_acc
            perform_to_save['acc'] = acc
            perform_to_save['nmse_val_source'] = nmse_val_source
            perform_to_save['nmse_val_target'] = nmse_val_target
            perform_to_save['nmse_val'] = nmse_val
            #
            perform_to_save['pad'] = pad
            perform_to_save['epoc_pad'] = epoc_pad
            
            # save
            os.makedirs(f"{model_path}/{sub_folder}/performance/", exist_ok=True)
            savemat(model_path + '/' + sub_folder + '/performance/performance.mat', perform_to_save)
            
            # Plot figures === save and overwrite at checkpoints
            plotfig.figLoss(line_list=[(nmse_val_source, 'Source Domain'), (nmse_val_target, 'Target Domain')], xlabel='Epoch', ylabel='NMSE',
                        title='NMSE in Validation', index_save=1, figure_save_path= model_path + '/' + sub_folder + '/performance', fig_name='NMSE_val')
            plotfig.figLoss(line_list=[(source_acc, 'Source Domain'), (target_acc, 'Target Domain')], xlabel='Epoch', ylabel='Discrimination Accuracy',
                        title='Domain Discrimination Accuracy in Validation', index_save=1, figure_save_path= model_path + '/' + sub_folder + '/performance', fig_name='Domain_acc')
            #
            plotfig.figLoss(line_list=[(train_loss, 'Training'), (val_loss, 'Validating')], xlabel='Epoch', ylabel='Total Loss',
                        title='Training and Validating Total Loss', index_save=1, figure_save_path= model_path + '/' + sub_folder + '/performance', fig_name='Loss_total')
            plotfig.figLoss(line_list=[(train_est_loss, 'Training-Source'), (train_est_loss_target, 'Training-Target'), 
                                    (val_est_loss_source, 'Validating-Source'), (val_est_loss_target, 'Validating-Target')], xlabel='Epoch', ylabel='Estimation Loss',
                        title='Training and Validating Estimation Loss', index_save=1, figure_save_path= model_path + '/' + sub_folder + '/performance', fig_name='Loss_est')
            plotfig.figLoss(line_list=[(train_domain_loss, 'Training'), (val_domain_loss, 'Validating')], xlabel='Epoch', ylabel='Domain Discrimination Loss',
                        title='Training and Validating Domain Discrimination Loss', index_save=1, figure_save_path= model_path + '/' + sub_folder + '/performance', fig_name='Loss_domain')
            
    # end of epoch loop
    # =====================            
    # Save performances
    # Save H matrix
    savemat(model_path + '/' + sub_folder + '/H_visualize/H_trix.mat', H_to_save)
# Out:
# Processing: FiLM
# batch_idx: 1/115
# /home/thien/miniconda3/envs/TF_py311/lib/python3.11/site-packages/keras/src/layers/layer.py:396: UserWarning: `build()` was called on layer 'domain_discriminator_2', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /home/thien/miniconda3/envs/TF_py311/lib/python3.11/site-packages/keras/src/layers/layer.py:396: UserWarning: `build()` was called on layer 'domain_discriminator_3', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 99.39782126701903 seconds
# epoch 1/70 Average Training Loss: 0.195554
# epoch 1/70 Average Estimation Loss (in Source domain): 0.208810
# epoch 1/70 Average Domain Discrimination Loss: 0.582158
# epoch 1/70 For observation only - Average Estimation Loss in Target domain: 0.177556
# epoch 1/70 (Val) Average Validating Loss: 0.191963
# epoch 1/70 (Val) Average Estimation Loss (in Source domain): 0.207268
# epoch 1/70 (Val) Average Domain Discrimination Loss: 0.150443
# epoch 1/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.176657
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 206.35087108495645 seconds
# epoch 2/70 Average Training Loss: 0.157009
# epoch 2/70 Average Estimation Loss (in Source domain): 0.198806
# epoch 2/70 Average Domain Discrimination Loss: 0.378567
# epoch 2/70 For observation only - Average Estimation Loss in Target domain: 0.175645
# epoch 2/70 (Val) Average Validating Loss: 0.187796
# epoch 2/70 (Val) Average Estimation Loss (in Source domain): 0.198202
# epoch 2/70 (Val) Average Domain Discrimination Loss: 0.129045
# epoch 2/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.177389
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 313.0629934309982 seconds
# epoch 3/70 Average Training Loss: 0.142891
# epoch 3/70 Average Estimation Loss (in Source domain): 0.191370
# epoch 3/70 Average Domain Discrimination Loss: 0.280655
# epoch 3/70 For observation only - Average Estimation Loss in Target domain: 0.177246
# epoch 3/70 (Val) Average Validating Loss: 0.185182
# epoch 3/70 (Val) Average Estimation Loss (in Source domain): 0.192002
# epoch 3/70 (Val) Average Domain Discrimination Loss: 0.122537
# epoch 3/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.178363
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 419.9319961889414 seconds
# epoch 4/70 Average Training Loss: 0.144572
# epoch 4/70 Average Estimation Loss (in Source domain): 0.187365
# epoch 4/70 Average Domain Discrimination Loss: 0.320673
# epoch 4/70 For observation only - Average Estimation Loss in Target domain: 0.176316
# epoch 4/70 (Val) Average Validating Loss: 0.182636
# epoch 4/70 (Val) Average Estimation Loss (in Source domain): 0.189753
# epoch 4/70 (Val) Average Domain Discrimination Loss: 0.131859
# epoch 4/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.175519
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 526.6955205940176 seconds
# epoch 5/70 Average Training Loss: 0.140305
# epoch 5/70 Average Estimation Loss (in Source domain): 0.186173
# epoch 5/70 Average Domain Discrimination Loss: 0.290272
# epoch 5/70 For observation only - Average Estimation Loss in Target domain: 0.173502
# epoch 5/70 (Val) Average Validating Loss: 0.181643
# epoch 5/70 (Val) Average Estimation Loss (in Source domain): 0.188967
# epoch 5/70 (Val) Average Domain Discrimination Loss: 0.120202
# epoch 5/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.174320
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 633.0522815010045 seconds
# epoch 6/70 Average Training Loss: 0.136677
# epoch 6/70 Average Estimation Loss (in Source domain): 0.185280
# epoch 6/70 Average Domain Discrimination Loss: 0.267107
# epoch 6/70 For observation only - Average Estimation Loss in Target domain: 0.179291
# epoch 6/70 (Val) Average Validating Loss: 0.187691
# epoch 6/70 (Val) Average Estimation Loss (in Source domain): 0.188255
# epoch 6/70 (Val) Average Domain Discrimination Loss: 0.121426
# epoch 6/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.187128
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 739.8441941109486 seconds
# epoch 7/70 Average Training Loss: 0.138169
# epoch 7/70 Average Estimation Loss (in Source domain): 0.184628
# epoch 7/70 Average Domain Discrimination Loss: 0.297268
# epoch 7/70 For observation only - Average Estimation Loss in Target domain: 0.209210
# epoch 7/70 (Val) Average Validating Loss: 0.207415
# epoch 7/70 (Val) Average Estimation Loss (in Source domain): 0.187626
# epoch 7/70 (Val) Average Domain Discrimination Loss: 0.115667
# epoch 7/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.227203
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 846.8126159689855 seconds
# epoch 8/70 Average Training Loss: 0.127531
# epoch 8/70 Average Estimation Loss (in Source domain): 0.184229
# epoch 8/70 Average Domain Discrimination Loss: 0.205692
# epoch 8/70 For observation only - Average Estimation Loss in Target domain: 0.226349
# epoch 8/70 (Val) Average Validating Loss: 0.208229
# epoch 8/70 (Val) Average Estimation Loss (in Source domain): 0.187221
# epoch 8/70 (Val) Average Domain Discrimination Loss: 0.112368
# epoch 8/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.229238
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 953.7360798430163 seconds
# epoch 9/70 Average Training Loss: 0.128202
# epoch 9/70 Average Estimation Loss (in Source domain): 0.183924
# epoch 9/70 Average Domain Discrimination Loss: 0.224769
# epoch 9/70 For observation only - Average Estimation Loss in Target domain: 0.236150
# epoch 9/70 (Val) Average Validating Loss: 0.203809
# epoch 9/70 (Val) Average Estimation Loss (in Source domain): 0.186892
# epoch 9/70 (Val) Average Domain Discrimination Loss: 0.110333
# epoch 9/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.220727
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 1060.1127105969936 seconds
# epoch 10/70 Average Training Loss: 0.123719
# epoch 10/70 Average Estimation Loss (in Source domain): 0.183587
# epoch 10/70 Average Domain Discrimination Loss: 0.190635
# epoch 10/70 For observation only - Average Estimation Loss in Target domain: 0.195570
# epoch 10/70 (Val) Average Validating Loss: 0.188734
# epoch 10/70 (Val) Average Estimation Loss (in Source domain): 0.186556
# epoch 10/70 (Val) Average Domain Discrimination Loss: 0.107871
# epoch 10/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.190913
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 1166.7348535750061 seconds
# epoch 11/70 Average Training Loss: 0.122546
# epoch 11/70 Average Estimation Loss (in Source domain): 0.183271
# epoch 11/70 Average Domain Discrimination Loss: 0.186639
# epoch 11/70 For observation only - Average Estimation Loss in Target domain: 0.182669
# epoch 11/70 (Val) Average Validating Loss: 0.184861
# epoch 11/70 (Val) Average Estimation Loss (in Source domain): 0.186264
# epoch 11/70 (Val) Average Domain Discrimination Loss: 0.116610
# epoch 11/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.183458
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 1273.7207883689553 seconds
# epoch 12/70 Average Training Loss: 0.136770
# epoch 12/70 Average Estimation Loss (in Source domain): 0.183010
# epoch 12/70 Average Domain Discrimination Loss: 0.334466
# epoch 12/70 For observation only - Average Estimation Loss in Target domain: 0.178644
# epoch 12/70 (Val) Average Validating Loss: 0.184308
# epoch 12/70 (Val) Average Estimation Loss (in Source domain): 0.185984
# epoch 12/70 (Val) Average Domain Discrimination Loss: 0.123258
# epoch 12/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.182632
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 1380.7750115039526 seconds
# epoch 13/70 Average Training Loss: 0.141015
# epoch 13/70 Average Estimation Loss (in Source domain): 0.182777
# epoch 13/70 Average Domain Discrimination Loss: 0.381430
# epoch 13/70 For observation only - Average Estimation Loss in Target domain: 0.178937
# epoch 13/70 (Val) Average Validating Loss: 0.187095
# epoch 13/70 (Val) Average Estimation Loss (in Source domain): 0.185733
# epoch 13/70 (Val) Average Domain Discrimination Loss: 0.124129
# epoch 13/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.188457
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 1487.3438763429876 seconds
# epoch 14/70 Average Training Loss: 0.132691
# epoch 14/70 Average Estimation Loss (in Source domain): 0.182629
# epoch 14/70 Average Domain Discrimination Loss: 0.302037
# epoch 14/70 For observation only - Average Estimation Loss in Target domain: 0.181875
# epoch 14/70 (Val) Average Validating Loss: 0.186602
# epoch 14/70 (Val) Average Estimation Loss (in Source domain): 0.185595
# epoch 14/70 (Val) Average Domain Discrimination Loss: 0.115726
# epoch 14/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.187608
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 1594.009051703033 seconds
# epoch 15/70 Average Training Loss: 0.132115
# epoch 15/70 Average Estimation Loss (in Source domain): 0.182393
# epoch 15/70 Average Domain Discrimination Loss: 0.300249
# epoch 15/70 For observation only - Average Estimation Loss in Target domain: 0.179774
# epoch 15/70 (Val) Average Validating Loss: 0.185254
# epoch 15/70 (Val) Average Estimation Loss (in Source domain): 0.185210
# epoch 15/70 (Val) Average Domain Discrimination Loss: 0.120098
# epoch 15/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.185299
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 1700.9742700279457 seconds
# epoch 16/70 Average Training Loss: 0.160877
# epoch 16/70 Average Estimation Loss (in Source domain): 0.182106
# epoch 16/70 Average Domain Discrimination Loss: 0.591918
# epoch 16/70 For observation only - Average Estimation Loss in Target domain: 0.185453
# epoch 16/70 (Val) Average Validating Loss: 0.197102
# epoch 16/70 (Val) Average Estimation Loss (in Source domain): 0.184803
# epoch 16/70 (Val) Average Domain Discrimination Loss: 0.249922
# epoch 16/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.209402
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 1807.7005820550257 seconds
# epoch 17/70 Average Training Loss: 0.151962
# epoch 17/70 Average Estimation Loss (in Source domain): 0.181828
# epoch 17/70 Average Domain Discrimination Loss: 0.506836
# epoch 17/70 For observation only - Average Estimation Loss in Target domain: 0.192453
# epoch 17/70 (Val) Average Validating Loss: 0.191372
# epoch 17/70 (Val) Average Estimation Loss (in Source domain): 0.184471
# epoch 17/70 (Val) Average Domain Discrimination Loss: 0.127619
# epoch 17/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.198273
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 1914.5291879409924 seconds
# epoch 18/70 Average Training Loss: 0.137425
# epoch 18/70 Average Estimation Loss (in Source domain): 0.181419
# epoch 18/70 Average Domain Discrimination Loss: 0.365416
# epoch 18/70 For observation only - Average Estimation Loss in Target domain: 0.187508
# epoch 18/70 (Val) Average Validating Loss: 0.187255
# epoch 18/70 (Val) Average Estimation Loss (in Source domain): 0.184211
# epoch 18/70 (Val) Average Domain Discrimination Loss: 0.116170
# epoch 18/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.190298
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 2022.357996503939 seconds
# epoch 19/70 Average Training Loss: 0.129033
# epoch 19/70 Average Estimation Loss (in Source domain): 0.180943
# epoch 19/70 Average Domain Discrimination Loss: 0.285356
# epoch 19/70 For observation only - Average Estimation Loss in Target domain: 0.191402
# epoch 19/70 (Val) Average Validating Loss: 0.190011
# epoch 19/70 (Val) Average Estimation Loss (in Source domain): 0.183504
# epoch 19/70 (Val) Average Domain Discrimination Loss: 0.114313
# epoch 19/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.196518
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 2129.6516866940074 seconds
# epoch 20/70 Average Training Loss: 0.125712
# epoch 20/70 Average Estimation Loss (in Source domain): 0.180556
# epoch 20/70 Average Domain Discrimination Loss: 0.255302
# epoch 20/70 For observation only - Average Estimation Loss in Target domain: 0.194841
# epoch 20/70 (Val) Average Validating Loss: 0.188531
# epoch 20/70 (Val) Average Estimation Loss (in Source domain): 0.183177
# epoch 20/70 (Val) Average Domain Discrimination Loss: 0.112932
# epoch 20/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.193885
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 2236.5863732079742 seconds
# epoch 21/70 Average Training Loss: 0.123718
# epoch 21/70 Average Estimation Loss (in Source domain): 0.180222
# epoch 21/70 Average Domain Discrimination Loss: 0.238092
# epoch 21/70 For observation only - Average Estimation Loss in Target domain: 0.195808
# epoch 21/70 (Val) Average Validating Loss: 0.188989
# epoch 21/70 (Val) Average Estimation Loss (in Source domain): 0.182840
# epoch 21/70 (Val) Average Domain Discrimination Loss: 0.112850
# epoch 21/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.195138
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 2343.9711977969855 seconds
# epoch 22/70 Average Training Loss: 0.142119
# epoch 22/70 Average Estimation Loss (in Source domain): 0.179898
# epoch 22/70 Average Domain Discrimination Loss: 0.424601
# epoch 22/70 For observation only - Average Estimation Loss in Target domain: 0.199452
# epoch 22/70 (Val) Average Validating Loss: 0.194150
# epoch 22/70 (Val) Average Estimation Loss (in Source domain): 0.182602
# epoch 22/70 (Val) Average Domain Discrimination Loss: 0.206141
# epoch 22/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.205698
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 2450.943127015955 seconds
# epoch 23/70 Average Training Loss: 0.157506
# epoch 23/70 Average Estimation Loss (in Source domain): 0.179488
# epoch 23/70 Average Domain Discrimination Loss: 0.581596
# epoch 23/70 For observation only - Average Estimation Loss in Target domain: 0.202849
# epoch 23/70 (Val) Average Validating Loss: 0.193462
# epoch 23/70 (Val) Average Estimation Loss (in Source domain): 0.182834
# epoch 23/70 (Val) Average Domain Discrimination Loss: 0.126082
# epoch 23/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.204090
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 2557.8561531109735 seconds
# epoch 24/70 Average Training Loss: 0.154591
# epoch 24/70 Average Estimation Loss (in Source domain): 0.179001
# epoch 24/70 Average Domain Discrimination Loss: 0.555890
# epoch 24/70 For observation only - Average Estimation Loss in Target domain: 0.217194
# epoch 24/70 (Val) Average Validating Loss: 0.208776
# epoch 24/70 (Val) Average Estimation Loss (in Source domain): 0.182984
# epoch 24/70 (Val) Average Domain Discrimination Loss: 0.158396
# epoch 24/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.234567
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 2664.6824081570376 seconds
# epoch 25/70 Average Training Loss: 0.226525
# epoch 25/70 Average Estimation Loss (in Source domain): 0.178502
# epoch 25/70 Average Domain Discrimination Loss: 1.278615
# epoch 25/70 For observation only - Average Estimation Loss in Target domain: 0.252497
# epoch 25/70 (Val) Average Validating Loss: 0.244983
# epoch 25/70 (Val) Average Estimation Loss (in Source domain): 0.183504
# epoch 25/70 (Val) Average Domain Discrimination Loss: 0.200614
# epoch 25/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.306461
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 2771.604498622939 seconds
# epoch 26/70 Average Training Loss: 0.254735
# epoch 26/70 Average Estimation Loss (in Source domain): 0.178210
# epoch 26/70 Average Domain Discrimination Loss: 1.562504
# epoch 26/70 For observation only - Average Estimation Loss in Target domain: 0.272074
# epoch 26/70 (Val) Average Validating Loss: 0.258837
# epoch 26/70 (Val) Average Estimation Loss (in Source domain): 0.184464
# epoch 26/70 (Val) Average Domain Discrimination Loss: 0.248411
# epoch 26/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.333210
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 2878.486481535947 seconds
# epoch 27/70 Average Training Loss: 0.314267
# epoch 27/70 Average Estimation Loss (in Source domain): 0.177392
# epoch 27/70 Average Domain Discrimination Loss: 2.162583
# epoch 27/70 For observation only - Average Estimation Loss in Target domain: 0.309568
# epoch 27/70 (Val) Average Validating Loss: 0.283936
# epoch 27/70 (Val) Average Estimation Loss (in Source domain): 0.184456
# epoch 27/70 (Val) Average Domain Discrimination Loss: 0.207339
# epoch 27/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.383416
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 2985.8930147549836 seconds
# epoch 28/70 Average Training Loss: 0.204094
# epoch 28/70 Average Estimation Loss (in Source domain): 0.176707
# epoch 28/70 Average Domain Discrimination Loss: 1.065095
# epoch 28/70 For observation only - Average Estimation Loss in Target domain: 0.306764
# epoch 28/70 (Val) Average Validating Loss: 0.261276
# epoch 28/70 (Val) Average Estimation Loss (in Source domain): 0.183493
# epoch 28/70 (Val) Average Domain Discrimination Loss: 0.137545
# epoch 28/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.339058
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 3094.0843554609455 seconds
# epoch 29/70 Average Training Loss: 0.180218
# epoch 29/70 Average Estimation Loss (in Source domain): 0.175393
# epoch 29/70 Average Domain Discrimination Loss: 0.833847
# epoch 29/70 For observation only - Average Estimation Loss in Target domain: 0.326488
# epoch 29/70 (Val) Average Validating Loss: 0.281869
# epoch 29/70 (Val) Average Estimation Loss (in Source domain): 0.182346
# epoch 29/70 (Val) Average Domain Discrimination Loss: 0.173392
# epoch 29/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.381392
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 3201.0933969489997 seconds
# epoch 30/70 Average Training Loss: 0.230307
# epoch 30/70 Average Estimation Loss (in Source domain): 0.174669
# epoch 30/70 Average Domain Discrimination Loss: 1.339151
# epoch 30/70 For observation only - Average Estimation Loss in Target domain: 0.376917
# epoch 30/70 (Val) Average Validating Loss: 0.301078
# epoch 30/70 (Val) Average Estimation Loss (in Source domain): 0.183447
# epoch 30/70 (Val) Average Domain Discrimination Loss: 0.299624
# epoch 30/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.418710
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 3315.0208724789554 seconds
# epoch 31/70 Average Training Loss: 0.360590
# epoch 31/70 Average Estimation Loss (in Source domain): 0.174324
# epoch 31/70 Average Domain Discrimination Loss: 2.644516
# epoch 31/70 For observation only - Average Estimation Loss in Target domain: 0.430385
# Unpack H_sample and save for visualization
# epoch 31/70 (Val) Average Validating Loss: 0.330006
# epoch 31/70 (Val) Average Estimation Loss (in Source domain): 0.184350
# epoch 31/70 (Val) Average Domain Discrimination Loss: 0.206642
# epoch 31/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.475662
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 3433.936618985026 seconds
# epoch 32/70 Average Training Loss: 0.399486
# epoch 32/70 Average Estimation Loss (in Source domain): 0.173466
# epoch 32/70 Average Domain Discrimination Loss: 3.038505
# epoch 32/70 For observation only - Average Estimation Loss in Target domain: 0.450292
# epoch 32/70 (Val) Average Validating Loss: 0.346377
# epoch 32/70 (Val) Average Estimation Loss (in Source domain): 0.186830
# epoch 32/70 (Val) Average Domain Discrimination Loss: 0.244244
# epoch 32/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.505925
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 3540.925308255013 seconds
# epoch 33/70 Average Training Loss: 0.372714
# epoch 33/70 Average Estimation Loss (in Source domain): 0.172366
# epoch 33/70 Average Domain Discrimination Loss: 2.776992
# epoch 33/70 For observation only - Average Estimation Loss in Target domain: 0.487733
# epoch 33/70 (Val) Average Validating Loss: 0.350968
# epoch 33/70 (Val) Average Estimation Loss (in Source domain): 0.190938
# epoch 33/70 (Val) Average Domain Discrimination Loss: 0.331697
# epoch 33/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.510999
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 3647.904390092939 seconds
# epoch 34/70 Average Training Loss: 0.425737
# epoch 34/70 Average Estimation Loss (in Source domain): 0.171906
# epoch 34/70 Average Domain Discrimination Loss: 3.309957
# epoch 34/70 For observation only - Average Estimation Loss in Target domain: 0.488348
# epoch 34/70 (Val) Average Validating Loss: 0.366121
# epoch 34/70 (Val) Average Estimation Loss (in Source domain): 0.193773
# epoch 34/70 (Val) Average Domain Discrimination Loss: 0.308052
# epoch 34/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.538469
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 3755.741987761925 seconds
# epoch 35/70
# Fitting IncrementalPCA on batches from features_source.h5 and features_target.h5
# Fitted PCA on batch: source 256/1840, target 256/1840
# Fitted PCA on batch: source 512/1840, target 512/1840
# Fitted PCA on batch: source 768/1840, target 768/1840
# Fitted PCA on batch: source 1024/1840, target 1024/1840
# Fitted PCA on batch: source 1280/1840, target 1280/1840
# Fitted PCA on batch: source 1536/1840, target 1536/1840
# Fitted PCA on batch: source 1792/1840, target 1792/1840
# Fitted PCA on batch: source 2048/1840, target 2048/1840
# Reduced source shape: (1840, 50), target shape: (1840, 50)
# == C: 0.01, Error rate: 0.2522
# == C: 0.1, Error rate: 0.1739
# == C: 0.5, Error rate: 0.0853
# == C: 1.0, Error rate: 0.0549
# == C: 2.0, Error rate: 0.0299
# == C: 5.0, Error rate: 0.0239
# == C: 10.0, Error rate: 0.0212
# == C: 50.0, Error rate: 0.0158
# == C: 100.0, Error rate: 0.0130
# == C: 500.0, Error rate: 0.0054
# == C: 1000.0, Error rate: 0.0060
# Best C: 500.0, Best error rate: 0.0054
# ============ PAD (SVM, batch PCA) = 1.9783
# Time 3777.2494565759553 seconds
# epoch 35/70 Average Training Loss: 0.507775
# epoch 35/70 Average Estimation Loss (in Source domain): 0.171003
# epoch 35/70 Average Domain Discrimination Loss: 4.135423
# epoch 35/70 For observation only - Average Estimation Loss in Target domain: 0.487705
# epoch 35/70 (Val) Average Validating Loss: 0.346324
# epoch 35/70 (Val) Average Estimation Loss (in Source domain): 0.194516
# epoch 35/70 (Val) Average Domain Discrimination Loss: 0.306260
# epoch 35/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.498133
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 3884.005307927029 seconds
# epoch 36/70 Average Training Loss: 0.450201
# epoch 36/70 Average Estimation Loss (in Source domain): 0.170335
# epoch 36/70 Average Domain Discrimination Loss: 3.563437
# epoch 36/70 For observation only - Average Estimation Loss in Target domain: 0.490132
# epoch 36/70 (Val) Average Validating Loss: 0.352298
# epoch 36/70 (Val) Average Estimation Loss (in Source domain): 0.199703
# epoch 36/70 (Val) Average Domain Discrimination Loss: 0.216199
# epoch 36/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.504893
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 3990.859918967006 seconds
# epoch 37/70 Average Training Loss: 0.438305
# epoch 37/70 Average Estimation Loss (in Source domain): 0.169795
# epoch 37/70 Average Domain Discrimination Loss: 3.447605
# epoch 37/70 For observation only - Average Estimation Loss in Target domain: 0.583837
# epoch 37/70 (Val) Average Validating Loss: 0.366252
# epoch 37/70 (Val) Average Estimation Loss (in Source domain): 0.202073
# epoch 37/70 (Val) Average Domain Discrimination Loss: 0.235476
# epoch 37/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.530431
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 4097.526455083978 seconds
# epoch 38/70 Average Training Loss: 0.587145
# epoch 38/70 Average Estimation Loss (in Source domain): 0.169158
# epoch 38/70 Average Domain Discrimination Loss: 4.939687
# epoch 38/70 For observation only - Average Estimation Loss in Target domain: 0.534420
# epoch 38/70 (Val) Average Validating Loss: 0.371190
# epoch 38/70 (Val) Average Estimation Loss (in Source domain): 0.202978
# epoch 38/70 (Val) Average Domain Discrimination Loss: 0.549375
# epoch 38/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.539403
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 4204.283657116932 seconds
# epoch 39/70 Average Training Loss: 0.523188
# epoch 39/70 Average Estimation Loss (in Source domain): 0.168401
# epoch 39/70 Average Domain Discrimination Loss: 4.304329
# epoch 39/70 For observation only - Average Estimation Loss in Target domain: 0.553895
# epoch 39/70 (Val) Average Validating Loss: 0.373682
# epoch 39/70 (Val) Average Estimation Loss (in Source domain): 0.204762
# epoch 39/70 (Val) Average Domain Discrimination Loss: 0.529771
# epoch 39/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.542601
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 4311.081191443023 seconds
# epoch 40/70 Average Training Loss: 0.524879
# epoch 40/70 Average Estimation Loss (in Source domain): 0.167995
# epoch 40/70 Average Domain Discrimination Loss: 4.323731
# epoch 40/70 For observation only - Average Estimation Loss in Target domain: 0.529024
# epoch 40/70 (Val) Average Validating Loss: 0.370578
# epoch 40/70 (Val) Average Estimation Loss (in Source domain): 0.205387
# epoch 40/70 (Val) Average Domain Discrimination Loss: 0.586311
# epoch 40/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.535769
# Model saved at epoch 40 to /home/thien/Code/H_predict_UDA/H_predict_Sionna/Domain_Adaptation/Domain_Adversarial/model/CNN/ver18_/FiLM/epoch_40
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 4418.15055931895 seconds
# epoch 41/70 Average Training Loss: 0.875822
# epoch 41/70 Average Estimation Loss (in Source domain): 0.167541
# epoch 41/70 Average Domain Discrimination Loss: 7.835918
# epoch 41/70 For observation only - Average Estimation Loss in Target domain: 0.637000
# Unpack H_sample and save for visualization
# epoch 41/70 (Val) Average Validating Loss: 0.414933
# epoch 41/70 (Val) Average Estimation Loss (in Source domain): 0.205487
# epoch 41/70 (Val) Average Domain Discrimination Loss: 0.549244
# epoch 41/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.624379
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 4525.67311389104 seconds
# epoch 42/70 Average Training Loss: 1.015457
# epoch 42/70 Average Estimation Loss (in Source domain): 0.167397
# epoch 42/70 Average Domain Discrimination Loss: 9.233512
# epoch 42/70 For observation only - Average Estimation Loss in Target domain: 0.596250
# epoch 42/70 (Val) Average Validating Loss: 0.408885
# epoch 42/70 (Val) Average Estimation Loss (in Source domain): 0.204084
# epoch 42/70 (Val) Average Domain Discrimination Loss: 1.435586
# epoch 42/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.613685
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 4632.731932500028 seconds
# epoch 43/70 Average Training Loss: 1.325935
# epoch 43/70 Average Estimation Loss (in Source domain): 0.167219
# epoch 43/70 Average Domain Discrimination Loss: 12.339596
# epoch 43/70 For observation only - Average Estimation Loss in Target domain: 0.590073
# epoch 43/70 (Val) Average Validating Loss: 0.425406
# epoch 43/70 (Val) Average Estimation Loss (in Source domain): 0.205336
# epoch 43/70 (Val) Average Domain Discrimination Loss: 0.789773
# epoch 43/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.645476
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 4739.9232996769715 seconds
# epoch 44/70 Average Training Loss: 1.198717
# epoch 44/70 Average Estimation Loss (in Source domain): 0.166176
# epoch 44/70 Average Domain Discrimination Loss: 11.072849
# epoch 44/70 For observation only - Average Estimation Loss in Target domain: 0.650543
# epoch 44/70 (Val) Average Validating Loss: 0.500096
# epoch 44/70 (Val) Average Estimation Loss (in Source domain): 0.207858
# epoch 44/70 (Val) Average Domain Discrimination Loss: 2.491908
# epoch 44/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.792333
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 4847.130458769971 seconds
# epoch 45/70 Average Training Loss: 2.187439
# epoch 45/70 Average Estimation Loss (in Source domain): 0.166288
# epoch 45/70 Average Domain Discrimination Loss: 20.960012
# epoch 45/70 For observation only - Average Estimation Loss in Target domain: 0.809286
# epoch 45/70 (Val) Average Validating Loss: 0.614829
# epoch 45/70 (Val) Average Estimation Loss (in Source domain): 0.210171
# epoch 45/70 (Val) Average Domain Discrimination Loss: 1.034268
# epoch 45/70 (Val) For observation only - Average Estimation Loss in Target domain: 1.019488
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 4954.311487401021 seconds
# epoch 46/70 Average Training Loss: 1.429167
# epoch 46/70 Average Estimation Loss (in Source domain): 0.166000
# epoch 46/70 Average Domain Discrimination Loss: 13.379025
# epoch 46/70 For observation only - Average Estimation Loss in Target domain: 0.804204
# epoch 46/70 (Val) Average Validating Loss: 0.553027
# epoch 46/70 (Val) Average Estimation Loss (in Source domain): 0.209245
# epoch 46/70 (Val) Average Domain Discrimination Loss: 0.689441
# epoch 46/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.896809
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 5061.349327219999 seconds
# epoch 47/70 Average Training Loss: 1.573620
# epoch 47/70 Average Estimation Loss (in Source domain): 0.165294
# epoch 47/70 Average Domain Discrimination Loss: 14.827485
# epoch 47/70 For observation only - Average Estimation Loss in Target domain: 0.754473
# epoch 47/70 (Val) Average Validating Loss: 0.524700
# epoch 47/70 (Val) Average Estimation Loss (in Source domain): 0.210270
# epoch 47/70 (Val) Average Domain Discrimination Loss: 1.000705
# epoch 47/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.839129
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 5168.566717754002 seconds
# epoch 48/70 Average Training Loss: 1.202505
# epoch 48/70 Average Estimation Loss (in Source domain): 0.165279
# epoch 48/70 Average Domain Discrimination Loss: 11.116728
# epoch 48/70 For observation only - Average Estimation Loss in Target domain: 0.695448
# epoch 48/70 (Val) Average Validating Loss: 0.514096
# epoch 48/70 (Val) Average Estimation Loss (in Source domain): 0.207597
# epoch 48/70 (Val) Average Domain Discrimination Loss: 0.710058
# epoch 48/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.820596
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 5275.906819605036 seconds
# epoch 49/70 Average Training Loss: 1.526259
# epoch 49/70 Average Estimation Loss (in Source domain): 0.164677
# epoch 49/70 Average Domain Discrimination Loss: 14.357592
# epoch 49/70 For observation only - Average Estimation Loss in Target domain: 0.707920
# epoch 49/70 (Val) Average Validating Loss: 0.536475
# epoch 49/70 (Val) Average Estimation Loss (in Source domain): 0.205356
# epoch 49/70 (Val) Average Domain Discrimination Loss: 1.871130
# epoch 49/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.867593
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 5383.034378450946 seconds
# epoch 50/70 Average Training Loss: 3.032729
# epoch 50/70 Average Estimation Loss (in Source domain): 0.166109
# epoch 50/70 Average Domain Discrimination Loss: 29.415428
# epoch 50/70 For observation only - Average Estimation Loss in Target domain: 0.646322
# epoch 50/70 (Val) Average Validating Loss: 0.538348
# epoch 50/70 (Val) Average Estimation Loss (in Source domain): 0.205578
# epoch 50/70 (Val) Average Domain Discrimination Loss: 1.676351
# epoch 50/70 (Val) For observation only - Average Estimation Loss in Target domain: 0.871118
# Model saved at epoch 50 to /home/thien/Code/H_predict_UDA/H_predict_Sionna/Domain_Adaptation/Domain_Adversarial/model/CNN/ver18_/FiLM/epoch_50
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 5490.51399168896 seconds
# epoch 51/70 Average Training Loss: 3.781257
# epoch 51/70 Average Estimation Loss (in Source domain): 0.165016
# epoch 51/70 Average Domain Discrimination Loss: 36.906464
# epoch 51/70 For observation only - Average Estimation Loss in Target domain: 0.699539
# Unpack H_sample and save for visualization
# /home/thien/Code/H_predict_UDA/H_predict_Sionna/Est_btween_CSIRS/helper/plotfig.py:50: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(10, 5))
# epoch 51/70 (Val) Average Validating Loss: 0.645817
# epoch 51/70 (Val) Average Estimation Loss (in Source domain): 0.202592
# epoch 51/70 (Val) Average Domain Discrimination Loss: 1.580302
# epoch 51/70 (Val) For observation only - Average Estimation Loss in Target domain: 1.089042
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 5598.245809827 seconds
# epoch 52/70 Average Training Loss: 3.219163
# epoch 52/70 Average Estimation Loss (in Source domain): 0.164931
# epoch 52/70 Average Domain Discrimination Loss: 31.286339
# epoch 52/70 For observation only - Average Estimation Loss in Target domain: 0.750717
# epoch 52/70 (Val) Average Validating Loss: 0.641915
# epoch 52/70 (Val) Average Estimation Loss (in Source domain): 0.198717
# epoch 52/70 (Val) Average Domain Discrimination Loss: 1.783169
# epoch 52/70 (Val) For observation only - Average Estimation Loss in Target domain: 1.085113
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 5705.12196956994 seconds
# epoch 53/70 Average Training Loss: 3.874057
# epoch 53/70 Average Estimation Loss (in Source domain): 0.164434
# epoch 53/70 Average Domain Discrimination Loss: 37.837982
# epoch 53/70 For observation only - Average Estimation Loss in Target domain: 0.805497
# epoch 53/70 (Val) Average Validating Loss: 0.694970
# epoch 53/70 (Val) Average Estimation Loss (in Source domain): 0.197352
# epoch 53/70 (Val) Average Domain Discrimination Loss: 0.975591
# epoch 53/70 (Val) For observation only - Average Estimation Loss in Target domain: 1.192588
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 5812.092869866989 seconds
# epoch 54/70 Average Training Loss: 3.626279
# epoch 54/70 Average Estimation Loss (in Source domain): 0.164133
# epoch 54/70 Average Domain Discrimination Loss: 35.361893
# epoch 54/70 For observation only - Average Estimation Loss in Target domain: 0.859286
# epoch 54/70 (Val) Average Validating Loss: 0.711317
# epoch 54/70 (Val) Average Estimation Loss (in Source domain): 0.195953
# epoch 54/70 (Val) Average Domain Discrimination Loss: 0.883945
# epoch 54/70 (Val) For observation only - Average Estimation Loss in Target domain: 1.226682
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 5918.924267797964 seconds
# epoch 55/70 Average Training Loss: 3.986765
# epoch 55/70 Average Estimation Loss (in Source domain): 0.164539
# epoch 55/70 Average Domain Discrimination Loss: 38.965115
# epoch 55/70 For observation only - Average Estimation Loss in Target domain: 0.922488
# epoch 55/70 (Val) Average Validating Loss: 0.742091
# epoch 55/70 (Val) Average Estimation Loss (in Source domain): 0.197107
# epoch 55/70 (Val) Average Domain Discrimination Loss: 0.909182
# epoch 55/70 (Val) For observation only - Average Estimation Loss in Target domain: 1.287075
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 6025.921478527016 seconds
# epoch 56/70 Average Training Loss: 4.720157
# epoch 56/70 Average Estimation Loss (in Source domain): 0.163811
# epoch 56/70 Average Domain Discrimination Loss: 46.302849
# epoch 56/70 For observation only - Average Estimation Loss in Target domain: 0.907309
# epoch 56/70 (Val) Average Validating Loss: 0.808306
# epoch 56/70 (Val) Average Estimation Loss (in Source domain): 0.197602
# epoch 56/70 (Val) Average Domain Discrimination Loss: 1.896088
# epoch 56/70 (Val) For observation only - Average Estimation Loss in Target domain: 1.419010
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 6133.312813787023 seconds
# epoch 57/70 Average Training Loss: 4.384650
# epoch 57/70 Average Estimation Loss (in Source domain): 0.163426
# epoch 57/70 Average Domain Discrimination Loss: 42.950180
# epoch 57/70 For observation only - Average Estimation Loss in Target domain: 0.904041
# epoch 57/70 (Val) Average Validating Loss: 0.885871
# epoch 57/70 (Val) Average Estimation Loss (in Source domain): 0.196187
# epoch 57/70 (Val) Average Domain Discrimination Loss: 1.834710
# epoch 57/70 (Val) For observation only - Average Estimation Loss in Target domain: 1.575555
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 6240.564854155993 seconds
# epoch 58/70 Average Training Loss: 4.657803
# epoch 58/70 Average Estimation Loss (in Source domain): 0.163063
# epoch 58/70 Average Domain Discrimination Loss: 45.683517
# epoch 58/70 For observation only - Average Estimation Loss in Target domain: 1.200102
# epoch 58/70 (Val) Average Validating Loss: 0.995565
# epoch 58/70 (Val) Average Estimation Loss (in Source domain): 0.194929
# epoch 58/70 (Val) Average Domain Discrimination Loss: 1.901066
# epoch 58/70 (Val) For observation only - Average Estimation Loss in Target domain: 1.796202
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 6347.733265524032 seconds
# epoch 59/70 Average Training Loss: 6.170358
# epoch 59/70 Average Estimation Loss (in Source domain): 0.162728
# epoch 59/70 Average Domain Discrimination Loss: 60.811180
# epoch 59/70 For observation only - Average Estimation Loss in Target domain: 1.210649
# epoch 59/70 (Val) Average Validating Loss: 1.047318
# epoch 59/70 (Val) Average Estimation Loss (in Source domain): 0.194891
# epoch 59/70 (Val) Average Domain Discrimination Loss: 5.355464
# epoch 59/70 (Val) For observation only - Average Estimation Loss in Target domain: 1.899745
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 6454.685436210013 seconds
# epoch 60/70 Average Training Loss: 8.591300
# epoch 60/70 Average Estimation Loss (in Source domain): 0.163840
# epoch 60/70 Average Domain Discrimination Loss: 85.015167
# epoch 60/70 For observation only - Average Estimation Loss in Target domain: 1.290991
# epoch 60/70 (Val) Average Validating Loss: 1.128398
# epoch 60/70 (Val) Average Estimation Loss (in Source domain): 0.196983
# epoch 60/70 (Val) Average Domain Discrimination Loss: 5.586050
# epoch 60/70 (Val) For observation only - Average Estimation Loss in Target domain: 2.059813
# Model saved at epoch 60 to /home/thien/Code/H_predict_UDA/H_predict_Sionna/Domain_Adaptation/Domain_Adversarial/model/CNN/ver18_/FiLM/epoch_60
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 6562.22795387404 seconds
# epoch 61/70 Average Training Loss: 8.316585
# epoch 61/70 Average Estimation Loss (in Source domain): 0.162923
# epoch 61/70 Average Domain Discrimination Loss: 82.272881
# epoch 61/70 For observation only - Average Estimation Loss in Target domain: 1.453658
# Unpack H_sample and save for visualization
# epoch 61/70 (Val) Average Validating Loss: 1.314158
# epoch 61/70 (Val) Average Estimation Loss (in Source domain): 0.195189
# epoch 61/70 (Val) Average Domain Discrimination Loss: 3.560858
# epoch 61/70 (Val) For observation only - Average Estimation Loss in Target domain: 2.433126
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 6669.5107823419385 seconds
# epoch 62/70 Average Training Loss: 7.061053
# epoch 62/70 Average Estimation Loss (in Source domain): 0.162890
# epoch 62/70 Average Domain Discrimination Loss: 69.718056
# epoch 62/70 For observation only - Average Estimation Loss in Target domain: 1.345250
# epoch 62/70 (Val) Average Validating Loss: 1.251055
# epoch 62/70 (Val) Average Estimation Loss (in Source domain): 0.192847
# epoch 62/70 (Val) Average Domain Discrimination Loss: 2.158733
# epoch 62/70 (Val) For observation only - Average Estimation Loss in Target domain: 2.309263
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 6776.108796939021 seconds
# epoch 63/70 Average Training Loss: 10.945942
# epoch 63/70 Average Estimation Loss (in Source domain): 0.163700
# epoch 63/70 Average Domain Discrimination Loss: 108.563232
# epoch 63/70 For observation only - Average Estimation Loss in Target domain: 1.642784
# epoch 63/70 (Val) Average Validating Loss: 1.949194
# epoch 63/70 (Val) Average Estimation Loss (in Source domain): 0.196568
# epoch 63/70 (Val) Average Domain Discrimination Loss: 5.712851
# epoch 63/70 (Val) For observation only - Average Estimation Loss in Target domain: 3.701820
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 6882.933861425961 seconds
# epoch 64/70 Average Training Loss: 16.888884
# epoch 64/70 Average Estimation Loss (in Source domain): 0.165146
# epoch 64/70 Average Domain Discrimination Loss: 167.985596
# epoch 64/70 For observation only - Average Estimation Loss in Target domain: 1.558682
# epoch 64/70 (Val) Average Validating Loss: 1.167818
# epoch 64/70 (Val) Average Estimation Loss (in Source domain): 0.196310
# epoch 64/70 (Val) Average Domain Discrimination Loss: 6.694126
# epoch 64/70 (Val) For observation only - Average Estimation Loss in Target domain: 2.139325
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 6990.045013761963 seconds
# epoch 65/70 Average Training Loss: 19.008333
# epoch 65/70 Average Estimation Loss (in Source domain): 0.165426
# epoch 65/70 Average Domain Discrimination Loss: 189.178619
# epoch 65/70 For observation only - Average Estimation Loss in Target domain: 1.624564
# epoch 65/70 (Val) Average Validating Loss: 1.765406
# epoch 65/70 (Val) Average Estimation Loss (in Source domain): 0.194144
# epoch 65/70 (Val) Average Domain Discrimination Loss: 5.166169
# epoch 65/70 (Val) For observation only - Average Estimation Loss in Target domain: 3.336667
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 7097.145259866957 seconds
# epoch 66/70 Average Training Loss: 18.300089
# epoch 66/70 Average Estimation Loss (in Source domain): 0.165968
# epoch 66/70 Average Domain Discrimination Loss: 182.093796
# epoch 66/70 For observation only - Average Estimation Loss in Target domain: 1.818635
# epoch 66/70 (Val) Average Validating Loss: 1.828279
# epoch 66/70 (Val) Average Estimation Loss (in Source domain): 0.195583
# epoch 66/70 (Val) Average Domain Discrimination Loss: 4.681647
# epoch 66/70 (Val) For observation only - Average Estimation Loss in Target domain: 3.460975
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 7204.12041286903 seconds
# epoch 67/70 Average Training Loss: 29.851734
# epoch 67/70 Average Estimation Loss (in Source domain): 0.164463
# epoch 67/70 Average Domain Discrimination Loss: 297.617920
# epoch 67/70 For observation only - Average Estimation Loss in Target domain: 1.895170
# epoch 67/70 (Val) Average Validating Loss: 1.622946
# epoch 67/70 (Val) Average Estimation Loss (in Source domain): 0.194531
# epoch 67/70 (Val) Average Domain Discrimination Loss: 19.841734
# epoch 67/70 (Val) For observation only - Average Estimation Loss in Target domain: 3.051360
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 7310.935428255936 seconds
# epoch 68/70 Average Training Loss: 39.455692
# epoch 68/70 Average Estimation Loss (in Source domain): 0.163477
# epoch 68/70 Average Domain Discrimination Loss: 393.662598
# epoch 68/70 For observation only - Average Estimation Loss in Target domain: 1.676764
# epoch 68/70 (Val) Average Validating Loss: 1.356094
# epoch 68/70 (Val) Average Estimation Loss (in Source domain): 0.191095
# epoch 68/70 (Val) Average Domain Discrimination Loss: 10.138662
# epoch 68/70 (Val) For observation only - Average Estimation Loss in Target domain: 2.521093
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 7418.0491514099995 seconds
# epoch 69/70 Average Training Loss: 32.550591
# epoch 69/70 Average Estimation Loss (in Source domain): 0.162258
# epoch 69/70 Average Domain Discrimination Loss: 324.617920
# epoch 69/70 For observation only - Average Estimation Loss in Target domain: 1.603755
# epoch 69/70 (Val) Average Validating Loss: 1.445336
# epoch 69/70 (Val) Average Estimation Loss (in Source domain): 0.190784
# epoch 69/70 (Val) Average Domain Discrimination Loss: 12.806220
# epoch 69/70 (Val) For observation only - Average Estimation Loss in Target domain: 2.699888
# batch_idx: 1/115
# batch_idx: 21/115
# batch_idx: 41/115
# batch_idx: 61/115
# batch_idx: 81/115
# batch_idx: 101/115
# batch_idx: 115/115
# Time 7525.998330818955 seconds
# epoch 70/70
# Fitting IncrementalPCA on batches from features_source.h5 and features_target.h5
# Fitted PCA on batch: source 256/1840, target 256/1840
# Fitted PCA on batch: source 512/1840, target 512/1840
# Fitted PCA on batch: source 768/1840, target 768/1840
# Fitted PCA on batch: source 1024/1840, target 1024/1840
# Fitted PCA on batch: source 1280/1840, target 1280/1840
# Fitted PCA on batch: source 1536/1840, target 1536/1840
# Fitted PCA on batch: source 1792/1840, target 1792/1840
# Fitted PCA on batch: source 2048/1840, target 2048/1840
# Reduced source shape: (1840, 50), target shape: (1840, 50)
# == C: 0.01, Error rate: 0.2625
# == C: 0.1, Error rate: 0.1723
# == C: 0.5, Error rate: 0.0592
# == C: 1.0, Error rate: 0.0424
# == C: 2.0, Error rate: 0.0250
# == C: 5.0, Error rate: 0.0190
# == C: 10.0, Error rate: 0.0168
# == C: 50.0, Error rate: 0.0158
# == C: 100.0, Error rate: 0.0136
# == C: 500.0, Error rate: 0.0065
# == C: 1000.0, Error rate: 0.0054
# Best C: 1000.0, Best error rate: 0.0054
# ============ PAD (SVM, batch PCA) = 1.9783
# Time 7547.063723869971 seconds
# epoch 70/70 Average Training Loss: 37.568268
# epoch 70/70 Average Estimation Loss (in Source domain): 0.161962
# epoch 70/70 Average Domain Discrimination Loss: 374.796356
# epoch 70/70 For observation only - Average Estimation Loss in Target domain: 1.568755
# Unpack H_sample and save for visualization
# epoch 70/70 (Val) Average Validating Loss: 1.246747
# epoch 70/70 (Val) Average Estimation Loss (in Source domain): 0.189808
# epoch 70/70 (Val) Average Domain Discrimination Loss: 16.423151
# epoch 70/70 (Val) For observation only - Average Estimation Loss in Target domain: 2.303686
# Model saved at epoch 70 to /home/thien/Code/H_predict_UDA/H_predict_Sionna/Domain_Adaptation/Domain_Adversarial/model/CNN/ver18_/FiLM/epoch_70

# %%
print(perform_to_save['pad'])
print(perform_to_save['epoc_pad'])
# Out:
# [1.9782608695652173, 1.9782608695652173]
# [34, 69]

# %%
nmse_val_source[:10]
# Out:
# [np.float32(0.77908045),
#  np.float32(0.76477724),
#  np.float32(0.7688697),
#  np.float32(0.7729806),
#  np.float32(0.77011913),
#  np.float32(0.77068245),
#  np.float32(0.77289575),
#  np.float32(0.7735989),
#  np.float32(0.7739618),
#  np.float32(0.77390224)]

# %%
plotfig.figLoss(line_list=[(nmse_val_source, 'Source Domain'), (nmse_val_target, 'Target Domain'), (nmse_val, 'Average')], xlabel='Epoch', ylabel='NMSE',
                        title='NMSE in Validation', index_save=1, fig_show=True, fig_name='NMSE_val')

# %%
plotfig.figLoss(line_list=[(nmse_val_source, 'Source Domain')], xlabel='Epoch', ylabel='NMSE',
                        title='NMSE in Validation in Source Domain', index_save=1, fig_show=True, fig_name='NMSE_val')
