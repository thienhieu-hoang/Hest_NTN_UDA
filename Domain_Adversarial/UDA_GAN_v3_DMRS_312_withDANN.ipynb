# %%
import tensorflow as tf

import os
import sys
import numpy as np
from scipy.io import savemat
from sklearn.linear_model import SGDClassifier

# os.environ["CUDA_VISIBLE_DEVICES"] = "1"
sys.path.append(os.path.abspath('helper'))
# import utils
# import loader
import utils_GAN, PAD, utils_GAN_FiLM
# Out:
# 2025-09-05 10:19:54.238211: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757081994.252443    7012 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757081994.256763    7012 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1757081994.267703    7012 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757081994.267718    7012 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757081994.267720    7012 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757081994.267721    7012 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-09-05 10:19:54.271472: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
notebook_dir = os.getcwd()
print(notebook_dir)
print(os.path.abspath(os.path.join(notebook_dir, '..', '..')))
sys.path.append(os.path.abspath(os.path.join(notebook_dir, '..', '..')))
import Est_btween_CSIRS.helper.utils as utils_CNN
import Est_btween_CSIRS.helper.loader as loader
import Est_btween_CSIRS.helper.plotfig as plotfig
# Out:
# /home/thien/Code/H_predict_UDA/H_predict_Sionna/Domain_Adaptation/Domain_Adversarial
# /home/thien/Code/H_predict_UDA/H_predict_Sionna

# %%
# Generate a (16, 792, 14, 2) matrix with random values
random_matrix = np.random.randn(16, 312, 14, 2)
random_matrix.shape

GAN_model = utils_GAN.GAN(n_subc=312)
out_put = GAN_model(random_matrix)
print(out_put.gen_out.shape)
print(out_put.disc_out.shape)
print(out_put.extracted_features.shape)
# Out:
# I0000 00:00:1757081998.513466    7012 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9543 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:1a:00.0, compute capability: 7.5
# I0000 00:00:1757081998.514061    7012 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 9543 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:67:00.0, compute capability: 7.5
# I0000 00:00:1757081998.514530    7012 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 9380 MB memory:  -> device: 2, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:68:00.0, compute capability: 7.5
# I0000 00:00:1757082000.935404    7012 cuda_dnn.cc:529] Loaded cuDNN version 90300
# (16, 312, 14, 2)
# (16, 8, 4, 1)
# (16, 18, 14, 512)

# %%
source_data_file_path = os.path.abspath(os.path.join(notebook_dir, '..', '..', 'Generate_Data', 'CDL_Channel', 'generatedChannel', 'ver9_', '-15dB', 'mapBaseData.mat'))
# target_data_file_path = os.path.abspath(os.path.join(notebook_dir, '..', '..', 'Generate_Data', 'Sionna', 'generatedChannel', 'ver6_', 'sionnaTrue.mat'))
target_data_file_path = os.path.abspath(os.path.join(notebook_dir, '..', '..', 'Generate_Data', 'Sionna', 'generatedChannel', 'ver7_', '-15dB', 'sionnaTrue.mat'))

# %%
norm_approach = 'minmax' # can be set to 'std'
lower_range = -1 
    # if norm_approach = 'minmax': 
        # =  0 for scaling to  [0 1]
        # = -1 for scaling to [-1 1]
    # if norm_approach = 'std': can be any value, but need to be defined
adv_weight=0.005
est_weight=1
domain_weight=0.5  # for Domain Discriminator, 0 for no Domain Discriminator

# snr_start = -25
# snr_step = 5
# snr_end = 25
# SNR = np.arange(snr_start, snr_end+1, snr_step)

# SNR = np.array([0])

# if len(SNR) >1:
#     SNR_txt = f'{snr_start}:{snr_step}:{snr_end}'
# else:
#     SNR_txt = f'{SNR[0]}'
    
# ============ CNN settings ==============
if norm_approach == 'minmax':
    if lower_range == 0:
        norm_txt = 'Using min-max [0 1]'
    elif lower_range ==-1:
        norm_txt = 'Using min-max [-1 1]'
elif norm_approach == 'no':
    norm_txt = 'No'
    
CNN_activation = 'Tanh'
CNN_DropOut = 0.2
if CNN_DropOut != 0:
    dropOut_txt = f'Add p={CNN_DropOut} DropOut'
    
# ============ Adversarial for Domain Discriminator settings ==============
    
    
# # create readme.txt file
# content = f"""Generated by file 'Domain_Adversarial/UDA_CNN_v3.ipynb'.
# 28 GHz fc,
# Source dataset got from {source_data_file_path},
# Target dataset got from {target_data_file_path},
# Learning rate {learning_rate},
# {norm_txt} scaler for each sample
# Using {CNN_activation} as activation function of CNN
# {dropOut_txt}
# ========= For Domain Discriminator ==========
# Extract features after layer {extract_layer} of CNN
# {text_lambda}
# """

# %%
# Paths to save
idx_save_path = loader.find_incremental_filename(notebook_dir + '/model/GAN','ver', '_', '')

save_model = 0
model_path = notebook_dir + '/model/GAN/ver' + str(idx_save_path) + '_'
# figure_path = notebook_dir + '/model/GAN/ver' + str(idx_save_path) + '_/figure'
model_readme = model_path + '/readme.txt'
# figure_readme = figure_path + '/readme.txt'

# if not os.path.exists(os.path.dirname(model_readme)):
#     os.makedirs(os.path.dirname(model_readme))
# # if not os.path.exists(os.path.dirname(figure_readme)):
# #     os.makedirs(os.path.dirname(figure_readme))

# # Open the file in write mode ('w'). If the file does not exist, it will be created.
# with open(model_readme, 'w') as file:
#     # Write the content to the file
#     file.write(content)

# # with open(figure_readme, 'w') as file:
# #     # Write the content to the file
# #     file.write(content)

# print(f"File '{model_readme}'  created and content written.")

# %%
import h5py

batch_size=16

# ============ Source data ==============
source_file = h5py.File(source_data_file_path, 'r')
H_true_source = source_file['H_true']
N_samp_source = H_true_source.shape[0]
print('N_samp_source = ', N_samp_source)

# ============ Target data ==============
target_file = h5py.File(target_data_file_path, 'r')
H_true_target = target_file['H_true']
N_samp_target = H_true_target.shape[0]
print('N_samp_target = ', N_samp_target)
# Out:
# N_samp_source =  2048
# N_samp_target =  2048

# %%
indices_source = np.arange(N_samp_source)
np.random.shuffle(indices_source)
indices_target = np.arange(N_samp_target)
np.random.shuffle(indices_target)
#
train_size = int(np.floor(N_samp_source * 0.9) // batch_size * batch_size)
val_size = N_samp_source - train_size

# Repeat the indices to match the maximum number of samples
N_samp = max(N_samp_source, N_samp_target) 
indices_source = np.resize(indices_source, N_samp)
indices_target = np.resize(indices_target, N_samp)

# =======================================================
## Divide the indices into training and validation sets
indices_train_source = indices_source[:train_size]
indices_val_source   = indices_source[train_size:train_size + val_size]

indices_train_target = indices_target[:train_size]
indices_val_target   = indices_target[train_size:train_size + val_size]

# to test code
# indices_train_source = indices_source[:96]
# indices_val_source = indices_source[2032:]
# indices_train_target = indices_target[:96]
# indices_val_target = indices_target[2032:]

print('train_size = ', indices_train_source.shape[0])
print('val_size = ', indices_val_source.shape[0])
# Out:
# train_size =  1840
# val_size =  208

# %%
# =========== Source dataset ==============
loader_H_true_train_source = utils_CNN.H5BatchLoader(source_file, dataset_name='H_true', batch_size=batch_size, shuffled_indices=indices_train_source)
loader_H_practical_train_source = utils_CNN.H5BatchLoader(source_file, 'H_practical_save', batch_size=batch_size, shuffled_indices=indices_train_source)
loader_H_linear_train_source = utils_CNN.H5BatchLoader(source_file, 'H_linear_save', batch_size=batch_size, shuffled_indices=indices_train_source)

loader_H_true_val_source = utils_CNN.H5BatchLoader(source_file, dataset_name='H_true', batch_size=batch_size, shuffled_indices=indices_val_source)
loader_H_practical_val_source = utils_CNN.H5BatchLoader(source_file, 'H_practical_save', batch_size=batch_size, shuffled_indices=indices_val_source)
loader_H_linear_val_source = utils_CNN.H5BatchLoader(source_file, 'H_linear_save', batch_size=batch_size, shuffled_indices=indices_val_source)


# =========== Target dataset ==============
loader_H_true_train_target = utils_CNN.H5BatchLoader(target_file, dataset_name='H_true', batch_size=batch_size, shuffled_indices=indices_train_target)
    # actually at target domain, we don't have true channels, just use this for evaluating the model
loader_H_practical_train_target = utils_CNN.H5BatchLoader(target_file, 'H_practical_save', batch_size=batch_size, shuffled_indices=indices_train_target)
    # channel at symbol 2 of slots 1,6,11 (channel corresponding to CSI-RS 1, 2)
loader_H_true_val_target = utils_CNN.H5BatchLoader(target_file, dataset_name='H_true', batch_size=batch_size, shuffled_indices=indices_val_target)
loader_H_practical_val_target = utils_CNN.H5BatchLoader(target_file, 'H_practical_save', batch_size=batch_size, shuffled_indices=indices_val_target)

print('size loader_H_true_train = ', loader_H_true_train_target.total_batches)
print('size loader_H_true_val = ', loader_H_true_val_target.total_batches)
# Out:
# size loader_H_true_train =  115
# size loader_H_true_val =  13

# %%
class DataLoaders:
    def __init__(self, file, indices_train, indices_val, tag='practical', batch_size=32):
        self.true_train = utils_CNN.H5BatchLoader(file, dataset_name='H_true', batch_size=batch_size, shuffled_indices=indices_train)
        self.true_val = utils_CNN.H5BatchLoader(file, dataset_name='H_true', batch_size=batch_size, shuffled_indices=indices_val)

        self.input_train = utils_CNN.H5BatchLoader(file, f'H_{tag}_save', batch_size=batch_size, shuffled_indices=indices_train)
        self.input_val = utils_CNN.H5BatchLoader(file, f'H_{tag}_save', batch_size=batch_size, shuffled_indices=indices_val)

# Source domain
class_dict_source = {
    'GAN_practical': DataLoaders(source_file, indices_train_source, indices_val_source, tag='practical', batch_size=batch_size),
    'GAN_linear': DataLoaders(source_file, indices_train_source, indices_val_source, tag='linear', batch_size=batch_size)
}

# Target domain
class_dict_target = {
    'GAN_practical': DataLoaders(target_file, indices_train_target, indices_val_target, tag='practical', batch_size=batch_size),
    'GAN_linear': DataLoaders(target_file, indices_train_target, indices_val_target, tag='linear', batch_size=batch_size)
}

# %%
# Calculate PAD for original datasets with SVM
# pad = PAD.original_PAD(loader_H_practical_train_source, loader_H_practical_train_target)
# print(f"PAD = {pad:.4f}")

# %%
loss_fn_ce = tf.keras.losses.MeanSquaredError()  # Channel estimation loss (generator loss)
loss_fn_bce = tf.keras.losses.BinaryCrossentropy(from_logits=False) # Binary cross-entropy loss for discriminator
loss_fn_domain = tf.keras.losses.BinaryCrossentropy()  # Domain classification loss

# %%
import time
start = time.perf_counter()

n_epochs= 300
epoch_min = 50
epoch_step = 100
# n_epochs= 3
# epoch_min = 0
# epoch_step = 1

sub_folder_ = ['GAN_practical'] # ['GAN_linear']  # ['GAN_linear', 'GAN_practical']

for sub_folder in sub_folder_:
    print(f"Processing: {sub_folder}")
    linear_interp = False
    if sub_folder == 'GAN_linear':
        linear_interp =True # flag to clip values that go beyond the estimated pilot (min, max)
    ##
    loader_H_true_train_source = class_dict_source[sub_folder].true_train
    loader_H_input_train_source = class_dict_source[sub_folder].input_train
    loader_H_true_val_source = class_dict_source[sub_folder].true_val
    loader_H_input_val_source = class_dict_source[sub_folder].input_val
    
    loader_H_true_train_target = class_dict_target[sub_folder].true_train
    loader_H_input_train_target = class_dict_target[sub_folder].input_train
    loader_H_true_val_target = class_dict_target[sub_folder].true_val
    loader_H_input_val_target = class_dict_target[sub_folder].input_val
    ##
    
    if not os.path.exists(os.path.dirname(model_path + '/' + sub_folder +'/')):
        os.makedirs(os.path.dirname(model_path + '/' + sub_folder + '/'))   # Domain_Adversarial/model/_/ver_/{sub_folder}

    train_loss          = [] # (epoch,1)
    train_est_loss      = [] 
    train_disc_loss     = [] 
    train_domain_loss   = []
    train_est_loss_target = []
    #    
    val_loss, val_gan_disc_loss, val_domain_disc_loss,\
    val_est_loss_source, val_est_loss_target, val_est_loss,\
    source_acc, target_acc, acc,\
    nmse_val_source, nmse_val_target, nmse_val = [[] for _ in range(12)]
    #
    H_to_save = {}          # list to save to .mat file for H
    perform_to_save = {}    # list to save to .mat file for nmse, losses,...

    model = utils_GAN.GAN(n_subc=312, gen_l2=None, disc_l2=1e-5)  # l2 regularization for generator and discriminator
    model_domain = utils_GAN_FiLM.DomainDiscriminator3()
    gen_optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4, beta_1=0.5, beta_2=0.9)
    disc_optimizer = tf.keras.optimizers.Adam(learning_rate=1e-5, beta_1=0.5, beta_2=0.9)  # WGAN-GP uses Adam optimizer with beta_1=0.5
    domain_optimizer = tf.keras.optimizers.Adam(learning_rate=5e-5)
    ####
    optimizer = [gen_optimizer, disc_optimizer, domain_optimizer]
    ####
    
    flag = 1 # flag to plot and save H_true
    pad_observe_svm = [] # pad observation over epochs
    pad_observe_lda = []
    pad_observe_logreg = []
    epoc_pad = []    # epochs that calculating pad (return_features == True)
    for epoch in range(n_epochs):
        # ===================== Training =====================
        loader_H_true_train_source.reset()
        # loader_H_practical_train_source.reset()
        loader_H_input_train_source.reset()
        loader_H_true_train_target.reset()
        # loader_H_practical_train_target.reset()
        loader_H_input_train_target.reset()
                
        # loader_H = [loader_H_practical_train_source, loader_H_true_train_source, loader_H_practical_train_target, loader_H_true_train_target]
        loader_H = [loader_H_input_train_source, loader_H_true_train_source, loader_H_input_train_target, loader_H_true_train_target]
        
        loss_fn = [loss_fn_ce, loss_fn_bce, loss_fn_domain]
    
        ##########################
        if epoch in [int(n_epochs * r) for r in [0, 0.25, 0.5, 0.75, 1.0]]:
            # return_features == return features to calculate PAD
            return_features = True
            epoc_pad.append(epoch)
        else:
            return_features = False

        ##########################
        train_step_output = utils_GAN.train_step_wgan_gp(model, model_domain, loader_H, loss_fn, optimizer, lower_range=-1,
                                adv_weight=adv_weight, est_weight=est_weight, domain_weight=domain_weight, return_features=return_features, linear_interp=linear_interp)
        
        train_epoc_loss_est        = train_step_output.avg_epoc_loss_est
        train_epoc_loss_d          = train_step_output.avg_epoc_loss_d
        train_epoc_loss_domain     = train_step_output.avg_epoc_loss_domain
        train_epoc_loss            = train_step_output.avg_epoc_loss
        train_epoc_loss_est_target = train_step_output.avg_epoc_loss_est_target
                # train_epoc_loss        = total train loss = loss_est + lambda_domain * domain_loss
                # train_epoc_loss_est    = loss in estimation network in source domain (labels available)
                # train_epoc_loss_domain = loss in domain discrimination network
                # train_epoc_loss_est_target - just to monitor - the machine can not calculate because no label available in source domain
                # All are already calculated in average over training dataset (source/target - respectively)
        print("Time", time.perf_counter() - start, "seconds")
        # Calculate PAD for the extracted features
        if return_features and (domain_weight!=0):
            features_source_file = "features_source.h5"
            features_target_file = "features_target.h5"
            print(f"epoch {epoch+1}/{n_epochs}")
            # pad_epoc_sgd  = PAD.cal_PAD_SGD(features_source_file, features_target_file)
            # pad_epoc  = PAD.cal_PAD2(features_source_file, features_target_file, pca_components=100, batch_size=128)
            X_features, y_features = PAD.extract_features_with_pca(features_source_file, features_target_file, pca_components=100)
            pad_svm_epoc = PAD.calc_pad_svm(X_features, y_features)
            pad_observe_svm.append(pad_svm_epoc)
            #
            pad_lda_epoc = PAD.calc_pad_lda(X_features, y_features)
            pad_observe_lda.append(pad_lda_epoc)
            #
            pad_logreg_epoc = PAD.calc_pad_logreg(X_features, y_features)
            pad_observe_logreg.append(pad_logreg_epoc)
            
            
            if os.path.exists(features_source_file):
                os.remove(features_source_file)
            if os.path.exists(features_target_file):
                os.remove(features_target_file)
            print("Time", time.perf_counter() - start, "seconds")
            
        
        # Average loss for the epoch
        train_loss.append(train_epoc_loss)
        print(f"epoch {epoch+1}/{n_epochs} Average Training Loss: {train_epoc_loss:.6f}")
        #
        train_est_loss.append(train_epoc_loss_est)
        print(f"epoch {epoch+1}/{n_epochs} Average Estimation Loss (in Source domain): {train_epoc_loss_est:.6f}")
        #
        train_disc_loss.append(train_epoc_loss_d)
        print(f"epoch {epoch+1}/{n_epochs} Average Disc Loss (in Source domain): {train_epoc_loss_d:.6f}")
        #
        train_domain_loss.append(train_epoc_loss_domain)
        print(f"epoch {epoch+1}/{n_epochs} Average Domain Discrimination Loss: {train_epoc_loss_domain:.6f}")
        #
        train_est_loss_target.append(train_epoc_loss_est_target)
        print(f"epoch {epoch+1}/{n_epochs} For observation only - Average Estimation Loss in Target domain: {train_epoc_loss_est_target:.6f}")
        
        
        # ===================== Evaluation =====================
        loader_H_true_val_source.reset()
        loader_H_input_val_source.reset()
        loader_H_true_val_target.reset()
        loader_H_input_val_target.reset()
        loader_H_eval = [loader_H_input_val_source, loader_H_true_val_source, loader_H_input_val_target, loader_H_true_val_target]

        loss_fn = [loss_fn_ce, loss_fn_bce, loss_fn_domain]
        
        # eval_func = utils_UDA_FiLM.val_step
        if (epoch==epoch_min) or (epoch+1>epoch_min and (epoch-epoch_min)%epoch_step==0) or epoch==n_epochs-1:
            H_sample, epoc_val_return = utils_GAN.val_step_wgan_gp(model, model_domain, loader_H_eval, loss_fn, lower_range, 
                                            adv_weight=adv_weight, est_weight=est_weight, domain_weight=domain_weight, linear_interp=linear_interp)
            utils_GAN.visualize_H(H_sample, H_to_save, epoch, plotfig.figChan, flag, model_path, sub_folder, domain_weight=domain_weight)
            flag = 0  # after the first epoch, no need to save H_true anymore
            
        else:
            _, epoc_val_return = utils_GAN.val_step_wgan_gp(model, model_domain, loader_H_eval, loss_fn, lower_range, 
                                            adv_weight=adv_weight, est_weight=est_weight, domain_weight=domain_weight, linear_interp=linear_interp)
        
        utils_GAN.post_val(epoc_val_return, epoch, n_epochs, val_est_loss, val_est_loss_source, val_loss, val_est_loss_target,
            val_gan_disc_loss, val_domain_disc_loss, nmse_val_source, nmse_val_target, nmse_val, source_acc, target_acc, acc, domain_weight=domain_weight)
        
        
        if (epoch==epoch_min) or (epoch+1>epoch_min and (epoch-epoch_min)%epoch_step==0) or epoch==n_epochs-1:
            utils_GAN.save_checkpoint(model, save_model, model_path, sub_folder, epoch, plotfig.figLoss, savemat, train_loss, train_est_loss, train_domain_loss, train_est_loss_target,
                    val_est_loss, val_est_loss_source, val_loss, val_est_loss_target, val_gan_disc_loss, val_domain_disc_loss,
                    source_acc, target_acc, acc, nmse_val_source, nmse_val_target, nmse_val, pad_observe_svm, epoc_pad, train_disc_loss, domain_weight=domain_weight)
    
    # end of epoch loop
    # =====================            
    # Save performances
    # Save H matrix
    savemat(model_path + '/' + sub_folder + '/H_visualize/H_trix.mat', H_to_save)

# end of trainmode
# Out:
# Processing: GAN_practical
# Time 92.076265169002 seconds
# epoch 1/300 Average Training Loss: 0.257807
# epoch 1/300 Average Estimation Loss (in Source domain): 0.083002
# epoch 1/300 Average Disc Loss (in Source domain): 1483.682983
# epoch 1/300 Average Domain Discrimination Loss: 0.745248
# epoch 1/300 For observation only - Average Estimation Loss in Target domain: 0.164203
# epoch 1/300 (Val) Weighted Total Loss: 1.884274
# epoch 1/300 (Val) Average Estimation Loss (mean): 0.224124
# epoch 1/300 (Val) Average Estimation Loss (Source): 0.135272
# epoch 1/300 (Val) Average Estimation Loss (Target): 0.312976
# epoch 1/300 (Val) GAN Discriminator Loss: 192.512436
# epoch 1/300 (Val) Domain Discriminator Loss: 1.395177
# epoch 1/300 (Val) NMSE (Source): 0.064391, NMSE (Target): 0.112484, NMSE (Mean): 0.088437
# epoch 1/300 (Val) Domain Discriminator Accuracy (Average): 0.4471
# Time 182.5593015570048 seconds
# epoch 2/300 Average Training Loss: 0.239019
# epoch 2/300 Average Estimation Loss (in Source domain): 0.065873
# epoch 2/300 Average Disc Loss (in Source domain): 24.148951
# epoch 2/300 Average Domain Discrimination Loss: 0.702685
# epoch 2/300 For observation only - Average Estimation Loss in Target domain: 0.157122
# epoch 2/300 (Val) Weighted Total Loss: 0.934254
# epoch 2/300 (Val) Average Estimation Loss (mean): 0.220104
# epoch 2/300 (Val) Average Estimation Loss (Source): 0.126716
# epoch 2/300 (Val) Average Estimation Loss (Target): 0.313493
# epoch 2/300 (Val) GAN Discriminator Loss: 4.001914
# epoch 2/300 (Val) Domain Discriminator Loss: 1.388279
# epoch 2/300 (Val) NMSE (Source): 0.060078, NMSE (Target): 0.112553, NMSE (Mean): 0.086315
# epoch 2/300 (Val) Domain Discriminator Accuracy (Average): 0.4591
# Time 272.17747006600257 seconds
# epoch 3/300 Average Training Loss: 0.234869
# epoch 3/300 Average Estimation Loss (in Source domain): 0.061629
# epoch 3/300 Average Disc Loss (in Source domain): 0.801647
# epoch 3/300 Average Domain Discrimination Loss: 0.695987
# epoch 3/300 For observation only - Average Estimation Loss in Target domain: 0.156441
# epoch 3/300 (Val) Weighted Total Loss: 0.914148
# epoch 3/300 (Val) Average Estimation Loss (mean): 0.217756
# epoch 3/300 (Val) Average Estimation Loss (Source): 0.120959
# epoch 3/300 (Val) Average Estimation Loss (Target): 0.314553
# epoch 3/300 (Val) GAN Discriminator Loss: 0.582576
# epoch 3/300 (Val) Domain Discriminator Loss: 1.386959
# epoch 3/300 (Val) NMSE (Source): 0.057075, NMSE (Target): 0.112719, NMSE (Mean): 0.084897
# epoch 3/300 (Val) Domain Discriminator Accuracy (Average): 0.5024
# Time 362.07491092300916 seconds
# epoch 4/300 Average Training Loss: 0.231788
# epoch 4/300 Average Estimation Loss (in Source domain): 0.058514
# epoch 4/300 Average Disc Loss (in Source domain): 0.384303
# epoch 4/300 Average Domain Discrimination Loss: 0.694025
# epoch 4/300 For observation only - Average Estimation Loss in Target domain: 0.156067
# epoch 4/300 (Val) Weighted Total Loss: 0.910822
# epoch 4/300 (Val) Average Estimation Loss (mean): 0.215443
# epoch 4/300 (Val) Average Estimation Loss (Source): 0.116216
# epoch 4/300 (Val) Average Estimation Loss (Target): 0.314669
# epoch 4/300 (Val) GAN Discriminator Loss: 0.423371
# epoch 4/300 (Val) Domain Discriminator Loss: 1.386524
# epoch 4/300 (Val) NMSE (Source): 0.054478, NMSE (Target): 0.112356, NMSE (Mean): 0.083417
# epoch 4/300 (Val) Domain Discriminator Accuracy (Average): 0.4784
# Time 451.0290547360055 seconds
# epoch 5/300 Average Training Loss: 0.229487
# epoch 5/300 Average Estimation Loss (in Source domain): 0.056157
# epoch 5/300 Average Disc Loss (in Source domain): 0.260447
# epoch 5/300 Average Domain Discrimination Loss: 0.693438
# epoch 5/300 For observation only - Average Estimation Loss in Target domain: 0.155557
# epoch 5/300 (Val) Weighted Total Loss: 0.907442
# epoch 5/300 (Val) Average Estimation Loss (mean): 0.213232
# epoch 5/300 (Val) Average Estimation Loss (Source): 0.112640
# epoch 5/300 (Val) Average Estimation Loss (Target): 0.313824
# epoch 5/300 (Val) GAN Discriminator Loss: 0.298265
# epoch 5/300 (Val) Domain Discriminator Loss: 1.385438
# epoch 5/300 (Val) NMSE (Source): 0.052476, NMSE (Target): 0.111721, NMSE (Mean): 0.082099
# epoch 5/300 (Val) Domain Discriminator Accuracy (Average): 0.5529
# Time 541.3316514070029 seconds
# epoch 6/300 Average Training Loss: 0.227401
# epoch 6/300 Average Estimation Loss (in Source domain): 0.054287
# epoch 6/300 Average Disc Loss (in Source domain): 0.182072
# epoch 6/300 Average Domain Discrimination Loss: 0.692684
# epoch 6/300 For observation only - Average Estimation Loss in Target domain: 0.155067
# epoch 6/300 (Val) Weighted Total Loss: 0.903191
# epoch 6/300 (Val) Average Estimation Loss (mean): 0.211676
# epoch 6/300 (Val) Average Estimation Loss (Source): 0.109954
# epoch 6/300 (Val) Average Estimation Loss (Target): 0.313398
# epoch 6/300 (Val) GAN Discriminator Loss: 0.223191
# epoch 6/300 (Val) Domain Discriminator Loss: 1.380797
# epoch 6/300 (Val) NMSE (Source): 0.051008, NMSE (Target): 0.111208, NMSE (Mean): 0.081108
# epoch 6/300 (Val) Domain Discriminator Accuracy (Average): 0.6130
# Time 631.2740043829981 seconds
# epoch 7/300 Average Training Loss: 0.225951
# epoch 7/300 Average Estimation Loss (in Source domain): 0.053432
# epoch 7/300 Average Disc Loss (in Source domain): 0.160633
# epoch 7/300 Average Domain Discrimination Loss: 0.692192
# epoch 7/300 For observation only - Average Estimation Loss in Target domain: 0.154527
# epoch 7/300 (Val) Weighted Total Loss: 0.901953
# epoch 7/300 (Val) Average Estimation Loss (mean): 0.210699
# epoch 7/300 (Val) Average Estimation Loss (Source): 0.109619
# epoch 7/300 (Val) Average Estimation Loss (Target): 0.311780
# epoch 7/300 (Val) GAN Discriminator Loss: 0.231772
# epoch 7/300 (Val) Domain Discriminator Loss: 1.380189
# epoch 7/300 (Val) NMSE (Source): 0.050800, NMSE (Target): 0.110323, NMSE (Mean): 0.080561
# epoch 7/300 (Val) Domain Discriminator Accuracy (Average): 0.5385
# Time 722.1105834990012 seconds
# epoch 8/300 Average Training Loss: 0.226251
# epoch 8/300 Average Estimation Loss (in Source domain): 0.053029
# epoch 8/300 Average Disc Loss (in Source domain): 0.145926
# epoch 8/300 Average Domain Discrimination Loss: 0.694449
# epoch 8/300 For observation only - Average Estimation Loss in Target domain: 0.153717
# epoch 8/300 (Val) Weighted Total Loss: 0.900387
# epoch 8/300 (Val) Average Estimation Loss (mean): 0.208384
# epoch 8/300 (Val) Average Estimation Loss (Source): 0.107188
# epoch 8/300 (Val) Average Estimation Loss (Target): 0.309579
# epoch 8/300 (Val) GAN Discriminator Loss: 0.178920
# epoch 8/300 (Val) Domain Discriminator Loss: 1.382218
# epoch 8/300 (Val) NMSE (Source): 0.049493, NMSE (Target): 0.109033, NMSE (Mean): 0.079263
# epoch 8/300 (Val) Domain Discriminator Accuracy (Average): 0.5385
# Time 812.8214138809999 seconds
# epoch 9/300 Average Training Loss: 0.224350
# epoch 9/300 Average Estimation Loss (in Source domain): 0.051442
# epoch 9/300 Average Disc Loss (in Source domain): 0.153048
# epoch 9/300 Average Domain Discrimination Loss: 0.692745
# epoch 9/300 For observation only - Average Estimation Loss in Target domain: 0.153280
# epoch 9/300 (Val) Weighted Total Loss: 0.897944
# epoch 9/300 (Val) Average Estimation Loss (mean): 0.207497
# epoch 9/300 (Val) Average Estimation Loss (Source): 0.105721
# epoch 9/300 (Val) Average Estimation Loss (Target): 0.309273
# epoch 9/300 (Val) GAN Discriminator Loss: 0.140392
# epoch 9/300 (Val) Domain Discriminator Loss: 1.379490
# epoch 9/300 (Val) NMSE (Source): 0.048606, NMSE (Target): 0.108744, NMSE (Mean): 0.078675
# epoch 9/300 (Val) Domain Discriminator Accuracy (Average): 0.6034
# Time 903.589830670011 seconds
# epoch 10/300 Average Training Loss: 0.223226
# epoch 10/300 Average Estimation Loss (in Source domain): 0.050450
# epoch 10/300 Average Disc Loss (in Source domain): 0.113362
# epoch 10/300 Average Domain Discrimination Loss: 0.692946
# epoch 10/300 For observation only - Average Estimation Loss in Target domain: 0.152709
# epoch 10/300 (Val) Weighted Total Loss: 0.897666
# epoch 10/300 (Val) Average Estimation Loss (mean): 0.205916
# epoch 10/300 (Val) Average Estimation Loss (Source): 0.104682
# epoch 10/300 (Val) Average Estimation Loss (Target): 0.307149
# epoch 10/300 (Val) GAN Discriminator Loss: 0.117082
# epoch 10/300 (Val) Domain Discriminator Loss: 1.382330
# epoch 10/300 (Val) NMSE (Source): 0.047989, NMSE (Target): 0.107659, NMSE (Mean): 0.077824
# epoch 10/300 (Val) Domain Discriminator Accuracy (Average): 0.5673
# Time 994.0027096640115 seconds
# epoch 11/300 Average Training Loss: 0.222351
# epoch 11/300 Average Estimation Loss (in Source domain): 0.049462
# epoch 11/300 Average Disc Loss (in Source domain): 0.126863
# epoch 11/300 Average Domain Discrimination Loss: 0.693560
# epoch 11/300 For observation only - Average Estimation Loss in Target domain: 0.152210
# epoch 11/300 (Val) Weighted Total Loss: 0.896486
# epoch 11/300 (Val) Average Estimation Loss (mean): 0.205553
# epoch 11/300 (Val) Average Estimation Loss (Source): 0.104038
# epoch 11/300 (Val) Average Estimation Loss (Target): 0.307068
# epoch 11/300 (Val) GAN Discriminator Loss: 0.128859
# epoch 11/300 (Val) Domain Discriminator Loss: 1.380579
# epoch 11/300 (Val) NMSE (Source): 0.047629, NMSE (Target): 0.107209, NMSE (Mean): 0.077419
# epoch 11/300 (Val) Domain Discriminator Accuracy (Average): 0.5962
# Time 1084.1605671150028 seconds
# epoch 12/300 Average Training Loss: 0.221079
# epoch 12/300 Average Estimation Loss (in Source domain): 0.048335
# epoch 12/300 Average Disc Loss (in Source domain): 0.089945
# epoch 12/300 Average Domain Discrimination Loss: 0.693272
# epoch 12/300 For observation only - Average Estimation Loss in Target domain: 0.151966
# epoch 12/300 (Val) Weighted Total Loss: 0.895433
# epoch 12/300 (Val) Average Estimation Loss (mean): 0.205016
# epoch 12/300 (Val) Average Estimation Loss (Source): 0.103322
# epoch 12/300 (Val) Average Estimation Loss (Target): 0.306710
# epoch 12/300 (Val) GAN Discriminator Loss: 0.107728
# epoch 12/300 (Val) Domain Discriminator Loss: 1.379758
# epoch 12/300 (Val) NMSE (Source): 0.047190, NMSE (Target): 0.106858, NMSE (Mean): 0.077024
# epoch 12/300 (Val) Domain Discriminator Accuracy (Average): 0.5697
# Time 1174.683275457006 seconds
# epoch 13/300 Average Training Loss: 0.219732
# epoch 13/300 Average Estimation Loss (in Source domain): 0.047230
# epoch 13/300 Average Disc Loss (in Source domain): 0.082055
# epoch 13/300 Average Domain Discrimination Loss: 0.693078
# epoch 13/300 For observation only - Average Estimation Loss in Target domain: 0.151756
# epoch 13/300 (Val) Weighted Total Loss: 0.892992
# epoch 13/300 (Val) Average Estimation Loss (mean): 0.203948
# epoch 13/300 (Val) Average Estimation Loss (Source): 0.102823
# epoch 13/300 (Val) Average Estimation Loss (Target): 0.305072
# epoch 13/300 (Val) GAN Discriminator Loss: 0.106894
# epoch 13/300 (Val) Domain Discriminator Loss: 1.377020
# epoch 13/300 (Val) NMSE (Source): 0.046813, NMSE (Target): 0.105841, NMSE (Mean): 0.076327
# epoch 13/300 (Val) Domain Discriminator Accuracy (Average): 0.5889
# Time 1264.8396884660033 seconds
# epoch 14/300 Average Training Loss: 0.218607
# epoch 14/300 Average Estimation Loss (in Source domain): 0.046287
# epoch 14/300 Average Disc Loss (in Source domain): 0.068498
# epoch 14/300 Average Domain Discrimination Loss: 0.692924
# epoch 14/300 For observation only - Average Estimation Loss in Target domain: 0.151833
# epoch 14/300 (Val) Weighted Total Loss: 0.893830
# epoch 14/300 (Val) Average Estimation Loss (mean): 0.203975
# epoch 14/300 (Val) Average Estimation Loss (Source): 0.102561
# epoch 14/300 (Val) Average Estimation Loss (Target): 0.305388
# epoch 14/300 (Val) GAN Discriminator Loss: 0.092440
# epoch 14/300 (Val) Domain Discriminator Loss: 1.378787
# epoch 14/300 (Val) NMSE (Source): 0.046597, NMSE (Target): 0.105855, NMSE (Mean): 0.076226
# epoch 14/300 (Val) Domain Discriminator Accuracy (Average): 0.5697
# Time 1354.9673365540075 seconds
# epoch 15/300 Average Training Loss: 0.217471
# epoch 15/300 Average Estimation Loss (in Source domain): 0.045394
# epoch 15/300 Average Disc Loss (in Source domain): 0.064070
# epoch 15/300 Average Domain Discrimination Loss: 0.692499
# epoch 15/300 For observation only - Average Estimation Loss in Target domain: 0.152083
# epoch 15/300 (Val) Weighted Total Loss: 0.892511
# epoch 15/300 (Val) Average Estimation Loss (mean): 0.203588
# epoch 15/300 (Val) Average Estimation Loss (Source): 0.101923
# epoch 15/300 (Val) Average Estimation Loss (Target): 0.305253
# epoch 15/300 (Val) GAN Discriminator Loss: 0.069619
# epoch 15/300 (Val) Domain Discriminator Loss: 1.377149
# epoch 15/300 (Val) NMSE (Source): 0.046178, NMSE (Target): 0.105535, NMSE (Mean): 0.075856
# epoch 15/300 (Val) Domain Discriminator Accuracy (Average): 0.5745
# Time 1445.2222711130016 seconds
# epoch 16/300 Average Training Loss: 0.215943
# epoch 16/300 Average Estimation Loss (in Source domain): 0.044371
# epoch 16/300 Average Disc Loss (in Source domain): 0.073616
# epoch 16/300 Average Domain Discrimination Loss: 0.692057
# epoch 16/300 For observation only - Average Estimation Loss in Target domain: 0.152069
# epoch 16/300 (Val) Weighted Total Loss: 0.893335
# epoch 16/300 (Val) Average Estimation Loss (mean): 0.204089
# epoch 16/300 (Val) Average Estimation Loss (Source): 0.101773
# epoch 16/300 (Val) Average Estimation Loss (Target): 0.306404
# epoch 16/300 (Val) GAN Discriminator Loss: 0.061281
# epoch 16/300 (Val) Domain Discriminator Loss: 1.377880
# epoch 16/300 (Val) NMSE (Source): 0.046130, NMSE (Target): 0.105758, NMSE (Mean): 0.075944
# epoch 16/300 (Val) Domain Discriminator Accuracy (Average): 0.5457
# Time 1536.1166328000108 seconds
# epoch 17/300 Average Training Loss: 0.214603
# epoch 17/300 Average Estimation Loss (in Source domain): 0.043630
# epoch 17/300 Average Disc Loss (in Source domain): 0.072744
# epoch 17/300 Average Domain Discrimination Loss: 0.691569
# epoch 17/300 For observation only - Average Estimation Loss in Target domain: 0.152112
# epoch 17/300 (Val) Weighted Total Loss: 0.892680
# epoch 17/300 (Val) Average Estimation Loss (mean): 0.203769
# epoch 17/300 (Val) Average Estimation Loss (Source): 0.101656
# epoch 17/300 (Val) Average Estimation Loss (Target): 0.305882
# epoch 17/300 (Val) GAN Discriminator Loss: 0.056064
# epoch 17/300 (Val) Domain Discriminator Loss: 1.377261
# epoch 17/300 (Val) NMSE (Source): 0.046068, NMSE (Target): 0.105567, NMSE (Mean): 0.075818
# epoch 17/300 (Val) Domain Discriminator Accuracy (Average): 0.5264
# Time 1626.4855907080055 seconds
# epoch 18/300 Average Training Loss: 0.213395
# epoch 18/300 Average Estimation Loss (in Source domain): 0.043031
# epoch 18/300 Average Disc Loss (in Source domain): 0.065374
# epoch 18/300 Average Domain Discrimination Loss: 0.691352
# epoch 18/300 For observation only - Average Estimation Loss in Target domain: 0.152405
# epoch 18/300 (Val) Weighted Total Loss: 0.892851
# epoch 18/300 (Val) Average Estimation Loss (mean): 0.204414
# epoch 18/300 (Val) Average Estimation Loss (Source): 0.101672
# epoch 18/300 (Val) Average Estimation Loss (Target): 0.307155
# epoch 18/300 (Val) GAN Discriminator Loss: 0.050962
# epoch 18/300 (Val) Domain Discriminator Loss: 1.376365
# epoch 18/300 (Val) NMSE (Source): 0.045997, NMSE (Target): 0.105895, NMSE (Mean): 0.075946
# epoch 18/300 (Val) Domain Discriminator Accuracy (Average): 0.5601
# Time 1716.4861438920052 seconds
# epoch 19/300 Average Training Loss: 0.212366
# epoch 19/300 Average Estimation Loss (in Source domain): 0.042586
# epoch 19/300 Average Disc Loss (in Source domain): 0.051824
# epoch 19/300 Average Domain Discrimination Loss: 0.691014
# epoch 19/300 For observation only - Average Estimation Loss in Target domain: 0.152432
# epoch 19/300 (Val) Weighted Total Loss: 0.894836
# epoch 19/300 (Val) Average Estimation Loss (mean): 0.204702
# epoch 19/300 (Val) Average Estimation Loss (Source): 0.101610
# epoch 19/300 (Val) Average Estimation Loss (Target): 0.307794
# epoch 19/300 (Val) GAN Discriminator Loss: 0.052805
# epoch 19/300 (Val) Domain Discriminator Loss: 1.379739
# epoch 19/300 (Val) NMSE (Source): 0.045867, NMSE (Target): 0.106000, NMSE (Mean): 0.075934
# epoch 19/300 (Val) Domain Discriminator Accuracy (Average): 0.5361
# Time 1807.1938489130116 seconds
# epoch 20/300 Average Training Loss: 0.211829
# epoch 20/300 Average Estimation Loss (in Source domain): 0.041968
# epoch 20/300 Average Disc Loss (in Source domain): 0.042183
# epoch 20/300 Average Domain Discrimination Loss: 0.691731
# epoch 20/300 For observation only - Average Estimation Loss in Target domain: 0.152730
# epoch 20/300 (Val) Weighted Total Loss: 0.896587
# epoch 20/300 (Val) Average Estimation Loss (mean): 0.205557
# epoch 20/300 (Val) Average Estimation Loss (Source): 0.102456
# epoch 20/300 (Val) Average Estimation Loss (Target): 0.308658
# epoch 20/300 (Val) GAN Discriminator Loss: 0.048672
# epoch 20/300 (Val) Domain Discriminator Loss: 1.381573
# epoch 20/300 (Val) NMSE (Source): 0.046167, NMSE (Target): 0.106325, NMSE (Mean): 0.076246
# epoch 20/300 (Val) Domain Discriminator Accuracy (Average): 0.5529
# Time 1898.0009782800043 seconds
# epoch 21/300 Average Training Loss: 0.211190
# epoch 21/300 Average Estimation Loss (in Source domain): 0.041571
# epoch 21/300 Average Disc Loss (in Source domain): 0.054575
# epoch 21/300 Average Domain Discrimination Loss: 0.691308
# epoch 21/300 For observation only - Average Estimation Loss in Target domain: 0.153083
# epoch 21/300 (Val) Weighted Total Loss: 0.897909
# epoch 21/300 (Val) Average Estimation Loss (mean): 0.205611
# epoch 21/300 (Val) Average Estimation Loss (Source): 0.101459
# epoch 21/300 (Val) Average Estimation Loss (Target): 0.309763
# epoch 21/300 (Val) GAN Discriminator Loss: 0.051214
# epoch 21/300 (Val) Domain Discriminator Loss: 1.384083
# epoch 21/300 (Val) NMSE (Source): 0.045693, NMSE (Target): 0.106466, NMSE (Mean): 0.076079
# epoch 21/300 (Val) Domain Discriminator Accuracy (Average): 0.5577
# Time 1988.8930849820026 seconds
# epoch 22/300 Average Training Loss: 0.210599
# epoch 22/300 Average Estimation Loss (in Source domain): 0.041289
# epoch 22/300 Average Disc Loss (in Source domain): 0.046107
# epoch 22/300 Average Domain Discrimination Loss: 0.691401
# epoch 22/300 For observation only - Average Estimation Loss in Target domain: 0.152988
# epoch 22/300 (Val) Weighted Total Loss: 0.899222
# epoch 22/300 (Val) Average Estimation Loss (mean): 0.206363
# epoch 22/300 (Val) Average Estimation Loss (Source): 0.102897
# epoch 22/300 (Val) Average Estimation Loss (Target): 0.309828
# epoch 22/300 (Val) GAN Discriminator Loss: 0.064530
# epoch 22/300 (Val) Domain Discriminator Loss: 1.385074
# epoch 22/300 (Val) NMSE (Source): 0.046361, NMSE (Target): 0.106666, NMSE (Mean): 0.076513
# epoch 22/300 (Val) Domain Discriminator Accuracy (Average): 0.5264
# Time 2079.7764349740028 seconds
# epoch 23/300 Average Training Loss: 0.210387
# epoch 23/300 Average Estimation Loss (in Source domain): 0.040934
# epoch 23/300 Average Disc Loss (in Source domain): 0.037763
# epoch 23/300 Average Domain Discrimination Loss: 0.691949
# epoch 23/300 For observation only - Average Estimation Loss in Target domain: 0.153235
# epoch 23/300 (Val) Weighted Total Loss: 0.896224
# epoch 23/300 (Val) Average Estimation Loss (mean): 0.205911
# epoch 23/300 (Val) Average Estimation Loss (Source): 0.102552
# epoch 23/300 (Val) Average Estimation Loss (Target): 0.309270
# epoch 23/300 (Val) GAN Discriminator Loss: 0.077532
# epoch 23/300 (Val) Domain Discriminator Loss: 1.379850
# epoch 23/300 (Val) NMSE (Source): 0.046387, NMSE (Target): 0.105924, NMSE (Mean): 0.076155
# epoch 23/300 (Val) Domain Discriminator Accuracy (Average): 0.5337
# Time 2170.151528485003 seconds
# epoch 24/300 Average Training Loss: 0.210038
# epoch 24/300 Average Estimation Loss (in Source domain): 0.040693
# epoch 24/300 Average Disc Loss (in Source domain): 0.035188
# epoch 24/300 Average Domain Discrimination Loss: 0.691728
# epoch 24/300 For observation only - Average Estimation Loss in Target domain: 0.153303
# epoch 24/300 (Val) Weighted Total Loss: 0.893212
# epoch 24/300 (Val) Average Estimation Loss (mean): 0.205442
# epoch 24/300 (Val) Average Estimation Loss (Source): 0.102324
# epoch 24/300 (Val) Average Estimation Loss (Target): 0.308560
# epoch 24/300 (Val) GAN Discriminator Loss: 0.038714
# epoch 24/300 (Val) Domain Discriminator Loss: 1.375154
# epoch 24/300 (Val) NMSE (Source): 0.046263, NMSE (Target): 0.105924, NMSE (Mean): 0.076093
# epoch 24/300 (Val) Domain Discriminator Accuracy (Average): 0.5745
# Time 2260.3883908380085 seconds
# epoch 25/300 Average Training Loss: 0.209837
# epoch 25/300 Average Estimation Loss (in Source domain): 0.040378
# epoch 25/300 Average Disc Loss (in Source domain): 0.032558
# epoch 25/300 Average Domain Discrimination Loss: 0.692886
# epoch 25/300 For observation only - Average Estimation Loss in Target domain: 0.153523
# epoch 25/300 (Val) Weighted Total Loss: 0.894696
# epoch 25/300 (Val) Average Estimation Loss (mean): 0.205139
# epoch 25/300 (Val) Average Estimation Loss (Source): 0.101668
# epoch 25/300 (Val) Average Estimation Loss (Target): 0.308610
# epoch 25/300 (Val) GAN Discriminator Loss: 0.053248
# epoch 25/300 (Val) Domain Discriminator Loss: 1.378582
# epoch 25/300 (Val) NMSE (Source): 0.045740, NMSE (Target): 0.105954, NMSE (Mean): 0.075847
# epoch 25/300 (Val) Domain Discriminator Accuracy (Average): 0.5697
# Time 2350.8207750560105 seconds
# epoch 26/300 Average Training Loss: 0.209777
# epoch 26/300 Average Estimation Loss (in Source domain): 0.039989
# epoch 26/300 Average Disc Loss (in Source domain): 0.051391
# epoch 26/300 Average Domain Discrimination Loss: 0.692954
# epoch 26/300 For observation only - Average Estimation Loss in Target domain: 0.153764
# epoch 26/300 (Val) Weighted Total Loss: 0.895663
# epoch 26/300 (Val) Average Estimation Loss (mean): 0.206490
# epoch 26/300 (Val) Average Estimation Loss (Source): 0.101467
# epoch 26/300 (Val) Average Estimation Loss (Target): 0.311512
# epoch 26/300 (Val) GAN Discriminator Loss: 0.023928
# epoch 26/300 (Val) Domain Discriminator Loss: 1.378108
# epoch 26/300 (Val) NMSE (Source): 0.045776, NMSE (Target): 0.106790, NMSE (Mean): 0.076283
# epoch 26/300 (Val) Domain Discriminator Accuracy (Average): 0.5409
# Time 2441.8763917379983 seconds
# epoch 27/300 Average Training Loss: 0.209275
# epoch 27/300 Average Estimation Loss (in Source domain): 0.039559
# epoch 27/300 Average Disc Loss (in Source domain): 0.038403
# epoch 27/300 Average Domain Discrimination Loss: 0.692436
# epoch 27/300 For observation only - Average Estimation Loss in Target domain: 0.153966
# epoch 27/300 (Val) Weighted Total Loss: 0.896416
# epoch 27/300 (Val) Average Estimation Loss (mean): 0.207943
# epoch 27/300 (Val) Average Estimation Loss (Source): 0.103293
# epoch 27/300 (Val) Average Estimation Loss (Target): 0.312593
# epoch 27/300 (Val) GAN Discriminator Loss: 0.045492
# epoch 27/300 (Val) Domain Discriminator Loss: 1.376492
# epoch 27/300 (Val) NMSE (Source): 0.046765, NMSE (Target): 0.107079, NMSE (Mean): 0.076922
# epoch 27/300 (Val) Domain Discriminator Accuracy (Average): 0.5938
# Time 2532.358614690005 seconds
# epoch 28/300 Average Training Loss: 0.208877
# epoch 28/300 Average Estimation Loss (in Source domain): 0.038975
# epoch 28/300 Average Disc Loss (in Source domain): 0.024223
# epoch 28/300 Average Domain Discrimination Loss: 0.692800
# epoch 28/300 For observation only - Average Estimation Loss in Target domain: 0.154577
# epoch 28/300 (Val) Weighted Total Loss: 0.895821
# epoch 28/300 (Val) Average Estimation Loss (mean): 0.207545
# epoch 28/300 (Val) Average Estimation Loss (Source): 0.103868
# epoch 28/300 (Val) Average Estimation Loss (Target): 0.311223
# epoch 28/300 (Val) GAN Discriminator Loss: 0.050322
# epoch 28/300 (Val) Domain Discriminator Loss: 1.376048
# epoch 28/300 (Val) NMSE (Source): 0.046854, NMSE (Target): 0.106344, NMSE (Mean): 0.076599
# epoch 28/300 (Val) Domain Discriminator Accuracy (Average): 0.5745
# Time 2622.133221505006 seconds
# epoch 29/300 Average Training Loss: 0.208228
# epoch 29/300 Average Estimation Loss (in Source domain): 0.038159
# epoch 29/300 Average Disc Loss (in Source domain): 0.031892
# epoch 29/300 Average Domain Discrimination Loss: 0.693200
# epoch 29/300 For observation only - Average Estimation Loss in Target domain: 0.154620
# epoch 29/300 (Val) Weighted Total Loss: 0.899982
# epoch 29/300 (Val) Average Estimation Loss (mean): 0.210005
# epoch 29/300 (Val) Average Estimation Loss (Source): 0.105375
# epoch 29/300 (Val) Average Estimation Loss (Target): 0.314635
# epoch 29/300 (Val) GAN Discriminator Loss: 0.048747
# epoch 29/300 (Val) Domain Discriminator Loss: 1.379467
# epoch 29/300 (Val) NMSE (Source): 0.047714, NMSE (Target): 0.107927, NMSE (Mean): 0.077821
# epoch 29/300 (Val) Domain Discriminator Accuracy (Average): 0.5529
# Time 2712.6796641560068 seconds
# epoch 30/300 Average Training Loss: 0.207416
# epoch 30/300 Average Estimation Loss (in Source domain): 0.037364
# epoch 30/300 Average Disc Loss (in Source domain): 0.045331
# epoch 30/300 Average Domain Discrimination Loss: 0.692705
# epoch 30/300 For observation only - Average Estimation Loss in Target domain: 0.155094
# epoch 30/300 (Val) Weighted Total Loss: 0.896950
# epoch 30/300 (Val) Average Estimation Loss (mean): 0.209397
# epoch 30/300 (Val) Average Estimation Loss (Source): 0.103614
# epoch 30/300 (Val) Average Estimation Loss (Target): 0.315179
# epoch 30/300 (Val) GAN Discriminator Loss: 0.035722
# epoch 30/300 (Val) Domain Discriminator Loss: 1.374749
# epoch 30/300 (Val) NMSE (Source): 0.046710, NMSE (Target): 0.108417, NMSE (Mean): 0.077564
# epoch 30/300 (Val) Domain Discriminator Accuracy (Average): 0.5673
# Time 2803.3558142429974 seconds
# epoch 31/300 Average Training Loss: 0.206206
# epoch 31/300 Average Estimation Loss (in Source domain): 0.036576
# epoch 31/300 Average Disc Loss (in Source domain): 0.026483
# epoch 31/300 Average Domain Discrimination Loss: 0.692021
# epoch 31/300 For observation only - Average Estimation Loss in Target domain: 0.155394
# epoch 31/300 (Val) Weighted Total Loss: 0.899269
# epoch 31/300 (Val) Average Estimation Loss (mean): 0.210399
# epoch 31/300 (Val) Average Estimation Loss (Source): 0.104135
# epoch 31/300 (Val) Average Estimation Loss (Target): 0.316664
# epoch 31/300 (Val) GAN Discriminator Loss: 0.060388
# epoch 31/300 (Val) Domain Discriminator Loss: 1.377135
# epoch 31/300 (Val) NMSE (Source): 0.047150, NMSE (Target): 0.109027, NMSE (Mean): 0.078088
# epoch 31/300 (Val) Domain Discriminator Accuracy (Average): 0.5625
# Time 2893.7349271150015 seconds
# epoch 32/300 Average Training Loss: 0.205703
# epoch 32/300 Average Estimation Loss (in Source domain): 0.036113
# epoch 32/300 Average Disc Loss (in Source domain): 0.034666
# epoch 32/300 Average Domain Discrimination Loss: 0.692385
# epoch 32/300 For observation only - Average Estimation Loss in Target domain: 0.155749
# epoch 32/300 (Val) Weighted Total Loss: 0.900223
# epoch 32/300 (Val) Average Estimation Loss (mean): 0.210754
# epoch 32/300 (Val) Average Estimation Loss (Source): 0.104814
# epoch 32/300 (Val) Average Estimation Loss (Target): 0.316693
# epoch 32/300 (Val) GAN Discriminator Loss: 0.014260
# epoch 32/300 (Val) Domain Discriminator Loss: 1.378797
# epoch 32/300 (Val) NMSE (Source): 0.047411, NMSE (Target): 0.108473, NMSE (Mean): 0.077942
# epoch 32/300 (Val) Domain Discriminator Accuracy (Average): 0.5481
# Time 2984.3264147709997 seconds
# epoch 33/300 Average Training Loss: 0.205055
# epoch 33/300 Average Estimation Loss (in Source domain): 0.035585
# epoch 33/300 Average Disc Loss (in Source domain): 0.025548
# epoch 33/300 Average Domain Discrimination Loss: 0.691868
# epoch 33/300 For observation only - Average Estimation Loss in Target domain: 0.156448
# epoch 33/300 (Val) Weighted Total Loss: 0.902611
# epoch 33/300 (Val) Average Estimation Loss (mean): 0.212789
# epoch 33/300 (Val) Average Estimation Loss (Source): 0.106043
# epoch 33/300 (Val) Average Estimation Loss (Target): 0.319536
# epoch 33/300 (Val) GAN Discriminator Loss: 0.010811
# epoch 33/300 (Val) Domain Discriminator Loss: 1.379534
# epoch 33/300 (Val) NMSE (Source): 0.048097, NMSE (Target): 0.110186, NMSE (Mean): 0.079141
# epoch 33/300 (Val) Domain Discriminator Accuracy (Average): 0.5601
# Time 3074.960244089001 seconds
# epoch 34/300 Average Training Loss: 0.204241
# epoch 34/300 Average Estimation Loss (in Source domain): 0.035056
# epoch 34/300 Average Disc Loss (in Source domain): 0.028889
# epoch 34/300 Average Domain Discrimination Loss: 0.691838
# epoch 34/300 For observation only - Average Estimation Loss in Target domain: 0.156620
# epoch 34/300 (Val) Weighted Total Loss: 0.903281
# epoch 34/300 (Val) Average Estimation Loss (mean): 0.213117
# epoch 34/300 (Val) Average Estimation Loss (Source): 0.107556
# epoch 34/300 (Val) Average Estimation Loss (Target): 0.318678
# epoch 34/300 (Val) GAN Discriminator Loss: 0.014295
# epoch 34/300 (Val) Domain Discriminator Loss: 1.380184
# epoch 34/300 (Val) NMSE (Source): 0.048859, NMSE (Target): 0.109215, NMSE (Mean): 0.079037
# epoch 34/300 (Val) Domain Discriminator Accuracy (Average): 0.5457
# Time 3166.0637393780053 seconds
# epoch 35/300 Average Training Loss: 0.203617
# epoch 35/300 Average Estimation Loss (in Source domain): 0.034729
# epoch 35/300 Average Disc Loss (in Source domain): 0.013347
# epoch 35/300 Average Domain Discrimination Loss: 0.691427
# epoch 35/300 For observation only - Average Estimation Loss in Target domain: 0.157137
# epoch 35/300 (Val) Weighted Total Loss: 0.905844
# epoch 35/300 (Val) Average Estimation Loss (mean): 0.215308
# epoch 35/300 (Val) Average Estimation Loss (Source): 0.107632
# epoch 35/300 (Val) Average Estimation Loss (Target): 0.322984
# epoch 35/300 (Val) GAN Discriminator Loss: 0.033154
# epoch 35/300 (Val) Domain Discriminator Loss: 1.380739
# epoch 35/300 (Val) NMSE (Source): 0.048968, NMSE (Target): 0.110736, NMSE (Mean): 0.079852
# epoch 35/300 (Val) Domain Discriminator Accuracy (Average): 0.5385
# Time 3257.3646279800014 seconds
# epoch 36/300 Average Training Loss: 0.203087
# epoch 36/300 Average Estimation Loss (in Source domain): 0.034442
# epoch 36/300 Average Disc Loss (in Source domain): 0.026538
# epoch 36/300 Average Domain Discrimination Loss: 0.692170
# epoch 36/300 For observation only - Average Estimation Loss in Target domain: 0.157820
# epoch 36/300 (Val) Weighted Total Loss: 0.908305
# epoch 36/300 (Val) Average Estimation Loss (mean): 0.216526
# epoch 36/300 (Val) Average Estimation Loss (Source): 0.108593
# epoch 36/300 (Val) Average Estimation Loss (Target): 0.324460
# epoch 36/300 (Val) GAN Discriminator Loss: 0.009778
# epoch 36/300 (Val) Domain Discriminator Loss: 1.383460
# epoch 36/300 (Val) NMSE (Source): 0.049369, NMSE (Target): 0.111047, NMSE (Mean): 0.080208
# epoch 36/300 (Val) Domain Discriminator Accuracy (Average): 0.5337
# Time 3348.425504953004 seconds
# epoch 37/300 Average Training Loss: 0.202433
# epoch 37/300 Average Estimation Loss (in Source domain): 0.033939
# epoch 37/300 Average Disc Loss (in Source domain): 0.018306
# epoch 37/300 Average Domain Discrimination Loss: 0.691353
# epoch 37/300 For observation only - Average Estimation Loss in Target domain: 0.157952
# epoch 37/300 (Val) Weighted Total Loss: 0.905918
# epoch 37/300 (Val) Average Estimation Loss (mean): 0.217871
# epoch 37/300 (Val) Average Estimation Loss (Source): 0.111588
# epoch 37/300 (Val) Average Estimation Loss (Target): 0.324153
# epoch 37/300 (Val) GAN Discriminator Loss: 0.001843
# epoch 37/300 (Val) Domain Discriminator Loss: 1.376076
# epoch 37/300 (Val) NMSE (Source): 0.050870, NMSE (Target): 0.111343, NMSE (Mean): 0.081106
# epoch 37/300 (Val) Domain Discriminator Accuracy (Average): 0.5529
# Time 3439.3160914900072 seconds
# epoch 38/300 Average Training Loss: 0.202475
# epoch 38/300 Average Estimation Loss (in Source domain): 0.033955
# epoch 38/300 Average Disc Loss (in Source domain): 0.011914
# epoch 38/300 Average Domain Discrimination Loss: 0.692522
# epoch 38/300 For observation only - Average Estimation Loss in Target domain: 0.157960
# epoch 38/300 (Val) Weighted Total Loss: 0.903069
# epoch 38/300 (Val) Average Estimation Loss (mean): 0.215387
# epoch 38/300 (Val) Average Estimation Loss (Source): 0.109191
# epoch 38/300 (Val) Average Estimation Loss (Target): 0.321583
# epoch 38/300 (Val) GAN Discriminator Loss: -0.014793
# epoch 38/300 (Val) Domain Discriminator Loss: 1.375512
# epoch 38/300 (Val) NMSE (Source): 0.049512, NMSE (Target): 0.110683, NMSE (Mean): 0.080097
# epoch 38/300 (Val) Domain Discriminator Accuracy (Average): 0.5553
# Time 3530.175409388001 seconds
# epoch 39/300 Average Training Loss: 0.202588
# epoch 39/300 Average Estimation Loss (in Source domain): 0.033735
# epoch 39/300 Average Disc Loss (in Source domain): 0.027030
# epoch 39/300 Average Domain Discrimination Loss: 0.693252
# epoch 39/300 For observation only - Average Estimation Loss in Target domain: 0.158031
# epoch 39/300 (Val) Weighted Total Loss: 0.905306
# epoch 39/300 (Val) Average Estimation Loss (mean): 0.215360
# epoch 39/300 (Val) Average Estimation Loss (Source): 0.107402
# epoch 39/300 (Val) Average Estimation Loss (Target): 0.323317
# epoch 39/300 (Val) GAN Discriminator Loss: 0.011022
# epoch 39/300 (Val) Domain Discriminator Loss: 1.379781
# epoch 39/300 (Val) NMSE (Source): 0.048649, NMSE (Target): 0.111088, NMSE (Mean): 0.079868
# epoch 39/300 (Val) Domain Discriminator Accuracy (Average): 0.5721
# Time 3621.2990232980083 seconds
# epoch 40/300 Average Training Loss: 0.202184
# epoch 40/300 Average Estimation Loss (in Source domain): 0.033280
# epoch 40/300 Average Disc Loss (in Source domain): 0.020808
# epoch 40/300 Average Domain Discrimination Loss: 0.693380
# epoch 40/300 For observation only - Average Estimation Loss in Target domain: 0.158277
# epoch 40/300 (Val) Weighted Total Loss: 0.903595
# epoch 40/300 (Val) Average Estimation Loss (mean): 0.215436
# epoch 40/300 (Val) Average Estimation Loss (Source): 0.107096
# epoch 40/300 (Val) Average Estimation Loss (Target): 0.323776
# epoch 40/300 (Val) GAN Discriminator Loss: 0.015757
# epoch 40/300 (Val) Domain Discriminator Loss: 1.376161
# epoch 40/300 (Val) NMSE (Source): 0.048600, NMSE (Target): 0.111286, NMSE (Mean): 0.079943
# epoch 40/300 (Val) Domain Discriminator Accuracy (Average): 0.5649
# Time 3712.0819400330074 seconds
# epoch 41/300 Average Training Loss: 0.202051
# epoch 41/300 Average Estimation Loss (in Source domain): 0.032989
# epoch 41/300 Average Disc Loss (in Source domain): 0.009823
# epoch 41/300 Average Domain Discrimination Loss: 0.692902
# epoch 41/300 For observation only - Average Estimation Loss in Target domain: 0.158716
# epoch 41/300 (Val) Weighted Total Loss: 0.903977
# epoch 41/300 (Val) Average Estimation Loss (mean): 0.215725
# epoch 41/300 (Val) Average Estimation Loss (Source): 0.108280
# epoch 41/300 (Val) Average Estimation Loss (Target): 0.323169
# epoch 41/300 (Val) GAN Discriminator Loss: -0.008690
# epoch 41/300 (Val) Domain Discriminator Loss: 1.376591
# epoch 41/300 (Val) NMSE (Source): 0.048925, NMSE (Target): 0.110975, NMSE (Mean): 0.079950
# epoch 41/300 (Val) Domain Discriminator Accuracy (Average): 0.5745
# Time 3802.840215257005 seconds
# epoch 42/300 Average Training Loss: 0.201368
# epoch 42/300 Average Estimation Loss (in Source domain): 0.032443
# epoch 42/300 Average Disc Loss (in Source domain): 0.007194
# epoch 42/300 Average Domain Discrimination Loss: 0.692573
# epoch 42/300 For observation only - Average Estimation Loss in Target domain: 0.158896
# epoch 42/300 (Val) Weighted Total Loss: 0.902593
# epoch 42/300 (Val) Average Estimation Loss (mean): 0.215263
# epoch 42/300 (Val) Average Estimation Loss (Source): 0.106521
# epoch 42/300 (Val) Average Estimation Loss (Target): 0.324005
# epoch 42/300 (Val) GAN Discriminator Loss: -0.001840
# epoch 42/300 (Val) Domain Discriminator Loss: 1.374679
# epoch 42/300 (Val) NMSE (Source): 0.048232, NMSE (Target): 0.111901, NMSE (Mean): 0.080066
# epoch 42/300 (Val) Domain Discriminator Accuracy (Average): 0.5962
# Time 3893.3343996410113 seconds
# epoch 43/300 Average Training Loss: 0.201206
# epoch 43/300 Average Estimation Loss (in Source domain): 0.032191
# epoch 43/300 Average Disc Loss (in Source domain): 0.030872
# epoch 43/300 Average Domain Discrimination Loss: 0.693117
# epoch 43/300 For observation only - Average Estimation Loss in Target domain: 0.159148
# epoch 43/300 (Val) Weighted Total Loss: 0.903119
# epoch 43/300 (Val) Average Estimation Loss (mean): 0.215097
# epoch 43/300 (Val) Average Estimation Loss (Source): 0.107055
# epoch 43/300 (Val) Average Estimation Loss (Target): 0.323139
# epoch 43/300 (Val) GAN Discriminator Loss: -0.022323
# epoch 43/300 (Val) Domain Discriminator Loss: 1.376266
# epoch 43/300 (Val) NMSE (Source): 0.048458, NMSE (Target): 0.111703, NMSE (Mean): 0.080081
# epoch 43/300 (Val) Domain Discriminator Accuracy (Average): 0.5649
# Time 3983.1770550430083 seconds
# epoch 44/300 Average Training Loss: 0.200602
# epoch 44/300 Average Estimation Loss (in Source domain): 0.031693
# epoch 44/300 Average Disc Loss (in Source domain): 0.007913
# epoch 44/300 Average Domain Discrimination Loss: 0.692465
# epoch 44/300 For observation only - Average Estimation Loss in Target domain: 0.159183
# epoch 44/300 (Val) Weighted Total Loss: 0.902130
# epoch 44/300 (Val) Average Estimation Loss (mean): 0.215503
# epoch 44/300 (Val) Average Estimation Loss (Source): 0.106480
# epoch 44/300 (Val) Average Estimation Loss (Target): 0.324527
# epoch 44/300 (Val) GAN Discriminator Loss: -0.005944
# epoch 44/300 (Val) Domain Discriminator Loss: 1.373313
# epoch 44/300 (Val) NMSE (Source): 0.047957, NMSE (Target): 0.111783, NMSE (Mean): 0.079870
# epoch 44/300 (Val) Domain Discriminator Accuracy (Average): 0.5721
# Time 4073.75361302901 seconds
# epoch 45/300 Average Training Loss: 0.200377
# epoch 45/300 Average Estimation Loss (in Source domain): 0.031281
# epoch 45/300 Average Disc Loss (in Source domain): 0.019622
# epoch 45/300 Average Domain Discrimination Loss: 0.692765
# epoch 45/300 For observation only - Average Estimation Loss in Target domain: 0.159355
# epoch 45/300 (Val) Weighted Total Loss: 0.904451
# epoch 45/300 (Val) Average Estimation Loss (mean): 0.216771
# epoch 45/300 (Val) Average Estimation Loss (Source): 0.107752
# epoch 45/300 (Val) Average Estimation Loss (Target): 0.325791
# epoch 45/300 (Val) GAN Discriminator Loss: 0.003220
# epoch 45/300 (Val) Domain Discriminator Loss: 1.375327
# epoch 45/300 (Val) NMSE (Source): 0.048791, NMSE (Target): 0.111701, NMSE (Mean): 0.080246
# epoch 45/300 (Val) Domain Discriminator Accuracy (Average): 0.5577
# Time 4164.069145294998 seconds
# epoch 46/300 Average Training Loss: 0.200132
# epoch 46/300 Average Estimation Loss (in Source domain): 0.031035
# epoch 46/300 Average Disc Loss (in Source domain): 0.018753
# epoch 46/300 Average Domain Discrimination Loss: 0.692771
# epoch 46/300 For observation only - Average Estimation Loss in Target domain: 0.159727
# epoch 46/300 (Val) Weighted Total Loss: 0.906642
# epoch 46/300 (Val) Average Estimation Loss (mean): 0.217446
# epoch 46/300 (Val) Average Estimation Loss (Source): 0.108866
# epoch 46/300 (Val) Average Estimation Loss (Target): 0.326025
# epoch 46/300 (Val) GAN Discriminator Loss: 0.020128
# epoch 46/300 (Val) Domain Discriminator Loss: 1.378192
# epoch 46/300 (Val) NMSE (Source): 0.049445, NMSE (Target): 0.112131, NMSE (Mean): 0.080788
# epoch 46/300 (Val) Domain Discriminator Accuracy (Average): 0.5409
# Time 4254.235231350001 seconds
# epoch 47/300 Average Training Loss: 0.199599
# epoch 47/300 Average Estimation Loss (in Source domain): 0.030628
# epoch 47/300 Average Disc Loss (in Source domain): 0.009890
# epoch 47/300 Average Domain Discrimination Loss: 0.692773
# epoch 47/300 For observation only - Average Estimation Loss in Target domain: 0.160013
# epoch 47/300 (Val) Weighted Total Loss: 0.906816
# epoch 47/300 (Val) Average Estimation Loss (mean): 0.217814
# epoch 47/300 (Val) Average Estimation Loss (Source): 0.108889
# epoch 47/300 (Val) Average Estimation Loss (Target): 0.326740
# epoch 47/300 (Val) GAN Discriminator Loss: 0.043360
# epoch 47/300 (Val) Domain Discriminator Loss: 1.377571
# epoch 47/300 (Val) NMSE (Source): 0.049462, NMSE (Target): 0.112139, NMSE (Mean): 0.080800
# epoch 47/300 (Val) Domain Discriminator Accuracy (Average): 0.5601
# Time 4344.572192987005 seconds
# epoch 48/300 Average Training Loss: 0.199166
# epoch 48/300 Average Estimation Loss (in Source domain): 0.030246
# epoch 48/300 Average Disc Loss (in Source domain): 0.005134
# epoch 48/300 Average Domain Discrimination Loss: 0.692753
# epoch 48/300 For observation only - Average Estimation Loss in Target domain: 0.160435
# epoch 48/300 (Val) Weighted Total Loss: 0.909739
# epoch 48/300 (Val) Average Estimation Loss (mean): 0.221258
# epoch 48/300 (Val) Average Estimation Loss (Source): 0.110408
# epoch 48/300 (Val) Average Estimation Loss (Target): 0.332108
# epoch 48/300 (Val) GAN Discriminator Loss: 0.026442
# epoch 48/300 (Val) Domain Discriminator Loss: 1.376698
# epoch 48/300 (Val) NMSE (Source): 0.050361, NMSE (Target): 0.114625, NMSE (Mean): 0.082493
# epoch 48/300 (Val) Domain Discriminator Accuracy (Average): 0.5481
# Time 4434.6559723300015 seconds
# epoch 49/300 Average Training Loss: 0.198474
# epoch 49/300 Average Estimation Loss (in Source domain): 0.029865
# epoch 49/300 Average Disc Loss (in Source domain): 0.002752
# epoch 49/300 Average Domain Discrimination Loss: 0.692393
# epoch 49/300 For observation only - Average Estimation Loss in Target domain: 0.160897
# epoch 49/300 (Val) Weighted Total Loss: 0.907855
# epoch 49/300 (Val) Average Estimation Loss (mean): 0.218793
# epoch 49/300 (Val) Average Estimation Loss (Source): 0.110048
# epoch 49/300 (Val) Average Estimation Loss (Target): 0.327538
# epoch 49/300 (Val) GAN Discriminator Loss: -0.007868
# epoch 49/300 (Val) Domain Discriminator Loss: 1.378203
# epoch 49/300 (Val) NMSE (Source): 0.050185, NMSE (Target): 0.113539, NMSE (Mean): 0.081862
# epoch 49/300 (Val) Domain Discriminator Accuracy (Average): 0.5457
# Time 4525.721307699001 seconds
# epoch 50/300 Average Training Loss: 0.198440
# epoch 50/300 Average Estimation Loss (in Source domain): 0.029740
# epoch 50/300 Average Disc Loss (in Source domain): 0.013166
# epoch 50/300 Average Domain Discrimination Loss: 0.693163
# epoch 50/300 For observation only - Average Estimation Loss in Target domain: 0.160851
# epoch 50/300 (Val) Weighted Total Loss: 0.909286
# epoch 50/300 (Val) Average Estimation Loss (mean): 0.220275
# epoch 50/300 (Val) Average Estimation Loss (Source): 0.110343
# epoch 50/300 (Val) Average Estimation Loss (Target): 0.330208
# epoch 50/300 (Val) GAN Discriminator Loss: 0.010866
# epoch 50/300 (Val) Domain Discriminator Loss: 1.377913
# epoch 50/300 (Val) NMSE (Source): 0.050508, NMSE (Target): 0.114660, NMSE (Mean): 0.082584
# epoch 50/300 (Val) Domain Discriminator Accuracy (Average): 0.5649
# Time 4616.309165893006 seconds
# epoch 51/300 Average Training Loss: 0.198409
# epoch 51/300 Average Estimation Loss (in Source domain): 0.029499
# epoch 51/300 Average Disc Loss (in Source domain): -0.001237
# epoch 51/300 Average Domain Discrimination Loss: 0.693054
# epoch 51/300 For observation only - Average Estimation Loss in Target domain: 0.161051
# epoch 51/300 (Val) Weighted Total Loss: 0.910553
# epoch 51/300 (Val) Average Estimation Loss (mean): 0.222542
# epoch 51/300 (Val) Average Estimation Loss (Source): 0.112375
# epoch 51/300 (Val) Average Estimation Loss (Target): 0.332709
# epoch 51/300 (Val) GAN Discriminator Loss: -0.004962
# epoch 51/300 (Val) Domain Discriminator Loss: 1.376072
# epoch 51/300 (Val) NMSE (Source): 0.051464, NMSE (Target): 0.115217, NMSE (Mean): 0.083341
# epoch 51/300 (Val) Domain Discriminator Accuracy (Average): 0.5697
# Time 4708.66798363901 seconds
# epoch 52/300 Average Training Loss: 0.198110
# epoch 52/300 Average Estimation Loss (in Source domain): 0.029286
# epoch 52/300 Average Disc Loss (in Source domain): 0.021631
# epoch 52/300 Average Domain Discrimination Loss: 0.692744
# epoch 52/300 For observation only - Average Estimation Loss in Target domain: 0.161530
# epoch 52/300 (Val) Weighted Total Loss: 0.911273
# epoch 52/300 (Val) Average Estimation Loss (mean): 0.221535
# epoch 52/300 (Val) Average Estimation Loss (Source): 0.112447
# epoch 52/300 (Val) Average Estimation Loss (Target): 0.330622
# epoch 52/300 (Val) GAN Discriminator Loss: -0.000639
# epoch 52/300 (Val) Domain Discriminator Loss: 1.379483
# epoch 52/300 (Val) NMSE (Source): 0.051369, NMSE (Target): 0.114159, NMSE (Mean): 0.082764
# epoch 52/300 (Val) Domain Discriminator Accuracy (Average): 0.5505
# Time 4799.436737144002 seconds
# epoch 53/300 Average Training Loss: 0.198094
# epoch 53/300 Average Estimation Loss (in Source domain): 0.029017
# epoch 53/300 Average Disc Loss (in Source domain): 0.011561
# epoch 53/300 Average Domain Discrimination Loss: 0.693511
# epoch 53/300 For observation only - Average Estimation Loss in Target domain: 0.161899
# epoch 53/300 (Val) Weighted Total Loss: 0.912960
# epoch 53/300 (Val) Average Estimation Loss (mean): 0.223325
# epoch 53/300 (Val) Average Estimation Loss (Source): 0.111649
# epoch 53/300 (Val) Average Estimation Loss (Target): 0.335000
# epoch 53/300 (Val) GAN Discriminator Loss: -0.048478
# epoch 53/300 (Val) Domain Discriminator Loss: 1.379755
# epoch 53/300 (Val) NMSE (Source): 0.051101, NMSE (Target): 0.116616, NMSE (Mean): 0.083859
# epoch 53/300 (Val) Domain Discriminator Accuracy (Average): 0.5288
# Time 4890.417491144006 seconds
# epoch 54/300 Average Training Loss: 0.197701
# epoch 54/300 Average Estimation Loss (in Source domain): 0.028697
# epoch 54/300 Average Disc Loss (in Source domain): 0.019716
# epoch 54/300 Average Domain Discrimination Loss: 0.692697
# epoch 54/300 For observation only - Average Estimation Loss in Target domain: 0.162114
# epoch 54/300 (Val) Weighted Total Loss: 0.909133
# epoch 54/300 (Val) Average Estimation Loss (mean): 0.220501
# epoch 54/300 (Val) Average Estimation Loss (Source): 0.111098
# epoch 54/300 (Val) Average Estimation Loss (Target): 0.329903
# epoch 54/300 (Val) GAN Discriminator Loss: -0.001943
# epoch 54/300 (Val) Domain Discriminator Loss: 1.377284
# epoch 54/300 (Val) NMSE (Source): 0.050603, NMSE (Target): 0.114112, NMSE (Mean): 0.082357
# epoch 54/300 (Val) Domain Discriminator Accuracy (Average): 0.5361
# Time 4981.262910773003 seconds
# epoch 55/300 Average Training Loss: 0.197082
# epoch 55/300 Average Estimation Loss (in Source domain): 0.028334
# epoch 55/300 Average Disc Loss (in Source domain): 0.017595
# epoch 55/300 Average Domain Discrimination Loss: 0.692631
# epoch 55/300 For observation only - Average Estimation Loss in Target domain: 0.162235
# epoch 55/300 (Val) Weighted Total Loss: 0.907190
# epoch 55/300 (Val) Average Estimation Loss (mean): 0.219826
# epoch 55/300 (Val) Average Estimation Loss (Source): 0.109218
# epoch 55/300 (Val) Average Estimation Loss (Target): 0.330434
# epoch 55/300 (Val) GAN Discriminator Loss: -0.028160
# epoch 55/300 (Val) Domain Discriminator Loss: 1.375011
# epoch 55/300 (Val) NMSE (Source): 0.049961, NMSE (Target): 0.114788, NMSE (Mean): 0.082375
# epoch 55/300 (Val) Domain Discriminator Accuracy (Average): 0.5505
# Time 5072.1102168070065 seconds
# epoch 56/300 Average Training Loss: 0.196706
# epoch 56/300 Average Estimation Loss (in Source domain): 0.027964
# epoch 56/300 Average Disc Loss (in Source domain): 0.003648
# epoch 56/300 Average Domain Discrimination Loss: 0.692740
# epoch 56/300 For observation only - Average Estimation Loss in Target domain: 0.161654
# epoch 56/300 (Val) Weighted Total Loss: 0.909510
# epoch 56/300 (Val) Average Estimation Loss (mean): 0.222563
# epoch 56/300 (Val) Average Estimation Loss (Source): 0.109149
# epoch 56/300 (Val) Average Estimation Loss (Target): 0.335977
# epoch 56/300 (Val) GAN Discriminator Loss: -0.003954
# epoch 56/300 (Val) Domain Discriminator Loss: 1.373934
# epoch 56/300 (Val) NMSE (Source): 0.050133, NMSE (Target): 0.116166, NMSE (Mean): 0.083149
# epoch 56/300 (Val) Domain Discriminator Accuracy (Average): 0.5553
# Time 5162.812452236001 seconds
# epoch 57/300 Average Training Loss: 0.196460
# epoch 57/300 Average Estimation Loss (in Source domain): 0.027823
# epoch 57/300 Average Disc Loss (in Source domain): 0.005409
# epoch 57/300 Average Domain Discrimination Loss: 0.692468
# epoch 57/300 For observation only - Average Estimation Loss in Target domain: 0.162329
# epoch 57/300 (Val) Weighted Total Loss: 0.907456
# epoch 57/300 (Val) Average Estimation Loss (mean): 0.221177
# epoch 57/300 (Val) Average Estimation Loss (Source): 0.109595
# epoch 57/300 (Val) Average Estimation Loss (Target): 0.332759
# epoch 57/300 (Val) GAN Discriminator Loss: -0.014386
# epoch 57/300 (Val) Domain Discriminator Loss: 1.372700
# ...
# epoch 282/300 (Val) Weighted Total Loss: 0.905450
# epoch 282/300 (Val) Average Estimation Loss (mean): 0.213368
# epoch 282/300 (Val) Average Estimation Loss (Source): 0.104099
# epoch 282/300 (Val) Average Estimation Loss (Target): 0.322637
# epoch 282/300 (Val) GAN Discriminator Loss: -0.152253
# epoch 282/300 (Val) Domain Discriminator Loss: 1.385687
# epoch 282/300 (Val) NMSE (Source): 0.046337, NMSE (Target): 0.110984, NMSE (Mean): 0.078660
# epoch 282/300 (Val) Domain Discriminator Accuracy (Average): 0.5312
# Time 25813.006657375998 seconds
# epoch 283/300 Average Training Loss: 0.182410
# epoch 283/300 Average Estimation Loss (in Source domain): 0.009934
# epoch 283/300 Average Disc Loss (in Source domain): -0.065853
# epoch 283/300 Average Domain Discrimination Loss: 0.693181
# epoch 283/300 For observation only - Average Estimation Loss in Target domain: 0.164065
# epoch 283/300 (Val) Weighted Total Loss: 0.901849
# epoch 283/300 (Val) Average Estimation Loss (mean): 0.209817
# epoch 283/300 (Val) Average Estimation Loss (Source): 0.103341
# epoch 283/300 (Val) Average Estimation Loss (Target): 0.316293
# epoch 283/300 (Val) GAN Discriminator Loss: -0.139201
# epoch 283/300 (Val) Domain Discriminator Loss: 1.385457
# epoch 283/300 (Val) NMSE (Source): 0.045782, NMSE (Target): 0.107478, NMSE (Mean): 0.076630
# epoch 283/300 (Val) Domain Discriminator Accuracy (Average): 0.5433
# Time 25902.865691193 seconds
# epoch 284/300 Average Training Loss: 0.182323
# epoch 284/300 Average Estimation Loss (in Source domain): 0.009918
# epoch 284/300 Average Disc Loss (in Source domain): -0.065310
# epoch 284/300 Average Domain Discrimination Loss: 0.693188
# epoch 284/300 For observation only - Average Estimation Loss in Target domain: 0.164220
# epoch 284/300 (Val) Weighted Total Loss: 0.903466
# epoch 284/300 (Val) Average Estimation Loss (mean): 0.211516
# epoch 284/300 (Val) Average Estimation Loss (Source): 0.103841
# epoch 284/300 (Val) Average Estimation Loss (Target): 0.319190
# epoch 284/300 (Val) GAN Discriminator Loss: -0.151056
# epoch 284/300 (Val) Domain Discriminator Loss: 1.385412
# epoch 284/300 (Val) NMSE (Source): 0.046132, NMSE (Target): 0.107932, NMSE (Mean): 0.077032
# epoch 284/300 (Val) Domain Discriminator Accuracy (Average): 0.5168
# Time 25992.809258098 seconds
# epoch 285/300 Average Training Loss: 0.182235
# epoch 285/300 Average Estimation Loss (in Source domain): 0.009934
# epoch 285/300 Average Disc Loss (in Source domain): -0.066927
# epoch 285/300 Average Domain Discrimination Loss: 0.693144
# epoch 285/300 For observation only - Average Estimation Loss in Target domain: 0.163856
# epoch 285/300 (Val) Weighted Total Loss: 0.909690
# epoch 285/300 (Val) Average Estimation Loss (mean): 0.217975
# epoch 285/300 (Val) Average Estimation Loss (Source): 0.105761
# epoch 285/300 (Val) Average Estimation Loss (Target): 0.330190
# epoch 285/300 (Val) GAN Discriminator Loss: -0.151938
# epoch 285/300 (Val) Domain Discriminator Loss: 1.384949
# epoch 285/300 (Val) NMSE (Source): 0.047640, NMSE (Target): 0.112007, NMSE (Mean): 0.079824
# epoch 285/300 (Val) Domain Discriminator Accuracy (Average): 0.5288
# Time 26082.247830677006 seconds
# epoch 286/300 Average Training Loss: 0.182131
# epoch 286/300 Average Estimation Loss (in Source domain): 0.009994
# epoch 286/300 Average Disc Loss (in Source domain): -0.065271
# epoch 286/300 Average Domain Discrimination Loss: 0.693107
# epoch 286/300 For observation only - Average Estimation Loss in Target domain: 0.164030
# epoch 286/300 (Val) Weighted Total Loss: 0.914559
# epoch 286/300 (Val) Average Estimation Loss (mean): 0.223145
# epoch 286/300 (Val) Average Estimation Loss (Source): 0.109340
# epoch 286/300 (Val) Average Estimation Loss (Target): 0.336950
# epoch 286/300 (Val) GAN Discriminator Loss: -0.155940
# epoch 286/300 (Val) Domain Discriminator Loss: 1.384387
# epoch 286/300 (Val) NMSE (Source): 0.049522, NMSE (Target): 0.114543, NMSE (Mean): 0.082032
# epoch 286/300 (Val) Domain Discriminator Accuracy (Average): 0.5481
# Time 26171.911702026002 seconds
# epoch 287/300 Average Training Loss: 0.181922
# epoch 287/300 Average Estimation Loss (in Source domain): 0.010048
# epoch 287/300 Average Disc Loss (in Source domain): -0.065865
# epoch 287/300 Average Domain Discrimination Loss: 0.693017
# epoch 287/300 For observation only - Average Estimation Loss in Target domain: 0.163850
# epoch 287/300 (Val) Weighted Total Loss: 0.914927
# epoch 287/300 (Val) Average Estimation Loss (mean): 0.223687
# epoch 287/300 (Val) Average Estimation Loss (Source): 0.108212
# epoch 287/300 (Val) Average Estimation Loss (Target): 0.339162
# epoch 287/300 (Val) GAN Discriminator Loss: -0.162948
# epoch 287/300 (Val) Domain Discriminator Loss: 1.384109
# epoch 287/300 (Val) NMSE (Source): 0.049112, NMSE (Target): 0.115270, NMSE (Mean): 0.082191
# epoch 287/300 (Val) Domain Discriminator Accuracy (Average): 0.5385
# Time 26262.516732046002 seconds
# epoch 288/300 Average Training Loss: 0.181473
# epoch 288/300 Average Estimation Loss (in Source domain): 0.010020
# epoch 288/300 Average Disc Loss (in Source domain): -0.067112
# epoch 288/300 Average Domain Discrimination Loss: 0.692859
# epoch 288/300 For observation only - Average Estimation Loss in Target domain: 0.163914
# epoch 288/300 (Val) Weighted Total Loss: 0.911495
# epoch 288/300 (Val) Average Estimation Loss (mean): 0.220389
# epoch 288/300 (Val) Average Estimation Loss (Source): 0.106560
# epoch 288/300 (Val) Average Estimation Loss (Target): 0.334217
# epoch 288/300 (Val) GAN Discriminator Loss: -0.154701
# epoch 288/300 (Val) Domain Discriminator Loss: 1.383760
# epoch 288/300 (Val) NMSE (Source): 0.048131, NMSE (Target): 0.113761, NMSE (Mean): 0.080946
# epoch 288/300 (Val) Domain Discriminator Accuracy (Average): 0.5529
# Time 26352.205313130005 seconds
# epoch 289/300 Average Training Loss: 0.181035
# epoch 289/300 Average Estimation Loss (in Source domain): 0.010329
# epoch 289/300 Average Disc Loss (in Source domain): -0.066345
# epoch 289/300 Average Domain Discrimination Loss: 0.692631
# epoch 289/300 For observation only - Average Estimation Loss in Target domain: 0.164040
# epoch 289/300 (Val) Weighted Total Loss: 0.909464
# epoch 289/300 (Val) Average Estimation Loss (mean): 0.219199
# epoch 289/300 (Val) Average Estimation Loss (Source): 0.106599
# epoch 289/300 (Val) Average Estimation Loss (Target): 0.331798
# epoch 289/300 (Val) GAN Discriminator Loss: -0.164754
# epoch 289/300 (Val) Domain Discriminator Loss: 1.382177
# epoch 289/300 (Val) NMSE (Source): 0.047696, NMSE (Target): 0.112814, NMSE (Mean): 0.080255
# epoch 289/300 (Val) Domain Discriminator Accuracy (Average): 0.5577
# Time 26441.93701052101 seconds
# epoch 290/300 Average Training Loss: 0.180126
# epoch 290/300 Average Estimation Loss (in Source domain): 0.010746
# epoch 290/300 Average Disc Loss (in Source domain): -0.066891
# epoch 290/300 Average Domain Discrimination Loss: 0.691680
# epoch 290/300 For observation only - Average Estimation Loss in Target domain: 0.163860
# epoch 290/300 (Val) Weighted Total Loss: 0.907646
# epoch 290/300 (Val) Average Estimation Loss (mean): 0.218282
# epoch 290/300 (Val) Average Estimation Loss (Source): 0.107540
# epoch 290/300 (Val) Average Estimation Loss (Target): 0.329024
# epoch 290/300 (Val) GAN Discriminator Loss: -0.162109
# epoch 290/300 (Val) Domain Discriminator Loss: 1.380348
# epoch 290/300 (Val) NMSE (Source): 0.048262, NMSE (Target): 0.112242, NMSE (Mean): 0.080252
# epoch 290/300 (Val) Domain Discriminator Accuracy (Average): 0.5409
# Time 26532.26766512901 seconds
# epoch 291/300 Average Training Loss: 0.178518
# epoch 291/300 Average Estimation Loss (in Source domain): 0.011461
# epoch 291/300 Average Disc Loss (in Source domain): -0.068330
# epoch 291/300 Average Domain Discrimination Loss: 0.690092
# epoch 291/300 For observation only - Average Estimation Loss in Target domain: 0.164568
# epoch 291/300 (Val) Weighted Total Loss: 0.903572
# epoch 291/300 (Val) Average Estimation Loss (mean): 0.217340
# epoch 291/300 (Val) Average Estimation Loss (Source): 0.106964
# epoch 291/300 (Val) Average Estimation Loss (Target): 0.327716
# epoch 291/300 (Val) GAN Discriminator Loss: -0.158515
# epoch 291/300 (Val) Domain Discriminator Loss: 1.374049
# epoch 291/300 (Val) NMSE (Source): 0.047898, NMSE (Target): 0.111514, NMSE (Mean): 0.079706
# epoch 291/300 (Val) Domain Discriminator Accuracy (Average): 0.5721
# Time 26621.45163098401 seconds
# epoch 292/300 Average Training Loss: 0.175506
# epoch 292/300 Average Estimation Loss (in Source domain): 0.012800
# epoch 292/300 Average Disc Loss (in Source domain): -0.070222
# epoch 292/300 Average Domain Discrimination Loss: 0.685552
# epoch 292/300 For observation only - Average Estimation Loss in Target domain: 0.164814
# epoch 292/300 (Val) Weighted Total Loss: 0.900473
# epoch 292/300 (Val) Average Estimation Loss (mean): 0.217390
# epoch 292/300 (Val) Average Estimation Loss (Source): 0.105039
# epoch 292/300 (Val) Average Estimation Loss (Target): 0.329742
# epoch 292/300 (Val) GAN Discriminator Loss: -0.161366
# epoch 292/300 (Val) Domain Discriminator Loss: 1.367780
# epoch 292/300 (Val) NMSE (Source): 0.047176, NMSE (Target): 0.112218, NMSE (Mean): 0.079697
# epoch 292/300 (Val) Domain Discriminator Accuracy (Average): 0.5793
# Time 26711.50060127501 seconds
# epoch 293/300 Average Training Loss: 0.171868
# epoch 293/300 Average Estimation Loss (in Source domain): 0.015149
# epoch 293/300 Average Disc Loss (in Source domain): -0.070797
# epoch 293/300 Average Domain Discrimination Loss: 0.679150
# epoch 293/300 For observation only - Average Estimation Loss in Target domain: 0.164643
# epoch 293/300 (Val) Weighted Total Loss: 0.896331
# epoch 293/300 (Val) Average Estimation Loss (mean): 0.216698
# epoch 293/300 (Val) Average Estimation Loss (Source): 0.104474
# epoch 293/300 (Val) Average Estimation Loss (Target): 0.328923
# epoch 293/300 (Val) GAN Discriminator Loss: -0.159764
# epoch 293/300 (Val) Domain Discriminator Loss: 1.360862
# epoch 293/300 (Val) NMSE (Source): 0.047081, NMSE (Target): 0.112726, NMSE (Mean): 0.079903
# epoch 293/300 (Val) Domain Discriminator Accuracy (Average): 0.5649
# Time 26802.188609795005 seconds
# epoch 294/300 Average Training Loss: 0.171166
# epoch 294/300 Average Estimation Loss (in Source domain): 0.018313
# epoch 294/300 Average Disc Loss (in Source domain): -0.070501
# epoch 294/300 Average Domain Discrimination Loss: 0.674911
# epoch 294/300 For observation only - Average Estimation Loss in Target domain: 0.163743
# epoch 294/300 (Val) Weighted Total Loss: 0.884215
# epoch 294/300 (Val) Average Estimation Loss (mean): 0.210838
# epoch 294/300 (Val) Average Estimation Loss (Source): 0.106309
# epoch 294/300 (Val) Average Estimation Loss (Target): 0.315367
# epoch 294/300 (Val) GAN Discriminator Loss: -0.157504
# epoch 294/300 (Val) Domain Discriminator Loss: 1.348329
# epoch 294/300 (Val) NMSE (Source): 0.047881, NMSE (Target): 0.108173, NMSE (Mean): 0.078027
# epoch 294/300 (Val) Domain Discriminator Accuracy (Average): 0.5721
# Time 26892.191493371007 seconds
# epoch 295/300 Average Training Loss: 0.174166
# epoch 295/300 Average Estimation Loss (in Source domain): 0.020856
# epoch 295/300 Average Disc Loss (in Source domain): -0.074818
# epoch 295/300 Average Domain Discrimination Loss: 0.682353
# epoch 295/300 For observation only - Average Estimation Loss in Target domain: 0.163291
# epoch 295/300 (Val) Weighted Total Loss: 0.897354
# epoch 295/300 (Val) Average Estimation Loss (mean): 0.212313
# epoch 295/300 (Val) Average Estimation Loss (Source): 0.105676
# epoch 295/300 (Val) Average Estimation Loss (Target): 0.318951
# epoch 295/300 (Val) GAN Discriminator Loss: -0.163054
# epoch 295/300 (Val) Domain Discriminator Loss: 1.371711
# epoch 295/300 (Val) NMSE (Source): 0.047728, NMSE (Target): 0.109639, NMSE (Mean): 0.078684
# epoch 295/300 (Val) Domain Discriminator Accuracy (Average): 0.5601
# Time 26982.61393351 seconds
# epoch 296/300 Average Training Loss: 0.178254
# epoch 296/300 Average Estimation Loss (in Source domain): 0.022512
# epoch 296/300 Average Disc Loss (in Source domain): -0.077126
# epoch 296/300 Average Domain Discrimination Loss: 0.688543
# epoch 296/300 For observation only - Average Estimation Loss in Target domain: 0.162622
# epoch 296/300 (Val) Weighted Total Loss: 0.901362
# epoch 296/300 (Val) Average Estimation Loss (mean): 0.218238
# epoch 296/300 (Val) Average Estimation Loss (Source): 0.106228
# epoch 296/300 (Val) Average Estimation Loss (Target): 0.330249
# epoch 296/300 (Val) GAN Discriminator Loss: -0.176087
# epoch 296/300 (Val) Domain Discriminator Loss: 1.368008
# epoch 296/300 (Val) NMSE (Source): 0.048154, NMSE (Target): 0.113766, NMSE (Mean): 0.080960
# epoch 296/300 (Val) Domain Discriminator Accuracy (Average): 0.5529
# Time 27072.520568062 seconds
# epoch 297/300 Average Training Loss: 0.183094
# epoch 297/300 Average Estimation Loss (in Source domain): 0.022054
# epoch 297/300 Average Disc Loss (in Source domain): -0.078165
# epoch 297/300 Average Domain Discrimination Loss: 0.696942
# epoch 297/300 For observation only - Average Estimation Loss in Target domain: 0.162560
# epoch 297/300 (Val) Weighted Total Loss: 0.901317
# epoch 297/300 (Val) Average Estimation Loss (mean): 0.217266
# epoch 297/300 (Val) Average Estimation Loss (Source): 0.105962
# epoch 297/300 (Val) Average Estimation Loss (Target): 0.328571
# epoch 297/300 (Val) GAN Discriminator Loss: -0.166941
# epoch 297/300 (Val) Domain Discriminator Loss: 1.369771
# epoch 297/300 (Val) NMSE (Source): 0.047802, NMSE (Target): 0.112994, NMSE (Mean): 0.080398
# epoch 297/300 (Val) Domain Discriminator Accuracy (Average): 0.5793
# Time 27161.97126673501 seconds
# epoch 298/300 Average Training Loss: 0.185316
# epoch 298/300 Average Estimation Loss (in Source domain): 0.020506
# epoch 298/300 Average Disc Loss (in Source domain): -0.076423
# epoch 298/300 Average Domain Discrimination Loss: 0.700705
# epoch 298/300 For observation only - Average Estimation Loss in Target domain: 0.162566
# epoch 298/300 (Val) Weighted Total Loss: 0.907264
# epoch 298/300 (Val) Average Estimation Loss (mean): 0.218916
# epoch 298/300 (Val) Average Estimation Loss (Source): 0.104688
# epoch 298/300 (Val) Average Estimation Loss (Target): 0.333143
# epoch 298/300 (Val) GAN Discriminator Loss: -0.169644
# epoch 298/300 (Val) Domain Discriminator Loss: 1.378394
# epoch 298/300 (Val) NMSE (Source): 0.047292, NMSE (Target): 0.114160, NMSE (Mean): 0.080726
# epoch 298/300 (Val) Domain Discriminator Accuracy (Average): 0.5601
# Time 27252.202756184008 seconds
# epoch 299/300 Average Training Loss: 0.187152
# epoch 299/300 Average Estimation Loss (in Source domain): 0.018287
# epoch 299/300 Average Disc Loss (in Source domain): -0.075986
# epoch 299/300 Average Domain Discrimination Loss: 0.702727
# epoch 299/300 For observation only - Average Estimation Loss in Target domain: 0.163447
# epoch 299/300 (Val) Weighted Total Loss: 0.912241
# epoch 299/300 (Val) Average Estimation Loss (mean): 0.219371
# epoch 299/300 (Val) Average Estimation Loss (Source): 0.106310
# epoch 299/300 (Val) Average Estimation Loss (Target): 0.332431
# epoch 299/300 (Val) GAN Discriminator Loss: -0.166572
# epoch 299/300 (Val) Domain Discriminator Loss: 1.387405
# epoch 299/300 (Val) NMSE (Source): 0.047786, NMSE (Target): 0.114070, NMSE (Mean): 0.080928
# epoch 299/300 (Val) Domain Discriminator Accuracy (Average): 0.5024
# Time 27342.42675515001 seconds
# epoch 300/300 Average Training Loss: 0.187503
# epoch 300/300 Average Estimation Loss (in Source domain): 0.015992
# epoch 300/300 Average Disc Loss (in Source domain): -0.076436
# epoch 300/300 Average Domain Discrimination Loss: 0.700691
# epoch 300/300 For observation only - Average Estimation Loss in Target domain: 0.164047
# epoch 300/300 (Val) Weighted Total Loss: 0.910691
# epoch 300/300 (Val) Average Estimation Loss (mean): 0.217792
# epoch 300/300 (Val) Average Estimation Loss (Source): 0.105858
# epoch 300/300 (Val) Average Estimation Loss (Target): 0.329725
# epoch 300/300 (Val) GAN Discriminator Loss: -0.165390
# epoch 300/300 (Val) Domain Discriminator Loss: 1.387452
# epoch 300/300 (Val) NMSE (Source): 0.047686, NMSE (Target): 0.112721, NMSE (Mean): 0.080204
# epoch 300/300 (Val) Domain Discriminator Accuracy (Average): 0.5096

# %%
pad_observe_svm
# Out:
# [0.9152173913043478, 0.9195652173913045, 1.0282608695652176]

# %%
pad_observe_lda
# Out:
# [0.473913043478261, 0.3217391304347825, 0.606521739130435]

# %%
epoc_pad
# Out:
# [75, 150, 225]

# %%
pad_observe_logreg
# Out:
# [0.4695652173913043, 0.31739130434782625, 0.606521739130435]

# %%
plotfig.figLoss(line_list=[(val_gan_disc_loss, 'Val Disc Loss')], xlabel='Epoch', ylabel='BCE',
                        title='Val GAN Disc Loss', fig_show=True, fig_name='Loss')

# %%
plotfig.figLoss(line_list=[(train_disc_loss, 'Train Disc Loss'), (val_gan_disc_loss, 'Val Disc Loss')], xlabel='Epoch', ylabel='BCE',
                        title='Val GAN Disc Loss', fig_show=True, fig_name='Loss')

# %%
plotfig.figLoss(line_list=[(train_disc_loss[70:], 'Train Disc Loss'), (val_gan_disc_loss[70:], 'Val Disc Loss')], xlabel='Epoch', ylabel='BCE',
                        title='Val GAN Disc Loss', fig_show=True, fig_name='Loss')

# %%
plotfig.figLoss(line_list=[(val_est_loss, 'Val Gen Loss'), (train_est_loss, 'Train Gen Loss')], xlabel='Epoch', ylabel='MSE',
                        title='MSE Loss', fig_show=True, fig_name='Loss')

# %%
plotfig.figLoss(line_list=[(nmse_val_source, 'Val NMSE')], xlabel='Epoch', ylabel='NMSE',
                        title='NMSE Val', fig_show=True, fig_name='Loss')

# %%
subload_GAN = notebook_dir + '/model/GAN'
subload_ = notebook_dir + '/model/GAN'

# %%
nmse_source_LI = []
nmse_target_LI = []
nmse_source_practical = []
nmse_target_practical = []
nmse_source_LI_GAN = []
nmse_target_LI_GAN = []
nmse_source_practical_GAN = []
nmse_target_practical_GAN = []

SNR_dB_ = np.arange(-15, 1, 5)

# %%
import scipy.io as sio

iver = 33
# Load the .mat file
# mat_data = sio.loadmat(f"{subload_GAN}/ver{iver}_/GAN_linear/performance/performance.mat")
mat_data = sio.loadmat(f"{subload_GAN}/ver{iver}_/GAN_practical/performance/performance.mat")

# Check the keys inside the file
print(mat_data.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'train_loss', 'train_est_loss', 'train_disc_loss', 'train_domain_loss', 'train_est_loss_target', 'val_est_loss', 'val_est_loss_source', 'val_loss', 'val_est_loss_target', 'val_gan_disc_loss', 'val_domain_disc_loss', 'source_acc', 'target_acc', 'acc', 'nmse_val_source', 'nmse_val_target', 'nmse_val', 'pad_observe', 'epoc_pad'])

# %% [markdown]
# -5 practical
# -5 linear

# %%
nmse_source_LI.append(mat_data['nmse_val_source'][0][0])
nmse_target_LI.append(mat_data['nmse_val_target'][0][0])
nmse_source_LI_GAN.append(mat_data['nmse_val_source'][0][-1])
nmse_target_LI_GAN.append(mat_data['nmse_val_target'][0][-1])

# %%
nmse_source_practical.append(mat_data['nmse_val_source'][0][0])
nmse_target_practical.append(mat_data['nmse_val_target'][0][0])
nmse_source_practical_GAN.append(mat_data['nmse_val_source'][0][-1])
nmse_target_practical_GAN.append(mat_data['nmse_val_target'][0][-1])

# %%
print(nmse_source_LI)
print(nmse_target_LI)
print(nmse_source_practical)
print(nmse_target_practical)
print(nmse_source_LI_GAN)
print(nmse_target_LI_GAN)
print(nmse_source_practical_GAN)
print(nmse_target_practical_GAN)
# Out:
# [np.float32(0.5314477), np.float32(0.17493351), np.float32(0.060796823), np.float32(0.026024938)]
# [np.float32(0.5534424), np.float32(0.21980993), np.float32(0.07586707), np.float32(0.037570745)]
# [np.float32(0.06439132), np.float32(0.034551684), np.float32(0.034207717), np.float32(0.014883802)]
# [np.float32(0.11248367), np.float32(0.08652819), np.float32(0.058597803), np.float32(0.02194548)]
# [np.float32(0.0880882), np.float32(0.038720086), np.float32(0.017131384), np.float32(0.0061257677)]
# [np.float32(0.11491652), np.float32(0.06090325), np.float32(0.025494127), np.float32(0.015823971)]
# [np.float32(0.047686353), np.float32(0.020024495), np.float32(0.01094668), np.float32(0.003343522)]
# [np.float32(0.11272094), np.float32(0.08703257), np.float32(0.043296788), np.float32(0.012802502)]

# %%
print(model_path + '/' + sub_folder + '/parameters/syn.mat')
# Out:
# /home/thien/Code/H_predict_UDA/H_predict_Sionna/Domain_Adaptation/Domain_Adversarial/model/GAN/ver37_/GAN_practical/parameters/syn.mat

# %%
savemat(model_path + '/syn.mat', {
    "nmse_source_LI": nmse_source_LI,
    "nmse_target_LI": nmse_target_LI,
    "nmse_source_practical": nmse_source_practical,
    "nmse_target_practical": nmse_target_practical,
    "nmse_source_LI_GAN": nmse_source_LI_GAN,
    "nmse_target_LI_GAN": nmse_target_LI_GAN,
    "nmse_source_practical_GAN": nmse_source_practical_GAN,
    "nmse_target_practical_GAN": nmse_target_practical_GAN,
    "SNR_dB_": SNR_dB_,
})

# %%
import matplotlib.pyplot as plt

# Epochs
epochs = [75, 150, 225]

# Data for ver36 (linear)
ver36_svm = [0.9847826086956522, 0.6804347826086956, 0.6260869565217391]
ver36_lda = [0.5478260869565217, 0.3021739130434784, 0.28695652173913055]
ver36_logreg = [0.5543478260869565, 0.30869565217391326, 0.27826086956521756]

# Data for ver37 (practical)
ver37_svm = [0.9152173913043478, 0.9195652173913045, 1.0282608695652176]
ver37_lda = [0.473913043478261, 0.3217391304347825, 0.606521739130435]
ver37_logreg = [0.4695652173913043, 0.31739130434782625, 0.606521739130435]

# --- Figure 1: ver36 linear ---
plt.figure(figsize=(7,5))
plt.plot(epochs, ver36_svm, '-o', label="SVM", linewidth=2)
plt.plot(epochs, ver36_lda, '-s', label="LDA", linewidth=2)
plt.plot(epochs, ver36_logreg, '-d', label="LogReg", linewidth=2)
plt.xlabel("Epochs")
plt.ylabel("PAD")
plt.title("SNR -15dB, LI-GAN")
plt.grid(True)
plt.legend()
plt.tight_layout()

# --- Figure 2: ver37 practical ---
plt.figure(figsize=(7,5))
plt.plot(epochs, ver37_svm, '-o', label="SVM", linewidth=2)
plt.plot(epochs, ver37_lda, '-s', label="LDA", linewidth=2)
plt.plot(epochs, ver37_logreg, '-d', label="LogReg", linewidth=2)
plt.xlabel("Epochs")
plt.ylabel("PAD")
plt.title("SNR -15dB, Practical-GAN")
plt.grid(True)
plt.legend()
plt.tight_layout()

plt.show()
